# %% [markdown]
# # Import Library

# %% [markdown]
# This code is for importing library what I need.

# %%
# !pip install numpy
# !pip install pandas
# !pip install nltk
# !pip install beautifulsoup4
# !pip install mpld3
# !pip install -U scikit-learn
# !pip install joblib
# !pip install gensim
# Out:
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.23.4)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.2.5)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.16.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: nltk in /shared-libs/python3.9/py/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (2022.9.13)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (8.1.3)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4) (2.3.2.post1)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: mpld3 in /root/venv/lib/python3.9/site-packages (0.5.9)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from mpld3) (2.11.3)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from mpld3) (3.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->mpld3) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (4.37.4)
# Requirement already satisfied: numpy>=1.19 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (1.23.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->mpld3) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->mpld3) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->mpld3) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (1.4.4)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mpld3) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: scikit-learn in /root/venv/lib/python3.9/site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.17.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: joblib>=1.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn) (1.9.3)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.2.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: gensim in /root/venv/lib/python3.9/site-packages (4.3.0)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /root/venv/lib/python3.9/site-packages (from gensim) (2.0.5)
# Requirement already satisfied: scipy>=1.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim) (1.9.3)
# Requirement already satisfied: numpy>=1.18.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim) (1.23.4)
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (from FuzzyTM>=0.4.0->gensim) (1.2.5)
# Requirement already satisfied: pyfume in /root/venv/lib/python3.9/site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2022.5)
# Requirement already satisfied: simpful in /root/venv/lib/python3.9/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.10.0)
# Requirement already satisfied: fst-pso in /root/venv/lib/python3.9/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: miniful in /root/venv/lib/python3.9/site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: requests in /shared-libs/python3.9/py/lib/python3.9/site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2022.9.24)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from bs4 import BeautifulSoup
import re
import os 
import codecs
from sklearn import feature_extraction
import mpld3
from glob import glob 
import json
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Get all the labels

# %% [markdown]
# ## Load the datasets

# %% [markdown]
# This code is for read JSON datasets, and take the labels column

# %%
#Load Labels CSV
df = pd.read_json("pallets_flask.json")
df
# Out:
#                                                     url  \
# 0     https://api.github.com/repos/pallets/flask/iss...
# 1     https://api.github.com/repos/pallets/flask/iss...
# 2     https://api.github.com/repos/pallets/flask/iss...
# 3     https://api.github.com/repos/pallets/flask/iss...
# 4     https://api.github.com/repos/pallets/flask/iss...
# ...                                                 ...
# 4644  https://api.github.com/repos/pallets/flask/iss...
# 4645  https://api.github.com/repos/pallets/flask/iss...
# 4646  https://api.github.com/repos/pallets/flask/iss...
# 4647  https://api.github.com/repos/pallets/flask/iss...
# 4648  https://api.github.com/repos/pallets/flask/iss...
#
#                                   repository_url  \
# 0     https://api.github.com/repos/pallets/flask
# 1     https://api.github.com/repos/pallets/flask
# 2     https://api.github.com/repos/pallets/flask
# 3     https://api.github.com/repos/pallets/flask
# 4     https://api.github.com/repos/pallets/flask
# ...                                          ...
# 4644  https://api.github.com/repos/pallets/flask
# 4645  https://api.github.com/repos/pallets/flask
# 4646  https://api.github.com/repos/pallets/flask
# 4647  https://api.github.com/repos/pallets/flask
# 4648  https://api.github.com/repos/pallets/flask
#
#                                              labels_url  \
# 0     https://api.github.com/repos/pallets/flask/iss...
# 1     https://api.github.com/repos/pallets/flask/iss...
# 2     https://api.github.com/repos/pallets/flask/iss...
# 3     https://api.github.com/repos/pallets/flask/iss...
# 4     https://api.github.com/repos/pallets/flask/iss...
# ...                                                 ...
# 4644  https://api.github.com/repos/pallets/flask/iss...
# 4645  https://api.github.com/repos/pallets/flask/iss...
# 4646  https://api.github.com/repos/pallets/flask/iss...
# 4647  https://api.github.com/repos/pallets/flask/iss...
# 4648  https://api.github.com/repos/pallets/flask/iss...
#
#                                            comments_url  \
# 0     https://api.github.com/repos/pallets/flask/iss...
# 1     https://api.github.com/repos/pallets/flask/iss...
# 2     https://api.github.com/repos/pallets/flask/iss...
# 3     https://api.github.com/repos/pallets/flask/iss...
# 4     https://api.github.com/repos/pallets/flask/iss...
# ...                                                 ...
# 4644  https://api.github.com/repos/pallets/flask/iss...
# 4645  https://api.github.com/repos/pallets/flask/iss...
# 4646  https://api.github.com/repos/pallets/flask/iss...
# 4647  https://api.github.com/repos/pallets/flask/iss...
# 4648  https://api.github.com/repos/pallets/flask/iss...
#
#                                              events_url  \
# 0     https://api.github.com/repos/pallets/flask/iss...
# 1     https://api.github.com/repos/pallets/flask/iss...
# 2     https://api.github.com/repos/pallets/flask/iss...
# 3     https://api.github.com/repos/pallets/flask/iss...
# 4     https://api.github.com/repos/pallets/flask/iss...
# ...                                                 ...
# 4644  https://api.github.com/repos/pallets/flask/iss...
# 4645  https://api.github.com/repos/pallets/flask/iss...
# 4646  https://api.github.com/repos/pallets/flask/iss...
# 4647  https://api.github.com/repos/pallets/flask/iss...
# 4648  https://api.github.com/repos/pallets/flask/iss...
#
#                                           html_url          id  \
# 0     https://github.com/pallets/flask/issues/4802  1360728252
# 1       https://github.com/pallets/flask/pull/4801  1360360916
# 2     https://github.com/pallets/flask/issues/4800  1360165146
# 3       https://github.com/pallets/flask/pull/4799  1359599579
# 4     https://github.com/pallets/flask/issues/4798  1358580833
# ...                                            ...         ...
# 4644     https://github.com/pallets/flask/issues/5      170451
# 4645     https://github.com/pallets/flask/issues/4      170448
# 4646     https://github.com/pallets/flask/issues/3      170445
# 4647     https://github.com/pallets/flask/issues/2      170444
# 4648     https://github.com/pallets/flask/issues/1      170443
#
#                    node_id  number  \
# 0       I_kwDOAAkbnM5RGxC8    4802
# 1      PR_kwDOAAkbnM4-Smp1    4801
# 2       I_kwDOAAkbnM5REnka    4800
# 3      PR_kwDOAAkbnM4-QFCh    4799
# 4       I_kwDOAAkbnM5Q-kxh    4798
# ...                    ...     ...
# 4644  MDU6SXNzdWUxNzA0NTE=       5
# 4645  MDU6SXNzdWUxNzA0NDg=       4
# 4646  MDU6SXNzdWUxNzA0NDU=       3
# 4647  MDU6SXNzdWUxNzA0NDQ=       2
# 4648  MDU6SXNzdWUxNzA0NDM=       1
#
#                                                   title  ...  \
# 0         New bug that never happen in previous version  ...
# 1                           Add missing .dev to version  ...
# 2     TypeError: Unicode-objects must be encoded bef...  ...
# 3               Close p tag in templateinheritance docs  ...
# 4     Split session across multiple chunks if the se...  ...
# ...                                                 ...  ...
# 4644                               Implement SQLAlchemy  ...
# 4645                           Integrate Babel for i18n  ...
# 4646          Switch to explicit request object passing  ...
# 4647      Get rid of the decorator function registering  ...
# 4648           Implement dotted names for URL endpoints  ...
#
#                      closed_at author_association active_lock_reason  \
# 0    2022-09-03 02:38:45+00:00               NONE               None
# 1    2022-09-02 15:52:14+00:00        CONTRIBUTOR               None
# 2    2022-09-02 14:47:46+00:00               NONE               None
# 3    2022-09-02 03:50:23+00:00               NONE               None
# 4    2022-09-01 12:06:50+00:00               NONE               None
# ...                        ...                ...                ...
# 4644 2010-04-13 10:53:09+00:00        CONTRIBUTOR           resolved
# 4645 2010-04-13 10:53:09+00:00        CONTRIBUTOR           resolved
# 4646 2010-04-13 10:53:09+00:00        CONTRIBUTOR           resolved
# 4647 2010-04-13 10:53:09+00:00        CONTRIBUTOR           resolved
# 4648 2010-04-13 10:53:09+00:00        CONTRIBUTOR           resolved
#
#                                                    body  \
# 0     **what the bug is:**\r\nwerkzeug.routing.excep...
# 1     This issue was causing many dead github links ...
# 2     Disclaimer: I'm a newbie.\r\n\r\nHi,\r\n\r\nI'...
# 3     I noticed this when going through the docs.\r\...
# 4     It is not uncommon nowadays for big organizati...
# ...                                                 ...
# 4644   Use SQLAlchemy in the core framework as an ORM\n
# 4645                        http://babel.edgewall.org\n
# 4646  This makes it more to type (because you now ha...
# 4647  Causes a lot of troubles for applications that...
# 4648  It makes a lot of sense to change the way endp...
#
#                                               reactions  \
# 0     {'url': 'https://api.github.com/repos/pallets/...
# 1     {'url': 'https://api.github.com/repos/pallets/...
# 2     {'url': 'https://api.github.com/repos/pallets/...
# 3     {'url': 'https://api.github.com/repos/pallets/...
# 4     {'url': 'https://api.github.com/repos/pallets/...
# ...                                                 ...
# 4644  {'url': 'https://api.github.com/repos/pallets/...
# 4645  {'url': 'https://api.github.com/repos/pallets/...
# 4646  {'url': 'https://api.github.com/repos/pallets/...
# 4647  {'url': 'https://api.github.com/repos/pallets/...
# 4648  {'url': 'https://api.github.com/repos/pallets/...
#
#                                            timeline_url  \
# 0     https://api.github.com/repos/pallets/flask/iss...
# 1     https://api.github.com/repos/pallets/flask/iss...
# 2     https://api.github.com/repos/pallets/flask/iss...
# 3     https://api.github.com/repos/pallets/flask/iss...
# 4     https://api.github.com/repos/pallets/flask/iss...
# ...                                                 ...
# 4644  https://api.github.com/repos/pallets/flask/iss...
# 4645  https://api.github.com/repos/pallets/flask/iss...
# 4646  https://api.github.com/repos/pallets/flask/iss...
# 4647  https://api.github.com/repos/pallets/flask/iss...
# 4648  https://api.github.com/repos/pallets/flask/iss...
#
#      performed_via_github_app  state_reason draft  \
# 0                         NaN     completed   NaN
# 1                         NaN          None   0.0
# 2                         NaN   not_planned   NaN
# 3                         NaN          None   0.0
# 4                         NaN   not_planned   NaN
# ...                       ...           ...   ...
# 4644                      NaN     completed   NaN
# 4645                      NaN     completed   NaN
# 4646                      NaN     completed   NaN
# 4647                      NaN     completed   NaN
# 4648                      NaN     completed   NaN
#
#                                            pull_request
# 0                                                   NaN
# 1     {'url': 'https://api.github.com/repos/pallets/...
# 2                                                   NaN
# 3     {'url': 'https://api.github.com/repos/pallets/...
# 4                                                   NaN
# ...                                                 ...
# 4644                                                NaN
# 4645                                                NaN
# 4646                                                NaN
# 4647                                                NaN
# 4648                                                NaN
#
# [4649 rows x 30 columns]

# %% [markdown]
# ## Take Closed Data

# %% [markdown]
# This is code to take data that is stated "close".

# %%
List = []
for ind, col in df.iterrows():
    if col["state"] == "closed":
        List.extend(col["labels"])

# %%
List
# Out:
# [{'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 398831866,
#   'node_id': 'MDU6TGFiZWwzOTg4MzE4NjY=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/json',
#   'name': 'json',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 398831866,
#   'node_id': 'MDU6TGFiZWwzOTg4MzE4NjY=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/json',
#   'name': 'json',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 398831866,
#   'node_id': 'MDU6TGFiZWwzOTg4MzE4NjY=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/json',
#   'name': 'json',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 1373069970,
#   'node_id': 'MDU6TGFiZWwxMzczMDY5OTcw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/save-for-sprint',
#   'name': 'save-for-sprint',
#   'color': 'ff6bd2',
#   'default': False,
#   'description': "Please don't pick this unless you're participating in an official sprint."},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 1373069970,
#   'node_id': 'MDU6TGFiZWwxMzczMDY5OTcw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/save-for-sprint',
#   'name': 'save-for-sprint',
#   'color': 'ff6bd2',
#   'default': False,
#   'description': "Please don't pick this unless you're participating in an official sprint."},
#  {'id': 1373069970,
#   'node_id': 'MDU6TGFiZWwxMzczMDY5OTcw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/save-for-sprint',
#   'name': 'save-for-sprint',
#   'color': 'ff6bd2',
#   'default': False,
#   'description': "Please don't pick this unless you're participating in an official sprint."},
#  {'id': 1373069970,
#   'node_id': 'MDU6TGFiZWwxMzczMDY5OTcw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/save-for-sprint',
#   'name': 'save-for-sprint',
#   'color': 'ff6bd2',
#   'default': False,
#   'description': "Please don't pick this unless you're participating in an official sprint."},
#  {'id': 1373069970,
#   'node_id': 'MDU6TGFiZWwxMzczMDY5OTcw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/save-for-sprint',
#   'name': 'save-for-sprint',
#   'color': 'ff6bd2',
#   'default': False,
#   'description': "Please don't pick this unless you're participating in an official sprint."},
#  {'id': 386620463,
#   'node_id': 'MDU6TGFiZWwzODY2MjA0NjM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/testing',
#   'name': 'testing',
#   'color': '006b75',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 3689541866,
#   'node_id': 'LA_kwDOAAkbnM7b6fDq',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/python',
#   'name': 'python',
#   'color': '2b67c6',
#   'default': False,
#   'description': 'Pull requests that update Python code'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 3689541866,
#   'node_id': 'LA_kwDOAAkbnM7b6fDq',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/python',
#   'name': 'python',
#   'color': '2b67c6',
#   'default': False,
#   'description': 'Pull requests that update Python code'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 3689541866,
#   'node_id': 'LA_kwDOAAkbnM7b6fDq',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/python',
#   'name': 'python',
#   'color': '2b67c6',
#   'default': False,
#   'description': 'Pull requests that update Python code'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 3689541866,
#   'node_id': 'LA_kwDOAAkbnM7b6fDq',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/python',
#   'name': 'python',
#   'color': '2b67c6',
#   'default': False,
#   'description': 'Pull requests that update Python code'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 3689541866,
#   'node_id': 'LA_kwDOAAkbnM7b6fDq',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/python',
#   'name': 'python',
#   'color': '2b67c6',
#   'default': False,
#   'description': 'Pull requests that update Python code'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 3689541866,
#   'node_id': 'LA_kwDOAAkbnM7b6fDq',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/python',
#   'name': 'python',
#   'color': '2b67c6',
#   'default': False,
#   'description': 'Pull requests that update Python code'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 3689541866,
#   'node_id': 'LA_kwDOAAkbnM7b6fDq',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/python',
#   'name': 'python',
#   'color': '2b67c6',
#   'default': False,
#   'description': 'Pull requests that update Python code'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 3689541866,
#   'node_id': 'LA_kwDOAAkbnM7b6fDq',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/python',
#   'name': 'python',
#   'color': '2b67c6',
#   'default': False,
#   'description': 'Pull requests that update Python code'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 3689541866,
#   'node_id': 'LA_kwDOAAkbnM7b6fDq',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/python',
#   'name': 'python',
#   'color': '2b67c6',
#   'default': False,
#   'description': 'Pull requests that update Python code'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 3666396815,
#   'node_id': 'LA_kwDOAAkbnM7aiMaP',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/github_actions',
#   'name': 'github_actions',
#   'color': '000000',
#   'default': False,
#   'description': 'Pull requests that update Github_actions code'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 135583063,
#   'node_id': 'MDU6TGFiZWwxMzU1ODMwNjM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/bug',
#   'name': 'bug',
#   'color': 'd93f0b',
#   'default': True,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 170296925,
#   'node_id': 'MDU6TGFiZWwxNzAyOTY5MjU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/good%20first%20issue',
#   'name': 'good first issue',
#   'color': 'fbca04',
#   'default': True,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2235274456,
#   'node_id': 'MDU6TGFiZWwyMjM1Mjc0NDU2',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/async',
#   'name': 'async',
#   'color': '2cb7a9',
#   'default': False,
#   'description': ''},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 135583063,
#   'node_id': 'MDU6TGFiZWwxMzU1ODMwNjM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/bug',
#   'name': 'bug',
#   'color': 'd93f0b',
#   'default': True,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 135583063,
#   'node_id': 'MDU6TGFiZWwxMzU1ODMwNjM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/bug',
#   'name': 'bug',
#   'color': 'd93f0b',
#   'default': True,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 1097195323,
#   'node_id': 'MDU6TGFiZWwxMDk3MTk1MzIz',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/Invalid',
#   'name': 'Invalid',
#   'color': 'ffaaff',
#   'default': False,
#   'description': 'Hacktoberfest: Very low quality PRs (or spam)'},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2090966500,
#   'node_id': 'MDU6TGFiZWwyMDkwOTY2NTAw',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/dependencies',
#   'name': 'dependencies',
#   'color': '0366d6',
#   'default': False,
#   'description': 'Pull requests that update a dependency file'},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 2997785562,
#   'node_id': 'MDU6TGFiZWwyOTk3Nzg1NTYy',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/typing',
#   'name': 'typing',
#   'color': '6087FE',
#   'default': False,
#   'description': ''},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 135583063,
#   'node_id': 'MDU6TGFiZWwxMzU1ODMwNjM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/bug',
#   'name': 'bug',
#   'color': 'd93f0b',
#   'default': True,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
# ...
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 130597497,
#   'node_id': 'MDU6TGFiZWwxMzA1OTc0OTc=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blocker',
#   'name': 'blocker',
#   'color': 'b60205',
#   'default': False,
#   'description': None},
#  {'id': 135583063,
#   'node_id': 'MDU6TGFiZWwxMzU1ODMwNjM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/bug',
#   'name': 'bug',
#   'color': 'd93f0b',
#   'default': True,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 135583063,
#   'node_id': 'MDU6TGFiZWwxMzU1ODMwNjM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/bug',
#   'name': 'bug',
#   'color': 'd93f0b',
#   'default': True,
#   'description': None},
#  {'id': 135583063,
#   'node_id': 'MDU6TGFiZWwxMzU1ODMwNjM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/bug',
#   'name': 'bug',
#   'color': 'd93f0b',
#   'default': True,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 130597497,
#   'node_id': 'MDU6TGFiZWwxMzA1OTc0OTc=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blocker',
#   'name': 'blocker',
#   'color': 'b60205',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 125213303,
#   'node_id': 'MDU6TGFiZWwxMjUyMTMzMDM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/discussion',
#   'name': 'discussion',
#   'color': 'c5def5',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 125213303,
#   'node_id': 'MDU6TGFiZWwxMjUyMTMzMDM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/discussion',
#   'name': 'discussion',
#   'color': 'c5def5',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 125213303,
#   'node_id': 'MDU6TGFiZWwxMjUyMTMzMDM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/discussion',
#   'name': 'discussion',
#   'color': 'c5def5',
#   'default': False,
#   'description': None},
#  {'id': 135583063,
#   'node_id': 'MDU6TGFiZWwxMzU1ODMwNjM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/bug',
#   'name': 'bug',
#   'color': 'd93f0b',
#   'default': True,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 380608249,
#   'node_id': 'MDU6TGFiZWwzODA2MDgyNDk=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/cli',
#   'name': 'cli',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 125213303,
#   'node_id': 'MDU6TGFiZWwxMjUyMTMzMDM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/discussion',
#   'name': 'discussion',
#   'color': 'c5def5',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 398835124,
#   'node_id': 'MDU6TGFiZWwzOTg4MzUxMjQ=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/session',
#   'name': 'session',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 130597497,
#   'node_id': 'MDU6TGFiZWwxMzA1OTc0OTc=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blocker',
#   'name': 'blocker',
#   'color': 'b60205',
#   'default': False,
#   'description': None},
#  {'id': 130597497,
#   'node_id': 'MDU6TGFiZWwxMzA1OTc0OTc=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blocker',
#   'name': 'blocker',
#   'color': 'b60205',
#   'default': False,
#   'description': None},
#  {'id': 135583063,
#   'node_id': 'MDU6TGFiZWwxMzU1ODMwNjM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/bug',
#   'name': 'bug',
#   'color': 'd93f0b',
#   'default': True,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 125213303,
#   'node_id': 'MDU6TGFiZWwxMjUyMTMzMDM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/discussion',
#   'name': 'discussion',
#   'color': 'c5def5',
#   'default': False,
#   'description': None},
#  {'id': 125213303,
#   'node_id': 'MDU6TGFiZWwxMjUyMTMzMDM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/discussion',
#   'name': 'discussion',
#   'color': 'c5def5',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 648340773,
#   'node_id': 'MDU6TGFiZWw2NDgzNDA3NzM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/logging',
#   'name': 'logging',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 170296925,
#   'node_id': 'MDU6TGFiZWwxNzAyOTY5MjU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/good%20first%20issue',
#   'name': 'good first issue',
#   'color': 'fbca04',
#   'default': True,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 170296925,
#   'node_id': 'MDU6TGFiZWwxNzAyOTY5MjU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/good%20first%20issue',
#   'name': 'good first issue',
#   'color': 'fbca04',
#   'default': True,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 170296925,
#   'node_id': 'MDU6TGFiZWwxNzAyOTY5MjU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/good%20first%20issue',
#   'name': 'good first issue',
#   'color': 'fbca04',
#   'default': True,
#   'description': None},
#  {'id': 357932495,
#   'node_id': 'MDU6TGFiZWwzNTc5MzI0OTU=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/blueprints',
#   'name': 'blueprints',
#   'color': '1d76db',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 125213303,
#   'node_id': 'MDU6TGFiZWwxMjUyMTMzMDM=',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/discussion',
#   'name': 'discussion',
#   'color': 'c5def5',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None},
#  {'id': 32876,
#   'node_id': 'MDU6TGFiZWwzMjg3Ng==',
#   'url': 'https://api.github.com/repos/pallets/flask/labels/docs',
#   'name': 'docs',
#   'color': '0e8a16',
#   'default': False,
#   'description': None}]

# %% [markdown]
# Try make a method to flat nested labels data and append it on empty list.Make visualization of list of labels but there is a lot of duplication.

# %%
List_Labels = []
for i in range(len(List)):
    List_Labels.append(List[i]["name"])
pd.DataFrame(List_Labels)
# Out:
#               0
# 0          docs
# 1          docs
# 2          docs
# 3          docs
# 4           cli
# ..          ...
# 917  discussion
# 918        docs
# 919        docs
# 920        docs
# 921        docs
#
# [922 rows x 1 columns]

# %% [markdown]
# Make visualization of list of labels but there is no duplication.

# %%
mylist = list(dict.fromkeys(List_Labels))
df_list_labels = pd.DataFrame(mylist)

# %%
df_list_labels
# Out:
#                    0
# 0               docs
# 1                cli
# 2             typing
# 3               json
# 4       dependencies
# 5    save-for-sprint
# 6            testing
# 7             python
# 8     github_actions
# 9                bug
# 10  good first issue
# 11             async
# 12           Invalid
# 13        blueprints
# 14          security
# 15           logging
# 16         packaging
# 17           session
# 18        discussion
# 19           blocker

# %%
df_list_labels.to_csv("List_of_Labels_No_Duplication.csv")

# %% [markdown]
# # After Classification

# %% [markdown]
# This code for reading csv dataset with classification labels

# %%
#Load Labels CSV
df_labels_classification = pd.read_csv("List_of_Labels_No_Duplication_Flask.csv")
df_labels_classification
# Out:
#               Labels  Unrelated  Experts Labels  Newcomers Labels  Critical  \
# 0               docs      False            True              True     False
# 1                cli       True           False             False     False
# 2             typing      False            True              True     False
# 3               json       True           False             False     False
# 4       dependencies       True            True              True     False
# 5    save-for-sprint      False            True              True     False
# 6            testing      False            True             False     False
# 7             python       True           False             False     False
# 8     github_actions       True           False             False     False
# 9                bug      False            True              True     False
# 10  good first issue      False           False              True     False
# 11             async       True           False             False     False
# 12           Invalid       True           False             False     False
# 13        blueprints      False            True             False     False
# 14          security      False            True             False     False
# 15           logging      False            True             False     False
# 16         packaging      False            True             False     False
# 17           session      False            True             False     False
# 18        discussion      False            True             False     False
# 19           blocker      False            True             False     False
#
#     NonCritical
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False

# %% [markdown]
# Slice only on boolean on Expert Labels

# %%
df_labels_classification['Experts Labels']
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# Name: Experts Labels, dtype: bool

# %% [markdown]
# Change Boolean to String on Expert Labels and Newcomers Labels item.

# %%
df_labels_classification['Experts Labels'] = df_labels_classification['Experts Labels'].map({True: 'True', False: 'False'})

# %%
df_labels_classification['Newcomers Labels'] = df_labels_classification['Newcomers Labels'].map({True: 'True', False: 'False'})

# %% [markdown]
# Make query of take all labels that is True on Expert Labels.

# %%
Expert_labels_classification = df_labels_classification[df_labels_classification['Experts Labels'].str.contains("True") & df_labels_classification['Newcomers Labels'].str.contains("False")]

# %% [markdown]
# Make column Unnamed to Labels.

# %%
Expert_labels_classification.rename( columns={'Unnamed: 0':'Labels'}, inplace=True )
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# Show the result.

# %%
Expert_labels_classification
# Out:
#         Labels  Unrelated Experts Labels Newcomers Labels  Critical  \
# 6      testing      False           True            False     False
# 13  blueprints      False           True            False     False
# 14    security      False           True            False     False
# 15     logging      False           True            False     False
# 16   packaging      False           True            False     False
# 17     session      False           True            False     False
# 18  discussion      False           True            False     False
# 19     blocker      False           True            False     False
#
#     NonCritical
# 6         False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False

# %% [markdown]
# Take item labels according on Expert classification

# %%
Expert_labels_classification['Labels']
# Out:
# 6        testing
# 13    blueprints
# 14      security
# 15       logging
# 16     packaging
# 17       session
# 18    discussion
# 19       blocker
# Name: Labels, dtype: object

# %% [markdown]
# This code for take item labels from Expert classification

# %%
Expert_labels = Expert_labels_classification['Labels']

# %% [markdown]
# This code for making new csv with the list of expert labels

# %%
Expert_labels.to_csv("labels_expert.csv", index=False)

# %% [markdown]
# Load data expert labels from csv

# %%
df_labels_expert = pd.read_csv("labels_expert.csv")
df_labels_expert
# Out:
#        Labels
# 0     testing
# 1  blueprints
# 2    security
# 3     logging
# 4   packaging
# 5     session
# 6  discussion
# 7     blocker

# %% [markdown]
# # Make query of take all labels that is True on Newcomers Labels.

# %%
Newcomers_labels_classification = df_labels_classification[df_labels_classification['Newcomers Labels'].str.contains("True")& df_labels_classification['Experts Labels'].str.contains("False")]

# %% [markdown]
# Make column Unnamed to Labels.

# %%
Newcomers_labels_classification.rename( columns={'Unnamed: 0':'Labels'}, inplace=True )
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# Show the result.

# %%
Newcomers_labels_classification
# Out:
#               Labels  Unrelated Experts Labels Newcomers Labels  Critical  \
# 10  good first issue      False          False             True     False
#
#     NonCritical
# 10        False

# %% [markdown]
# Take item labels according on Expert classification

# %%
Newcomers_labels_classification['Labels']
# Out:
# 10    good first issue
# Name: Labels, dtype: object

# %% [markdown]
# This code for take item labels from newcomers classification

# %%
Labels_Newcomers = Newcomers_labels_classification['Labels']

# %% [markdown]
# This code for take item labels from newcomers classification

# %%
Labels_Newcomers.to_csv("labels_newcomers.csv", index=False)

# %% [markdown]
# Load data newcomers labels from csv

# %%
df_labels_newcomers = pd.read_csv("labels_newcomers.csv")
df_labels_newcomers
# Out:
#              Labels
# 0  good first issue

# %% [markdown]
# # Make query of take all labels that is True on Experts and Newcomers Labels.

# %%
Expert_And_Newcomers_labels_classification = df_labels_classification[df_labels_classification['Experts Labels'].str.contains("True") & df_labels_classification['Newcomers Labels'].str.contains("True")]

# %% [markdown]
# Make column Unnamed to Labels.

# %%
Expert_And_Newcomers_labels_classification.rename( columns={'Unnamed: 0':'Labels'}, inplace=True )
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# Show the result.

# %%
Expert_And_Newcomers_labels_classification
# Out:
#             Labels  Unrelated Experts Labels Newcomers Labels  Critical  \
# 0             docs      False           True             True     False
# 2           typing      False           True             True     False
# 4     dependencies       True           True             True     False
# 5  save-for-sprint      False           True             True     False
# 9              bug      False           True             True     False
#
#    NonCritical
# 0         True
# 2        False
# 4        False
# 5        False
# 9        False

# %% [markdown]
# Take item labels according on Newcomers and Expert classification

# %%
Expert_And_Newcomers_labels_classification["Labels"]
# Out:
# 0               docs
# 2             typing
# 4       dependencies
# 5    save-for-sprint
# 9                bug
# Name: Labels, dtype: object

# %% [markdown]
# This code for take item labels from newcomers and experts classification

# %%
Labels_Expert_And_Newcomers = Expert_And_Newcomers_labels_classification["Labels"]

# %% [markdown]
# This code for making new csv with the list of newcomers and experts labels

# %%
Labels_Expert_And_Newcomers.to_csv("labels_experts_newcomers.csv", index=False)

# %% [markdown]
# Load data experts and newcomers labels from csv

# %%
df_labels_experts_newcomers = pd.read_csv("labels_experts_newcomers.csv")
df_labels_experts_newcomers
# Out:
#             Labels
# 0             docs
# 1           typing
# 2     dependencies
# 3  save-for-sprint
# 4              bug

# %% [markdown]
# # Combine Newcomers and Experts

# %%
result = Labels_Newcomers.append(Expert_labels)
pd.DataFrame(result)
# Out:
#               Labels
# 10  good first issue
# 6            testing
# 13        blueprints
# 14          security
# 15           logging
# 16         packaging
# 17           session
# 18        discussion
# 19           blocker

# %% [markdown]
# make it CSV

# %%
result.to_csv("labels_experts_newcomers_combined.csv", index=False)

# %% [markdown]
# show the result

# %%
df_labels_experts_newcomers_combined = pd.read_csv("labels_experts_newcomers_combined.csv")
df_labels_experts_newcomers_combined
# Out:
#              Labels
# 0  good first issue
# 1           testing
# 2        blueprints
# 3          security
# 4           logging
# 5         packaging
# 6           session
# 7        discussion
# 8           blocker

# %% [markdown]
# # Try Make Query for Issues according Labels Newcomers, Expert and Both

# %% [markdown]
# Convert aws_aws-cdk_close.json to csv file

# %%
df.to_csv("pallets_flask.csv",index=False)

# %% [markdown]
# Load aws_aws-cdk_close.csv

# %%
df2 = pd.read_csv("pallets_flask.csv")
df2.index += 1 
df2
# Out:
#                                                     url  \
# 1     https://api.github.com/repos/pallets/flask/iss...
# 2     https://api.github.com/repos/pallets/flask/iss...
# 3     https://api.github.com/repos/pallets/flask/iss...
# 4     https://api.github.com/repos/pallets/flask/iss...
# 5     https://api.github.com/repos/pallets/flask/iss...
# ...                                                 ...
# 4645  https://api.github.com/repos/pallets/flask/iss...
# 4646  https://api.github.com/repos/pallets/flask/iss...
# 4647  https://api.github.com/repos/pallets/flask/iss...
# 4648  https://api.github.com/repos/pallets/flask/iss...
# 4649  https://api.github.com/repos/pallets/flask/iss...
#
#                                   repository_url  \
# 1     https://api.github.com/repos/pallets/flask
# 2     https://api.github.com/repos/pallets/flask
# 3     https://api.github.com/repos/pallets/flask
# 4     https://api.github.com/repos/pallets/flask
# 5     https://api.github.com/repos/pallets/flask
# ...                                          ...
# 4645  https://api.github.com/repos/pallets/flask
# 4646  https://api.github.com/repos/pallets/flask
# 4647  https://api.github.com/repos/pallets/flask
# 4648  https://api.github.com/repos/pallets/flask
# 4649  https://api.github.com/repos/pallets/flask
#
#                                              labels_url  \
# 1     https://api.github.com/repos/pallets/flask/iss...
# 2     https://api.github.com/repos/pallets/flask/iss...
# 3     https://api.github.com/repos/pallets/flask/iss...
# 4     https://api.github.com/repos/pallets/flask/iss...
# 5     https://api.github.com/repos/pallets/flask/iss...
# ...                                                 ...
# 4645  https://api.github.com/repos/pallets/flask/iss...
# 4646  https://api.github.com/repos/pallets/flask/iss...
# 4647  https://api.github.com/repos/pallets/flask/iss...
# 4648  https://api.github.com/repos/pallets/flask/iss...
# 4649  https://api.github.com/repos/pallets/flask/iss...
#
#                                            comments_url  \
# 1     https://api.github.com/repos/pallets/flask/iss...
# 2     https://api.github.com/repos/pallets/flask/iss...
# 3     https://api.github.com/repos/pallets/flask/iss...
# 4     https://api.github.com/repos/pallets/flask/iss...
# 5     https://api.github.com/repos/pallets/flask/iss...
# ...                                                 ...
# 4645  https://api.github.com/repos/pallets/flask/iss...
# 4646  https://api.github.com/repos/pallets/flask/iss...
# 4647  https://api.github.com/repos/pallets/flask/iss...
# 4648  https://api.github.com/repos/pallets/flask/iss...
# 4649  https://api.github.com/repos/pallets/flask/iss...
#
#                                              events_url  \
# 1     https://api.github.com/repos/pallets/flask/iss...
# 2     https://api.github.com/repos/pallets/flask/iss...
# 3     https://api.github.com/repos/pallets/flask/iss...
# 4     https://api.github.com/repos/pallets/flask/iss...
# 5     https://api.github.com/repos/pallets/flask/iss...
# ...                                                 ...
# 4645  https://api.github.com/repos/pallets/flask/iss...
# 4646  https://api.github.com/repos/pallets/flask/iss...
# 4647  https://api.github.com/repos/pallets/flask/iss...
# 4648  https://api.github.com/repos/pallets/flask/iss...
# 4649  https://api.github.com/repos/pallets/flask/iss...
#
#                                           html_url          id  \
# 1     https://github.com/pallets/flask/issues/4802  1360728252
# 2       https://github.com/pallets/flask/pull/4801  1360360916
# 3     https://github.com/pallets/flask/issues/4800  1360165146
# 4       https://github.com/pallets/flask/pull/4799  1359599579
# 5     https://github.com/pallets/flask/issues/4798  1358580833
# ...                                            ...         ...
# 4645     https://github.com/pallets/flask/issues/5      170451
# 4646     https://github.com/pallets/flask/issues/4      170448
# 4647     https://github.com/pallets/flask/issues/3      170445
# 4648     https://github.com/pallets/flask/issues/2      170444
# 4649     https://github.com/pallets/flask/issues/1      170443
#
#                    node_id  number  \
# 1       I_kwDOAAkbnM5RGxC8    4802
# 2      PR_kwDOAAkbnM4-Smp1    4801
# 3       I_kwDOAAkbnM5REnka    4800
# 4      PR_kwDOAAkbnM4-QFCh    4799
# 5       I_kwDOAAkbnM5Q-kxh    4798
# ...                    ...     ...
# 4645  MDU6SXNzdWUxNzA0NTE=       5
# 4646  MDU6SXNzdWUxNzA0NDg=       4
# 4647  MDU6SXNzdWUxNzA0NDU=       3
# 4648  MDU6SXNzdWUxNzA0NDQ=       2
# 4649  MDU6SXNzdWUxNzA0NDM=       1
#
#                                                   title  ...  \
# 1         New bug that never happen in previous version  ...
# 2                           Add missing .dev to version  ...
# 3     TypeError: Unicode-objects must be encoded bef...  ...
# 4               Close p tag in templateinheritance docs  ...
# 5     Split session across multiple chunks if the se...  ...
# ...                                                 ...  ...
# 4645                               Implement SQLAlchemy  ...
# 4646                           Integrate Babel for i18n  ...
# 4647          Switch to explicit request object passing  ...
# 4648      Get rid of the decorator function registering  ...
# 4649           Implement dotted names for URL endpoints  ...
#
#                       closed_at author_association active_lock_reason  \
# 1     2022-09-03 02:38:45+00:00               NONE                NaN
# 2     2022-09-02 15:52:14+00:00        CONTRIBUTOR                NaN
# 3     2022-09-02 14:47:46+00:00               NONE                NaN
# 4     2022-09-02 03:50:23+00:00               NONE                NaN
# 5     2022-09-01 12:06:50+00:00               NONE                NaN
# ...                         ...                ...                ...
# 4645  2010-04-13 10:53:09+00:00        CONTRIBUTOR           resolved
# 4646  2010-04-13 10:53:09+00:00        CONTRIBUTOR           resolved
# 4647  2010-04-13 10:53:09+00:00        CONTRIBUTOR           resolved
# 4648  2010-04-13 10:53:09+00:00        CONTRIBUTOR           resolved
# 4649  2010-04-13 10:53:09+00:00        CONTRIBUTOR           resolved
#
#                                                    body  \
# 1     **what the bug is:**\r\nwerkzeug.routing.excep...
# 2     This issue was causing many dead github links ...
# 3     Disclaimer: I'm a newbie.\r\n\r\nHi,\r\n\r\nI'...
# 4     I noticed this when going through the docs.\r\...
# 5     It is not uncommon nowadays for big organizati...
# ...                                                 ...
# 4645   Use SQLAlchemy in the core framework as an ORM\n
# 4646                        http://babel.edgewall.org\n
# 4647  This makes it more to type (because you now ha...
# 4648  Causes a lot of troubles for applications that...
# 4649  It makes a lot of sense to change the way endp...
#
#                                               reactions  \
# 1     {'url': 'https://api.github.com/repos/pallets/...
# 2     {'url': 'https://api.github.com/repos/pallets/...
# 3     {'url': 'https://api.github.com/repos/pallets/...
# 4     {'url': 'https://api.github.com/repos/pallets/...
# 5     {'url': 'https://api.github.com/repos/pallets/...
# ...                                                 ...
# 4645  {'url': 'https://api.github.com/repos/pallets/...
# 4646  {'url': 'https://api.github.com/repos/pallets/...
# 4647  {'url': 'https://api.github.com/repos/pallets/...
# 4648  {'url': 'https://api.github.com/repos/pallets/...
# 4649  {'url': 'https://api.github.com/repos/pallets/...
#
#                                            timeline_url  \
# 1     https://api.github.com/repos/pallets/flask/iss...
# 2     https://api.github.com/repos/pallets/flask/iss...
# 3     https://api.github.com/repos/pallets/flask/iss...
# 4     https://api.github.com/repos/pallets/flask/iss...
# 5     https://api.github.com/repos/pallets/flask/iss...
# ...                                                 ...
# 4645  https://api.github.com/repos/pallets/flask/iss...
# 4646  https://api.github.com/repos/pallets/flask/iss...
# 4647  https://api.github.com/repos/pallets/flask/iss...
# 4648  https://api.github.com/repos/pallets/flask/iss...
# 4649  https://api.github.com/repos/pallets/flask/iss...
#
#      performed_via_github_app  state_reason draft  \
# 1                         NaN     completed   NaN
# 2                         NaN           NaN   0.0
# 3                         NaN   not_planned   NaN
# 4                         NaN           NaN   0.0
# 5                         NaN   not_planned   NaN
# ...                       ...           ...   ...
# 4645                      NaN     completed   NaN
# 4646                      NaN     completed   NaN
# 4647                      NaN     completed   NaN
# 4648                      NaN     completed   NaN
# 4649                      NaN     completed   NaN
#
#                                            pull_request
# 1                                                   NaN
# 2     {'url': 'https://api.github.com/repos/pallets/...
# 3                                                   NaN
# 4     {'url': 'https://api.github.com/repos/pallets/...
# 5                                                   NaN
# ...                                                 ...
# 4645                                                NaN
# 4646                                                NaN
# 4647                                                NaN
# 4648                                                NaN
# 4649                                                NaN
#
# [4649 rows x 30 columns]

# %%
df2.to_csv("pallets_flask_close_index.csv",index=False)

# %% [markdown]
# # Newcomers

# %% [markdown]
# Add items in newcomers labels to an empty list.

# %%
List_Labels_Newcomers = []
for i in range(len(df_labels_newcomers)):
    List_Labels_Newcomers.append(df_labels_newcomers['Labels'][i])

# %% [markdown]
# This code is for querrying the datasets according list of labels of newcomers

# %%
df2_newcomers_labels = df2[df2['labels'].str.contains('|'.join(List_Labels_Newcomers))]

# %% [markdown]
# Show data newcomers labels

# %%
pd.DataFrame(df2_newcomers_labels['labels'])
# Out:
#                                                  labels
# 387   [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 893   [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 1438  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 1439  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 1447  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 1448  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 1452  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 1626  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 1711  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 2132  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 2283  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 2341  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 2367  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 2369  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 2373  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 2389  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 2393  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 2399  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 2403  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 2411  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 2624  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 2664  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 2734  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 2738  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 2742  [{'id': 135583063, 'node_id': 'MDU6TGFiZWwxMzU...
# 2824  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 2835  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 2861  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 3007  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 3186  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 3209  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 3254  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 3362  [{'id': 125213303, 'node_id': 'MDU6TGFiZWwxMjU...
# 4118  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4216  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4384  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...

# %% [markdown]
# # Experts

# %% [markdown]
# Add items in Expert labels to an empty list.

# %%
List_Labels_Expert = []
for i in range(len(df_labels_expert)):
    List_Labels_Expert.append(df_labels_expert['Labels'][i])

# %% [markdown]
# This code is for querrying the datasets according list of labels of experts

# %%
df2_expert_labels = df2[df2['labels'].str.contains('|'.join(List_Labels_Expert))]

# %% [markdown]
# Show data expert labels

# %%
pd.DataFrame(df2_expert_labels['labels'])
# Out:
#                                                  labels
# 203   [{'id': 386620463, 'node_id': 'MDU6TGFiZWwzODY...
# 599   [{'id': 357932495, 'node_id': 'MDU6TGFiZWwzNTc...
# 610   [{'id': 357932495, 'node_id': 'MDU6TGFiZWwzNTc...
# 615   [{'id': 357932495, 'node_id': 'MDU6TGFiZWwzNTc...
# 621   [{'id': 357932495, 'node_id': 'MDU6TGFiZWwzNTc...
# ...                                                 ...
# 4228  [{'id': 357932495, 'node_id': 'MDU6TGFiZWwzNTc...
# 4302  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4361  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4384  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4475  [{'id': 125213303, 'node_id': 'MDU6TGFiZWwxMjU...
#
# [132 rows x 1 columns]

# %% [markdown]
# # Both but sliced

# %% [markdown]
# Add items in experts and newcomers labels to an empty list.

# %%
List_Labels_Expert_Newcomers = []
for i in range(len(df_labels_experts_newcomers)):
    List_Labels_Expert_Newcomers.append(df_labels_experts_newcomers['Labels'][i])

# %% [markdown]
# This code is for querrying the datasets according list of labels of experts and newcomers

# %%
df2_expert_newcomers_labels = df2[df2['labels'].str.contains('|'.join(List_Labels_Expert_Newcomers))]

# %% [markdown]
# Show data expert and newcomers labels

# %%
pd.DataFrame(df2_expert_newcomers_labels['labels'])
# Out:
#                                                  labels
# 9     [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 14    [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 25    [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 26    [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 47    [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# ...                                                 ...
# 4474  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4477  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4521  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4582  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4623  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
#
# [590 rows x 1 columns]

# %% [markdown]
# # Both combined

# %% [markdown]
# combine label newcomers and experts

# %%
df2_expert_newcomers_labels_combined = df2_newcomers_labels.append(df2_expert_labels)

# %%
pd.DataFrame(df2_expert_newcomers_labels_combined['labels'])
# Out:
#                                                  labels
# 387   [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 893   [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 1438  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 1439  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# 1447  [{'id': 170296925, 'node_id': 'MDU6TGFiZWwxNzA...
# ...                                                 ...
# 4228  [{'id': 357932495, 'node_id': 'MDU6TGFiZWwzNTc...
# 4302  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4361  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4384  [{'id': 32876, 'node_id': 'MDU6TGFiZWwzMjg3Ng=...
# 4475  [{'id': 125213303, 'node_id': 'MDU6TGFiZWwxMjU...
#
# [168 rows x 1 columns]

# %% [markdown]
# # Newcomers, Expert and both Dataset

# %% [markdown]
# Make 3 dataset csv file that is newcomers dataset, expert dataset and both

# %% [markdown]
# ## Newcomers

# %% [markdown]
# Make dataset csv according newcomers labels

# %%
df2_newcomers_labels.to_csv("data_newcomers.csv", index=False)

# %% [markdown]
# Read the dataset according newcomers labels

# %%
data_newcomers = pd.read_csv("data_newcomers.csv")
data_newcomers
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pallets/flask/iss...
# 1   https://api.github.com/repos/pallets/flask/iss...
# 2   https://api.github.com/repos/pallets/flask/iss...
# 3   https://api.github.com/repos/pallets/flask/iss...
# 4   https://api.github.com/repos/pallets/flask/iss...
# 5   https://api.github.com/repos/pallets/flask/iss...
# 6   https://api.github.com/repos/pallets/flask/iss...
# 7   https://api.github.com/repos/pallets/flask/iss...
# 8   https://api.github.com/repos/pallets/flask/iss...
# 9   https://api.github.com/repos/pallets/flask/iss...
# 10  https://api.github.com/repos/pallets/flask/iss...
# 11  https://api.github.com/repos/pallets/flask/iss...
# 12  https://api.github.com/repos/pallets/flask/iss...
# 13  https://api.github.com/repos/pallets/flask/iss...
# 14  https://api.github.com/repos/pallets/flask/iss...
# 15  https://api.github.com/repos/pallets/flask/iss...
# 16  https://api.github.com/repos/pallets/flask/iss...
# 17  https://api.github.com/repos/pallets/flask/iss...
# 18  https://api.github.com/repos/pallets/flask/iss...
# 19  https://api.github.com/repos/pallets/flask/iss...
# 20  https://api.github.com/repos/pallets/flask/iss...
# 21  https://api.github.com/repos/pallets/flask/iss...
# 22  https://api.github.com/repos/pallets/flask/iss...
# 23  https://api.github.com/repos/pallets/flask/iss...
# 24  https://api.github.com/repos/pallets/flask/iss...
# 25  https://api.github.com/repos/pallets/flask/iss...
# 26  https://api.github.com/repos/pallets/flask/iss...
# 27  https://api.github.com/repos/pallets/flask/iss...
# 28  https://api.github.com/repos/pallets/flask/iss...
# 29  https://api.github.com/repos/pallets/flask/iss...
# 30  https://api.github.com/repos/pallets/flask/iss...
# 31  https://api.github.com/repos/pallets/flask/iss...
# 32  https://api.github.com/repos/pallets/flask/iss...
# 33  https://api.github.com/repos/pallets/flask/iss...
# 34  https://api.github.com/repos/pallets/flask/iss...
# 35  https://api.github.com/repos/pallets/flask/iss...
#
#                                 repository_url  \
# 0   https://api.github.com/repos/pallets/flask
# 1   https://api.github.com/repos/pallets/flask
# 2   https://api.github.com/repos/pallets/flask
# 3   https://api.github.com/repos/pallets/flask
# 4   https://api.github.com/repos/pallets/flask
# 5   https://api.github.com/repos/pallets/flask
# 6   https://api.github.com/repos/pallets/flask
# 7   https://api.github.com/repos/pallets/flask
# 8   https://api.github.com/repos/pallets/flask
# 9   https://api.github.com/repos/pallets/flask
# 10  https://api.github.com/repos/pallets/flask
# 11  https://api.github.com/repos/pallets/flask
# 12  https://api.github.com/repos/pallets/flask
# 13  https://api.github.com/repos/pallets/flask
# 14  https://api.github.com/repos/pallets/flask
# 15  https://api.github.com/repos/pallets/flask
# 16  https://api.github.com/repos/pallets/flask
# 17  https://api.github.com/repos/pallets/flask
# 18  https://api.github.com/repos/pallets/flask
# 19  https://api.github.com/repos/pallets/flask
# 20  https://api.github.com/repos/pallets/flask
# 21  https://api.github.com/repos/pallets/flask
# 22  https://api.github.com/repos/pallets/flask
# 23  https://api.github.com/repos/pallets/flask
# 24  https://api.github.com/repos/pallets/flask
# 25  https://api.github.com/repos/pallets/flask
# 26  https://api.github.com/repos/pallets/flask
# 27  https://api.github.com/repos/pallets/flask
# 28  https://api.github.com/repos/pallets/flask
# 29  https://api.github.com/repos/pallets/flask
# 30  https://api.github.com/repos/pallets/flask
# 31  https://api.github.com/repos/pallets/flask
# 32  https://api.github.com/repos/pallets/flask
# 33  https://api.github.com/repos/pallets/flask
# 34  https://api.github.com/repos/pallets/flask
# 35  https://api.github.com/repos/pallets/flask
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pallets/flask/iss...
# 1   https://api.github.com/repos/pallets/flask/iss...
# 2   https://api.github.com/repos/pallets/flask/iss...
# 3   https://api.github.com/repos/pallets/flask/iss...
# 4   https://api.github.com/repos/pallets/flask/iss...
# 5   https://api.github.com/repos/pallets/flask/iss...
# 6   https://api.github.com/repos/pallets/flask/iss...
# 7   https://api.github.com/repos/pallets/flask/iss...
# 8   https://api.github.com/repos/pallets/flask/iss...
# 9   https://api.github.com/repos/pallets/flask/iss...
# 10  https://api.github.com/repos/pallets/flask/iss...
# 11  https://api.github.com/repos/pallets/flask/iss...
# 12  https://api.github.com/repos/pallets/flask/iss...
# 13  https://api.github.com/repos/pallets/flask/iss...
# 14  https://api.github.com/repos/pallets/flask/iss...
# 15  https://api.github.com/repos/pallets/flask/iss...
# 16  https://api.github.com/repos/pallets/flask/iss...
# 17  https://api.github.com/repos/pallets/flask/iss...
# 18  https://api.github.com/repos/pallets/flask/iss...
# 19  https://api.github.com/repos/pallets/flask/iss...
# 20  https://api.github.com/repos/pallets/flask/iss...
# 21  https://api.github.com/repos/pallets/flask/iss...
# 22  https://api.github.com/repos/pallets/flask/iss...
# 23  https://api.github.com/repos/pallets/flask/iss...
# 24  https://api.github.com/repos/pallets/flask/iss...
# 25  https://api.github.com/repos/pallets/flask/iss...
# 26  https://api.github.com/repos/pallets/flask/iss...
# 27  https://api.github.com/repos/pallets/flask/iss...
# 28  https://api.github.com/repos/pallets/flask/iss...
# 29  https://api.github.com/repos/pallets/flask/iss...
# 30  https://api.github.com/repos/pallets/flask/iss...
# 31  https://api.github.com/repos/pallets/flask/iss...
# 32  https://api.github.com/repos/pallets/flask/iss...
# 33  https://api.github.com/repos/pallets/flask/iss...
# 34  https://api.github.com/repos/pallets/flask/iss...
# 35  https://api.github.com/repos/pallets/flask/iss...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pallets/flask/iss...
# 1   https://api.github.com/repos/pallets/flask/iss...
# 2   https://api.github.com/repos/pallets/flask/iss...
# 3   https://api.github.com/repos/pallets/flask/iss...
# 4   https://api.github.com/repos/pallets/flask/iss...
# 5   https://api.github.com/repos/pallets/flask/iss...
# 6   https://api.github.com/repos/pallets/flask/iss...
# 7   https://api.github.com/repos/pallets/flask/iss...
# 8   https://api.github.com/repos/pallets/flask/iss...
# 9   https://api.github.com/repos/pallets/flask/iss...
# 10  https://api.github.com/repos/pallets/flask/iss...
# 11  https://api.github.com/repos/pallets/flask/iss...
# 12  https://api.github.com/repos/pallets/flask/iss...
# 13  https://api.github.com/repos/pallets/flask/iss...
# 14  https://api.github.com/repos/pallets/flask/iss...
# 15  https://api.github.com/repos/pallets/flask/iss...
# 16  https://api.github.com/repos/pallets/flask/iss...
# 17  https://api.github.com/repos/pallets/flask/iss...
# 18  https://api.github.com/repos/pallets/flask/iss...
# 19  https://api.github.com/repos/pallets/flask/iss...
# 20  https://api.github.com/repos/pallets/flask/iss...
# 21  https://api.github.com/repos/pallets/flask/iss...
# 22  https://api.github.com/repos/pallets/flask/iss...
# 23  https://api.github.com/repos/pallets/flask/iss...
# 24  https://api.github.com/repos/pallets/flask/iss...
# 25  https://api.github.com/repos/pallets/flask/iss...
# 26  https://api.github.com/repos/pallets/flask/iss...
# 27  https://api.github.com/repos/pallets/flask/iss...
# 28  https://api.github.com/repos/pallets/flask/iss...
# 29  https://api.github.com/repos/pallets/flask/iss...
# 30  https://api.github.com/repos/pallets/flask/iss...
# 31  https://api.github.com/repos/pallets/flask/iss...
# 32  https://api.github.com/repos/pallets/flask/iss...
# 33  https://api.github.com/repos/pallets/flask/iss...
# 34  https://api.github.com/repos/pallets/flask/iss...
# 35  https://api.github.com/repos/pallets/flask/iss...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pallets/flask/iss...
# 1   https://api.github.com/repos/pallets/flask/iss...
# 2   https://api.github.com/repos/pallets/flask/iss...
# 3   https://api.github.com/repos/pallets/flask/iss...
# 4   https://api.github.com/repos/pallets/flask/iss...
# 5   https://api.github.com/repos/pallets/flask/iss...
# 6   https://api.github.com/repos/pallets/flask/iss...
# 7   https://api.github.com/repos/pallets/flask/iss...
# 8   https://api.github.com/repos/pallets/flask/iss...
# 9   https://api.github.com/repos/pallets/flask/iss...
# 10  https://api.github.com/repos/pallets/flask/iss...
# 11  https://api.github.com/repos/pallets/flask/iss...
# 12  https://api.github.com/repos/pallets/flask/iss...
# 13  https://api.github.com/repos/pallets/flask/iss...
# 14  https://api.github.com/repos/pallets/flask/iss...
# 15  https://api.github.com/repos/pallets/flask/iss...
# 16  https://api.github.com/repos/pallets/flask/iss...
# 17  https://api.github.com/repos/pallets/flask/iss...
# 18  https://api.github.com/repos/pallets/flask/iss...
# 19  https://api.github.com/repos/pallets/flask/iss...
# 20  https://api.github.com/repos/pallets/flask/iss...
# 21  https://api.github.com/repos/pallets/flask/iss...
# 22  https://api.github.com/repos/pallets/flask/iss...
# 23  https://api.github.com/repos/pallets/flask/iss...
# 24  https://api.github.com/repos/pallets/flask/iss...
# 25  https://api.github.com/repos/pallets/flask/iss...
# 26  https://api.github.com/repos/pallets/flask/iss...
# 27  https://api.github.com/repos/pallets/flask/iss...
# 28  https://api.github.com/repos/pallets/flask/iss...
# 29  https://api.github.com/repos/pallets/flask/iss...
# 30  https://api.github.com/repos/pallets/flask/iss...
# 31  https://api.github.com/repos/pallets/flask/iss...
# 32  https://api.github.com/repos/pallets/flask/iss...
# 33  https://api.github.com/repos/pallets/flask/iss...
# 34  https://api.github.com/repos/pallets/flask/iss...
# 35  https://api.github.com/repos/pallets/flask/iss...
#
#                                         html_url          id  \
# 0   https://github.com/pallets/flask/issues/4333  1049595014
# 1   https://github.com/pallets/flask/issues/3787   718946947
# 2   https://github.com/pallets/flask/issues/3227   450343888
# 3   https://github.com/pallets/flask/issues/3226   450340069
# 4   https://github.com/pallets/flask/issues/3218   448470200
# 5   https://github.com/pallets/flask/issues/3216   448354370
# 6   https://github.com/pallets/flask/issues/3211   447338595
# 7   https://github.com/pallets/flask/issues/3035   391875785
# 8   https://github.com/pallets/flask/issues/2949   371384627
# 9   https://github.com/pallets/flask/issues/2523   274935512
# 10  https://github.com/pallets/flask/issues/2372   235964788
# 11  https://github.com/pallets/flask/issues/2313   230785340
# 12  https://github.com/pallets/flask/issues/2287   230065905
# 13  https://github.com/pallets/flask/issues/2285   228895440
# 14  https://github.com/pallets/flask/issues/2281   228304950
# 15  https://github.com/pallets/flask/issues/2265   225440697
# 16  https://github.com/pallets/flask/issues/2261   224893351
# 17  https://github.com/pallets/flask/issues/2255   223647063
# 18  https://github.com/pallets/flask/issues/2251   223419442
# 19  https://github.com/pallets/flask/issues/2243   221885630
# 20  https://github.com/pallets/flask/issues/2029   177755555
# 21  https://github.com/pallets/flask/issues/1989   172388812
# 22  https://github.com/pallets/flask/issues/1919   161126295
# 23  https://github.com/pallets/flask/issues/1915   160759442
# 24  https://github.com/pallets/flask/issues/1911   160130813
# 25  https://github.com/pallets/flask/issues/1828   157397409
# 26  https://github.com/pallets/flask/issues/1817   156270277
# 27  https://github.com/pallets/flask/issues/1790   150748774
# 28  https://github.com/pallets/flask/issues/1644   120845274
# 29  https://github.com/pallets/flask/issues/1465    78862672
# 30  https://github.com/pallets/flask/issues/1442    69691676
# 31  https://github.com/pallets/flask/issues/1397    64537532
# 32  https://github.com/pallets/flask/issues/1289    52526455
# 33   https://github.com/pallets/flask/issues/532     5255028
# 34   https://github.com/pallets/flask/issues/434     3613442
# 35   https://github.com/pallets/flask/issues/266     1133381
#
#                      node_id  number  \
# 0         I_kwDOAAkbnM4-j4yG    4333
# 1   MDU6SXNzdWU3MTg5NDY5NDc=    3787
# 2   MDU6SXNzdWU0NTAzNDM4ODg=    3227
# 3   MDU6SXNzdWU0NTAzNDAwNjk=    3226
# 4   MDU6SXNzdWU0NDg0NzAyMDA=    3218
# 5   MDU6SXNzdWU0NDgzNTQzNzA=    3216
# 6   MDU6SXNzdWU0NDczMzg1OTU=    3211
# 7   MDU6SXNzdWUzOTE4NzU3ODU=    3035
# 8   MDU6SXNzdWUzNzEzODQ2Mjc=    2949
# 9   MDU6SXNzdWUyNzQ5MzU1MTI=    2523
# 10  MDU6SXNzdWUyMzU5NjQ3ODg=    2372
# 11  MDU6SXNzdWUyMzA3ODUzNDA=    2313
# 12  MDU6SXNzdWUyMzAwNjU5MDU=    2287
# 13  MDU6SXNzdWUyMjg4OTU0NDA=    2285
# 14  MDU6SXNzdWUyMjgzMDQ5NTA=    2281
# 15  MDU6SXNzdWUyMjU0NDA2OTc=    2265
# 16  MDU6SXNzdWUyMjQ4OTMzNTE=    2261
# 17  MDU6SXNzdWUyMjM2NDcwNjM=    2255
# 18  MDU6SXNzdWUyMjM0MTk0NDI=    2251
# 19  MDU6SXNzdWUyMjE4ODU2MzA=    2243
# 20  MDU6SXNzdWUxNzc3NTU1NTU=    2029
# 21  MDU6SXNzdWUxNzIzODg4MTI=    1989
# 22  MDU6SXNzdWUxNjExMjYyOTU=    1919
# 23  MDU6SXNzdWUxNjA3NTk0NDI=    1915
# 24  MDU6SXNzdWUxNjAxMzA4MTM=    1911
# 25  MDU6SXNzdWUxNTczOTc0MDk=    1828
# 26  MDU6SXNzdWUxNTYyNzAyNzc=    1817
# 27  MDU6SXNzdWUxNTA3NDg3NzQ=    1790
# 28  MDU6SXNzdWUxMjA4NDUyNzQ=    1644
# 29  MDU6SXNzdWU3ODg2MjY3Mg==    1465
# 30  MDU6SXNzdWU2OTY5MTY3Ng==    1442
# 31  MDU6SXNzdWU2NDUzNzUzMg==    1397
# 32  MDU6SXNzdWU1MjUyNjQ1NQ==    1289
# 33      MDU6SXNzdWU1MjU1MDI4     532
# 34      MDU6SXNzdWUzNjEzNDQy     434
# 35      MDU6SXNzdWUxMTMzMzgx     266
#
#                                                 title  ...  \
# 0   `after_this_request` fails with a meaningless ...  ...
# 1   Outdated external link in errorhandling docume...  ...
# 2              suspicious unexplained `except: raise`  ...
# 3        unused import: werkzeug.datastructures:Range  ...
# 4                        Use @property as a decorator  ...
# 5                       Document Blueprint parameters  ...
# 6                            Don't require ssl module  ...
# 7   yum install virtualenv instead of python-virtu...  ...
# 8   Documentation "Testing Flask Applications" sho...  ...
# 9   Missing import statement in "Uploading Files" ...  ...
# 10  JSONEncoder encodes aware datetime objects in ...  ...
# 11      Organize the gevent tests into a single class  ...
# 12        DRY up the test suite using pytest fixtures  ...
# 13                               Review HTTP security  ...
# 14        Document how to set env vars for PowerShell  ...
# 15  Detect `create_app` when FLASK_APP doesn't spe...  ...
# 16  Documentation: Term "development mode" is unclear  ...
# 17  Generating relative url with app context shoul...  ...
# 18  Class-based View should set provide_automatic_...  ...
# 19     Take advantage of Py3.6 json support for bytes  ...
# 20              Zero-padded file modes in repository   ...
# 21  Disable OS-level autocorrect in the interactiv...  ...
# 22         Remove easy_install from installation docs  ...
# 23  Use pip in upgrade documentation instead of ea...  ...
# 24                          Wrong import json library  ...
# 25                            `flask --version` fails  ...
# 26           Unify versionadded markers (0.11 vs 1.0)  ...
# 27  flaskr example seems to loose data on every la...  ...
# 28  Please update mod_wsgi documentation to use ht...  ...
# 29                            packaging docs outdated  ...
# 30         small inaccuracy in get_json documentation  ...
# 31  flask.Request should have an is_static field f...  ...
# 32                         bad content-length default  ...
# 33                Mention Extensions in the Docs more  ...
# 34  sessions documentation (client side vs server ...  ...
# 35    Blueprint template lookup not documented enough  ...
#
#                     closed_at author_association active_lock_reason  \
# 0   2021-12-23 01:49:46+00:00             MEMBER           resolved
# 1   2020-10-12 02:15:27+00:00               NONE           resolved
# 2   2019-05-31 16:56:44+00:00             MEMBER           resolved
# 3   2019-05-31 17:03:17+00:00             MEMBER           resolved
# 4   2019-05-31 17:46:19+00:00             MEMBER           resolved
# 5   2019-06-12 21:04:05+00:00             MEMBER           resolved
# 6   2019-06-01 13:37:56+00:00             MEMBER           resolved
# 7   2019-01-06 18:37:17+00:00               NONE           resolved
# 8   2019-06-01 13:38:34+00:00               NONE           resolved
# 9   2017-11-17 20:05:35+00:00               NONE           resolved
# 10  2017-06-15 01:42:15+00:00               NONE           resolved
# 11  2017-05-24 00:53:22+00:00        CONTRIBUTOR           resolved
# 12  2017-05-23 22:18:40+00:00        CONTRIBUTOR           resolved
# 13  2017-05-27 17:08:18+00:00             MEMBER           resolved
# 14  2017-05-24 00:21:45+00:00             MEMBER           resolved
# 15  2017-05-22 23:16:28+00:00             MEMBER           resolved
# 16  2017-05-22 18:49:13+00:00               NONE           resolved
# 17  2017-04-23 20:44:11+00:00             MEMBER           resolved
# 18  2017-05-23 19:46:44+00:00             MEMBER           resolved
# 19  2017-05-12 14:26:01+00:00             MEMBER           resolved
# 20  2016-10-14 08:13:53+00:00               NONE           resolved
# 21  2016-08-22 23:47:57+00:00        CONTRIBUTOR           resolved
# 22  2016-07-05 19:01:27+00:00        CONTRIBUTOR           resolved
# 23  2016-06-22 20:27:08+00:00               NONE           resolved
# 24  2017-05-22 19:37:58+00:00               NONE           resolved
# 25  2016-06-02 12:24:07+00:00        CONTRIBUTOR           resolved
# 26  2016-05-23 12:43:42+00:00             MEMBER           resolved
# 27  2016-05-13 21:58:50+00:00               NONE           resolved
# 28  2015-12-10 05:09:13+00:00               NONE           resolved
# 29  2015-10-31 21:40:34+00:00        CONTRIBUTOR           resolved
# 30  2015-04-28 07:38:48+00:00               NONE           resolved
# 31  2015-03-30 22:14:53+00:00               NONE           resolved
# 32  2016-12-12 22:03:52+00:00               NONE           resolved
# 33  2017-05-22 22:58:49+00:00        CONTRIBUTOR           resolved
# 34  2016-10-26 18:41:43+00:00        CONTRIBUTOR           resolved
# 35  2016-06-04 06:25:27+00:00             MEMBER           resolved
#
#                                                  body  \
# 0   https://github.com/pallets/flask/blob/9039534e...
# 1   Just a small contribution, in documentation se...
# 2   The following two lines:\r\nhttps://github.com...
# 3   The following line contains an unused import:\...
# 4   A bunch of properties in the codebase are defi...
# 5   `Blueprint` does not have reStructuredText mar...
# 6   Python can be compiled without certain modules...
# 7   ---\r\n\r\n### Expected Behavior\r\n\r\n`yum i...
# 8   The `flask.testing` `FlaskClient` has clean-up...
# 9   ### Expected Behavior\r\n\r\nExamples in the d...
# 10  ``flask.json.JSONEncoder()`` encodes aware dat...
# 11  https://github.com/pallets/flask/blob/c8e56d58...
# 12  The test suite is a bit of a mess as far as ho...
# 13  We should make sure we're providing good, thor...
# 14  PowerShell's syntax is different than CMD's.\r...
# 15  `find_best_app` only looks for `app` and `appl...
# 16  I'm doing some work which requires defining so...
# 17  This is a pattern to generate the url to pass ...
# 18  ~Deprecate in favor of #2249, #1489, #1488, wh...
# 19  [Python 3.6 added support for loading json fro...
# 20  After cloning this repository with git and you...
# 21  If you’re using the interactive debugger in th...
# 22  As pointed out in #1915, http://flask.pocoo.or...
# 23  In the upgrade docs, `easy_install` is listed ...
# 24  [This code](https://github.com/pallets/flask/b...
# 25  The `flask` CLI utility that ships with Flask ...
# 26  There are a few `versionadded::` markers that ...
# 27  Branch: 0.10\nExample - flaskr\nDescription: E...
# 28  This is my own fault as I was looking for othe...
# 29  from here ->  http://flask.pocoo.org/docs/0.10...
# 30  In the documentation for [`get_json`](http://f...
# 31  It would be nice to be able to easily tell sta...
# 32  In werkzeug's WSGIRequestHandler, CONTENT-LENG...
# 33  I had a friend that was going through the quic...
# 34  more explicit docs on client side sessions vs ...
# 35  The new blueprint template lookup scheme where...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pallets/...
# 1   {'url': 'https://api.github.com/repos/pallets/...
# 2   {'url': 'https://api.github.com/repos/pallets/...
# 3   {'url': 'https://api.github.com/repos/pallets/...
# 4   {'url': 'https://api.github.com/repos/pallets/...
# 5   {'url': 'https://api.github.com/repos/pallets/...
# 6   {'url': 'https://api.github.com/repos/pallets/...
# 7   {'url': 'https://api.github.com/repos/pallets/...
# 8   {'url': 'https://api.github.com/repos/pallets/...
# 9   {'url': 'https://api.github.com/repos/pallets/...
# 10  {'url': 'https://api.github.com/repos/pallets/...
# 11  {'url': 'https://api.github.com/repos/pallets/...
# 12  {'url': 'https://api.github.com/repos/pallets/...
# 13  {'url': 'https://api.github.com/repos/pallets/...
# 14  {'url': 'https://api.github.com/repos/pallets/...
# 15  {'url': 'https://api.github.com/repos/pallets/...
# 16  {'url': 'https://api.github.com/repos/pallets/...
# 17  {'url': 'https://api.github.com/repos/pallets/...
# 18  {'url': 'https://api.github.com/repos/pallets/...
# 19  {'url': 'https://api.github.com/repos/pallets/...
# 20  {'url': 'https://api.github.com/repos/pallets/...
# 21  {'url': 'https://api.github.com/repos/pallets/...
# 22  {'url': 'https://api.github.com/repos/pallets/...
# 23  {'url': 'https://api.github.com/repos/pallets/...
# 24  {'url': 'https://api.github.com/repos/pallets/...
# 25  {'url': 'https://api.github.com/repos/pallets/...
# 26  {'url': 'https://api.github.com/repos/pallets/...
# 27  {'url': 'https://api.github.com/repos/pallets/...
# 28  {'url': 'https://api.github.com/repos/pallets/...
# 29  {'url': 'https://api.github.com/repos/pallets/...
# 30  {'url': 'https://api.github.com/repos/pallets/...
# 31  {'url': 'https://api.github.com/repos/pallets/...
# 32  {'url': 'https://api.github.com/repos/pallets/...
# 33  {'url': 'https://api.github.com/repos/pallets/...
# 34  {'url': 'https://api.github.com/repos/pallets/...
# 35  {'url': 'https://api.github.com/repos/pallets/...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pallets/flask/iss...
# 1   https://api.github.com/repos/pallets/flask/iss...
# 2   https://api.github.com/repos/pallets/flask/iss...
# 3   https://api.github.com/repos/pallets/flask/iss...
# 4   https://api.github.com/repos/pallets/flask/iss...
# 5   https://api.github.com/repos/pallets/flask/iss...
# 6   https://api.github.com/repos/pallets/flask/iss...
# 7   https://api.github.com/repos/pallets/flask/iss...
# 8   https://api.github.com/repos/pallets/flask/iss...
# 9   https://api.github.com/repos/pallets/flask/iss...
# 10  https://api.github.com/repos/pallets/flask/iss...
# 11  https://api.github.com/repos/pallets/flask/iss...
# 12  https://api.github.com/repos/pallets/flask/iss...
# 13  https://api.github.com/repos/pallets/flask/iss...
# 14  https://api.github.com/repos/pallets/flask/iss...
# 15  https://api.github.com/repos/pallets/flask/iss...
# 16  https://api.github.com/repos/pallets/flask/iss...
# 17  https://api.github.com/repos/pallets/flask/iss...
# 18  https://api.github.com/repos/pallets/flask/iss...
# 19  https://api.github.com/repos/pallets/flask/iss...
# 20  https://api.github.com/repos/pallets/flask/iss...
# 21  https://api.github.com/repos/pallets/flask/iss...
# 22  https://api.github.com/repos/pallets/flask/iss...
# 23  https://api.github.com/repos/pallets/flask/iss...
# 24  https://api.github.com/repos/pallets/flask/iss...
# 25  https://api.github.com/repos/pallets/flask/iss...
# 26  https://api.github.com/repos/pallets/flask/iss...
# 27  https://api.github.com/repos/pallets/flask/iss...
# 28  https://api.github.com/repos/pallets/flask/iss...
# 29  https://api.github.com/repos/pallets/flask/iss...
# 30  https://api.github.com/repos/pallets/flask/iss...
# 31  https://api.github.com/repos/pallets/flask/iss...
# 32  https://api.github.com/repos/pallets/flask/iss...
# 33  https://api.github.com/repos/pallets/flask/iss...
# 34  https://api.github.com/repos/pallets/flask/iss...
# 35  https://api.github.com/repos/pallets/flask/iss...
#
#    performed_via_github_app  state_reason draft pull_request
# 0                       NaN     completed   NaN          NaN
# 1                       NaN     completed   NaN          NaN
# 2                       NaN     completed   NaN          NaN
# 3                       NaN     completed   NaN          NaN
# 4                       NaN     completed   NaN          NaN
# 5                       NaN     completed   NaN          NaN
# 6                       NaN     completed   NaN          NaN
# 7                       NaN     completed   NaN          NaN
# 8                       NaN     completed   NaN          NaN
# 9                       NaN     completed   NaN          NaN
# 10                      NaN     completed   NaN          NaN
# 11                      NaN     completed   NaN          NaN
# 12                      NaN     completed   NaN          NaN
# 13                      NaN     completed   NaN          NaN
# 14                      NaN     completed   NaN          NaN
# 15                      NaN     completed   NaN          NaN
# 16                      NaN     completed   NaN          NaN
# 17                      NaN     completed   NaN          NaN
# 18                      NaN     completed   NaN          NaN
# 19                      NaN     completed   NaN          NaN
# 20                      NaN     completed   NaN          NaN
# 21                      NaN     completed   NaN          NaN
# 22                      NaN     completed   NaN          NaN
# 23                      NaN     completed   NaN          NaN
# 24                      NaN     completed   NaN          NaN
# 25                      NaN     completed   NaN          NaN
# 26                      NaN     completed   NaN          NaN
# 27                      NaN     completed   NaN          NaN
# 28                      NaN     completed   NaN          NaN
# 29                      NaN     completed   NaN          NaN
# 30                      NaN     completed   NaN          NaN
# 31                      NaN     completed   NaN          NaN
# 32                      NaN     completed   NaN          NaN
# 33                      NaN     completed   NaN          NaN
# 34                      NaN     completed   NaN          NaN
# 35                      NaN     completed   NaN          NaN
#
# [36 rows x 30 columns]

# %% [markdown]
# Took data newcomers which is closed issue

# %%
data_newcomers_closed = data_newcomers[data_newcomers.state == "closed"]

# %% [markdown]
# Show closed data newcomers

# %%
data_newcomers_closed.reset_index(drop=True, inplace=True)
data_newcomers_closed.index += 1 
data_newcomers_closed
# Out:
#                                                   url  \
# 1   https://api.github.com/repos/pallets/flask/iss...
# 2   https://api.github.com/repos/pallets/flask/iss...
# 3   https://api.github.com/repos/pallets/flask/iss...
# 4   https://api.github.com/repos/pallets/flask/iss...
# 5   https://api.github.com/repos/pallets/flask/iss...
# 6   https://api.github.com/repos/pallets/flask/iss...
# 7   https://api.github.com/repos/pallets/flask/iss...
# 8   https://api.github.com/repos/pallets/flask/iss...
# 9   https://api.github.com/repos/pallets/flask/iss...
# 10  https://api.github.com/repos/pallets/flask/iss...
# 11  https://api.github.com/repos/pallets/flask/iss...
# 12  https://api.github.com/repos/pallets/flask/iss...
# 13  https://api.github.com/repos/pallets/flask/iss...
# 14  https://api.github.com/repos/pallets/flask/iss...
# 15  https://api.github.com/repos/pallets/flask/iss...
# 16  https://api.github.com/repos/pallets/flask/iss...
# 17  https://api.github.com/repos/pallets/flask/iss...
# 18  https://api.github.com/repos/pallets/flask/iss...
# 19  https://api.github.com/repos/pallets/flask/iss...
# 20  https://api.github.com/repos/pallets/flask/iss...
# 21  https://api.github.com/repos/pallets/flask/iss...
# 22  https://api.github.com/repos/pallets/flask/iss...
# 23  https://api.github.com/repos/pallets/flask/iss...
# 24  https://api.github.com/repos/pallets/flask/iss...
# 25  https://api.github.com/repos/pallets/flask/iss...
# 26  https://api.github.com/repos/pallets/flask/iss...
# 27  https://api.github.com/repos/pallets/flask/iss...
# 28  https://api.github.com/repos/pallets/flask/iss...
# 29  https://api.github.com/repos/pallets/flask/iss...
# 30  https://api.github.com/repos/pallets/flask/iss...
# 31  https://api.github.com/repos/pallets/flask/iss...
# 32  https://api.github.com/repos/pallets/flask/iss...
# 33  https://api.github.com/repos/pallets/flask/iss...
# 34  https://api.github.com/repos/pallets/flask/iss...
# 35  https://api.github.com/repos/pallets/flask/iss...
# 36  https://api.github.com/repos/pallets/flask/iss...
#
#                                 repository_url  \
# 1   https://api.github.com/repos/pallets/flask
# 2   https://api.github.com/repos/pallets/flask
# 3   https://api.github.com/repos/pallets/flask
# 4   https://api.github.com/repos/pallets/flask
# 5   https://api.github.com/repos/pallets/flask
# 6   https://api.github.com/repos/pallets/flask
# 7   https://api.github.com/repos/pallets/flask
# 8   https://api.github.com/repos/pallets/flask
# 9   https://api.github.com/repos/pallets/flask
# 10  https://api.github.com/repos/pallets/flask
# 11  https://api.github.com/repos/pallets/flask
# 12  https://api.github.com/repos/pallets/flask
# 13  https://api.github.com/repos/pallets/flask
# 14  https://api.github.com/repos/pallets/flask
# 15  https://api.github.com/repos/pallets/flask
# 16  https://api.github.com/repos/pallets/flask
# 17  https://api.github.com/repos/pallets/flask
# 18  https://api.github.com/repos/pallets/flask
# 19  https://api.github.com/repos/pallets/flask
# 20  https://api.github.com/repos/pallets/flask
# 21  https://api.github.com/repos/pallets/flask
# 22  https://api.github.com/repos/pallets/flask
# 23  https://api.github.com/repos/pallets/flask
# 24  https://api.github.com/repos/pallets/flask
# 25  https://api.github.com/repos/pallets/flask
# 26  https://api.github.com/repos/pallets/flask
# 27  https://api.github.com/repos/pallets/flask
# 28  https://api.github.com/repos/pallets/flask
# 29  https://api.github.com/repos/pallets/flask
# 30  https://api.github.com/repos/pallets/flask
# 31  https://api.github.com/repos/pallets/flask
# 32  https://api.github.com/repos/pallets/flask
# 33  https://api.github.com/repos/pallets/flask
# 34  https://api.github.com/repos/pallets/flask
# 35  https://api.github.com/repos/pallets/flask
# 36  https://api.github.com/repos/pallets/flask
#
#                                            labels_url  \
# 1   https://api.github.com/repos/pallets/flask/iss...
# 2   https://api.github.com/repos/pallets/flask/iss...
# 3   https://api.github.com/repos/pallets/flask/iss...
# 4   https://api.github.com/repos/pallets/flask/iss...
# 5   https://api.github.com/repos/pallets/flask/iss...
# 6   https://api.github.com/repos/pallets/flask/iss...
# 7   https://api.github.com/repos/pallets/flask/iss...
# 8   https://api.github.com/repos/pallets/flask/iss...
# 9   https://api.github.com/repos/pallets/flask/iss...
# 10  https://api.github.com/repos/pallets/flask/iss...
# 11  https://api.github.com/repos/pallets/flask/iss...
# 12  https://api.github.com/repos/pallets/flask/iss...
# 13  https://api.github.com/repos/pallets/flask/iss...
# 14  https://api.github.com/repos/pallets/flask/iss...
# 15  https://api.github.com/repos/pallets/flask/iss...
# 16  https://api.github.com/repos/pallets/flask/iss...
# 17  https://api.github.com/repos/pallets/flask/iss...
# 18  https://api.github.com/repos/pallets/flask/iss...
# 19  https://api.github.com/repos/pallets/flask/iss...
# 20  https://api.github.com/repos/pallets/flask/iss...
# 21  https://api.github.com/repos/pallets/flask/iss...
# 22  https://api.github.com/repos/pallets/flask/iss...
# 23  https://api.github.com/repos/pallets/flask/iss...
# 24  https://api.github.com/repos/pallets/flask/iss...
# 25  https://api.github.com/repos/pallets/flask/iss...
# 26  https://api.github.com/repos/pallets/flask/iss...
# 27  https://api.github.com/repos/pallets/flask/iss...
# 28  https://api.github.com/repos/pallets/flask/iss...
# 29  https://api.github.com/repos/pallets/flask/iss...
# 30  https://api.github.com/repos/pallets/flask/iss...
# 31  https://api.github.com/repos/pallets/flask/iss...
# 32  https://api.github.com/repos/pallets/flask/iss...
# 33  https://api.github.com/repos/pallets/flask/iss...
# 34  https://api.github.com/repos/pallets/flask/iss...
# 35  https://api.github.com/repos/pallets/flask/iss...
# 36  https://api.github.com/repos/pallets/flask/iss...
#
#                                          comments_url  \
# 1   https://api.github.com/repos/pallets/flask/iss...
# 2   https://api.github.com/repos/pallets/flask/iss...
# 3   https://api.github.com/repos/pallets/flask/iss...
# 4   https://api.github.com/repos/pallets/flask/iss...
# 5   https://api.github.com/repos/pallets/flask/iss...
# 6   https://api.github.com/repos/pallets/flask/iss...
# 7   https://api.github.com/repos/pallets/flask/iss...
# 8   https://api.github.com/repos/pallets/flask/iss...
# 9   https://api.github.com/repos/pallets/flask/iss...
# 10  https://api.github.com/repos/pallets/flask/iss...
# 11  https://api.github.com/repos/pallets/flask/iss...
# 12  https://api.github.com/repos/pallets/flask/iss...
# 13  https://api.github.com/repos/pallets/flask/iss...
# 14  https://api.github.com/repos/pallets/flask/iss...
# 15  https://api.github.com/repos/pallets/flask/iss...
# 16  https://api.github.com/repos/pallets/flask/iss...
# 17  https://api.github.com/repos/pallets/flask/iss...
# 18  https://api.github.com/repos/pallets/flask/iss...
# 19  https://api.github.com/repos/pallets/flask/iss...
# 20  https://api.github.com/repos/pallets/flask/iss...
# 21  https://api.github.com/repos/pallets/flask/iss...
# 22  https://api.github.com/repos/pallets/flask/iss...
# 23  https://api.github.com/repos/pallets/flask/iss...
# 24  https://api.github.com/repos/pallets/flask/iss...
# 25  https://api.github.com/repos/pallets/flask/iss...
# 26  https://api.github.com/repos/pallets/flask/iss...
# 27  https://api.github.com/repos/pallets/flask/iss...
# 28  https://api.github.com/repos/pallets/flask/iss...
# 29  https://api.github.com/repos/pallets/flask/iss...
# 30  https://api.github.com/repos/pallets/flask/iss...
# 31  https://api.github.com/repos/pallets/flask/iss...
# 32  https://api.github.com/repos/pallets/flask/iss...
# 33  https://api.github.com/repos/pallets/flask/iss...
# 34  https://api.github.com/repos/pallets/flask/iss...
# 35  https://api.github.com/repos/pallets/flask/iss...
# 36  https://api.github.com/repos/pallets/flask/iss...
#
#                                            events_url  \
# 1   https://api.github.com/repos/pallets/flask/iss...
# 2   https://api.github.com/repos/pallets/flask/iss...
# 3   https://api.github.com/repos/pallets/flask/iss...
# 4   https://api.github.com/repos/pallets/flask/iss...
# 5   https://api.github.com/repos/pallets/flask/iss...
# 6   https://api.github.com/repos/pallets/flask/iss...
# 7   https://api.github.com/repos/pallets/flask/iss...
# 8   https://api.github.com/repos/pallets/flask/iss...
# 9   https://api.github.com/repos/pallets/flask/iss...
# 10  https://api.github.com/repos/pallets/flask/iss...
# 11  https://api.github.com/repos/pallets/flask/iss...
# 12  https://api.github.com/repos/pallets/flask/iss...
# 13  https://api.github.com/repos/pallets/flask/iss...
# 14  https://api.github.com/repos/pallets/flask/iss...
# 15  https://api.github.com/repos/pallets/flask/iss...
# 16  https://api.github.com/repos/pallets/flask/iss...
# 17  https://api.github.com/repos/pallets/flask/iss...
# 18  https://api.github.com/repos/pallets/flask/iss...
# 19  https://api.github.com/repos/pallets/flask/iss...
# 20  https://api.github.com/repos/pallets/flask/iss...
# 21  https://api.github.com/repos/pallets/flask/iss...
# 22  https://api.github.com/repos/pallets/flask/iss...
# 23  https://api.github.com/repos/pallets/flask/iss...
# 24  https://api.github.com/repos/pallets/flask/iss...
# 25  https://api.github.com/repos/pallets/flask/iss...
# 26  https://api.github.com/repos/pallets/flask/iss...
# 27  https://api.github.com/repos/pallets/flask/iss...
# 28  https://api.github.com/repos/pallets/flask/iss...
# 29  https://api.github.com/repos/pallets/flask/iss...
# 30  https://api.github.com/repos/pallets/flask/iss...
# 31  https://api.github.com/repos/pallets/flask/iss...
# 32  https://api.github.com/repos/pallets/flask/iss...
# 33  https://api.github.com/repos/pallets/flask/iss...
# 34  https://api.github.com/repos/pallets/flask/iss...
# 35  https://api.github.com/repos/pallets/flask/iss...
# 36  https://api.github.com/repos/pallets/flask/iss...
#
#                                         html_url          id  \
# 1   https://github.com/pallets/flask/issues/4333  1049595014
# 2   https://github.com/pallets/flask/issues/3787   718946947
# 3   https://github.com/pallets/flask/issues/3227   450343888
# 4   https://github.com/pallets/flask/issues/3226   450340069
# 5   https://github.com/pallets/flask/issues/3218   448470200
# 6   https://github.com/pallets/flask/issues/3216   448354370
# 7   https://github.com/pallets/flask/issues/3211   447338595
# 8   https://github.com/pallets/flask/issues/3035   391875785
# 9   https://github.com/pallets/flask/issues/2949   371384627
# 10  https://github.com/pallets/flask/issues/2523   274935512
# 11  https://github.com/pallets/flask/issues/2372   235964788
# 12  https://github.com/pallets/flask/issues/2313   230785340
# 13  https://github.com/pallets/flask/issues/2287   230065905
# 14  https://github.com/pallets/flask/issues/2285   228895440
# 15  https://github.com/pallets/flask/issues/2281   228304950
# 16  https://github.com/pallets/flask/issues/2265   225440697
# 17  https://github.com/pallets/flask/issues/2261   224893351
# 18  https://github.com/pallets/flask/issues/2255   223647063
# 19  https://github.com/pallets/flask/issues/2251   223419442
# 20  https://github.com/pallets/flask/issues/2243   221885630
# 21  https://github.com/pallets/flask/issues/2029   177755555
# 22  https://github.com/pallets/flask/issues/1989   172388812
# 23  https://github.com/pallets/flask/issues/1919   161126295
# 24  https://github.com/pallets/flask/issues/1915   160759442
# 25  https://github.com/pallets/flask/issues/1911   160130813
# 26  https://github.com/pallets/flask/issues/1828   157397409
# 27  https://github.com/pallets/flask/issues/1817   156270277
# 28  https://github.com/pallets/flask/issues/1790   150748774
# 29  https://github.com/pallets/flask/issues/1644   120845274
# 30  https://github.com/pallets/flask/issues/1465    78862672
# 31  https://github.com/pallets/flask/issues/1442    69691676
# 32  https://github.com/pallets/flask/issues/1397    64537532
# 33  https://github.com/pallets/flask/issues/1289    52526455
# 34   https://github.com/pallets/flask/issues/532     5255028
# 35   https://github.com/pallets/flask/issues/434     3613442
# 36   https://github.com/pallets/flask/issues/266     1133381
#
#                      node_id  number  \
# 1         I_kwDOAAkbnM4-j4yG    4333
# 2   MDU6SXNzdWU3MTg5NDY5NDc=    3787
# 3   MDU6SXNzdWU0NTAzNDM4ODg=    3227
# 4   MDU6SXNzdWU0NTAzNDAwNjk=    3226
# 5   MDU6SXNzdWU0NDg0NzAyMDA=    3218
# 6   MDU6SXNzdWU0NDgzNTQzNzA=    3216
# 7   MDU6SXNzdWU0NDczMzg1OTU=    3211
# 8   MDU6SXNzdWUzOTE4NzU3ODU=    3035
# 9   MDU6SXNzdWUzNzEzODQ2Mjc=    2949
# 10  MDU6SXNzdWUyNzQ5MzU1MTI=    2523
# 11  MDU6SXNzdWUyMzU5NjQ3ODg=    2372
# 12  MDU6SXNzdWUyMzA3ODUzNDA=    2313
# 13  MDU6SXNzdWUyMzAwNjU5MDU=    2287
# 14  MDU6SXNzdWUyMjg4OTU0NDA=    2285
# 15  MDU6SXNzdWUyMjgzMDQ5NTA=    2281
# 16  MDU6SXNzdWUyMjU0NDA2OTc=    2265
# 17  MDU6SXNzdWUyMjQ4OTMzNTE=    2261
# 18  MDU6SXNzdWUyMjM2NDcwNjM=    2255
# 19  MDU6SXNzdWUyMjM0MTk0NDI=    2251
# 20  MDU6SXNzdWUyMjE4ODU2MzA=    2243
# 21  MDU6SXNzdWUxNzc3NTU1NTU=    2029
# 22  MDU6SXNzdWUxNzIzODg4MTI=    1989
# 23  MDU6SXNzdWUxNjExMjYyOTU=    1919
# 24  MDU6SXNzdWUxNjA3NTk0NDI=    1915
# 25  MDU6SXNzdWUxNjAxMzA4MTM=    1911
# 26  MDU6SXNzdWUxNTczOTc0MDk=    1828
# 27  MDU6SXNzdWUxNTYyNzAyNzc=    1817
# 28  MDU6SXNzdWUxNTA3NDg3NzQ=    1790
# 29  MDU6SXNzdWUxMjA4NDUyNzQ=    1644
# 30  MDU6SXNzdWU3ODg2MjY3Mg==    1465
# 31  MDU6SXNzdWU2OTY5MTY3Ng==    1442
# 32  MDU6SXNzdWU2NDUzNzUzMg==    1397
# 33  MDU6SXNzdWU1MjUyNjQ1NQ==    1289
# 34      MDU6SXNzdWU1MjU1MDI4     532
# 35      MDU6SXNzdWUzNjEzNDQy     434
# 36      MDU6SXNzdWUxMTMzMzgx     266
#
#                                                 title  ...  \
# 1   `after_this_request` fails with a meaningless ...  ...
# 2   Outdated external link in errorhandling docume...  ...
# 3              suspicious unexplained `except: raise`  ...
# 4        unused import: werkzeug.datastructures:Range  ...
# 5                        Use @property as a decorator  ...
# 6                       Document Blueprint parameters  ...
# 7                            Don't require ssl module  ...
# 8   yum install virtualenv instead of python-virtu...  ...
# 9   Documentation "Testing Flask Applications" sho...  ...
# 10  Missing import statement in "Uploading Files" ...  ...
# 11  JSONEncoder encodes aware datetime objects in ...  ...
# 12      Organize the gevent tests into a single class  ...
# 13        DRY up the test suite using pytest fixtures  ...
# 14                               Review HTTP security  ...
# 15        Document how to set env vars for PowerShell  ...
# 16  Detect `create_app` when FLASK_APP doesn't spe...  ...
# 17  Documentation: Term "development mode" is unclear  ...
# 18  Generating relative url with app context shoul...  ...
# 19  Class-based View should set provide_automatic_...  ...
# 20     Take advantage of Py3.6 json support for bytes  ...
# 21              Zero-padded file modes in repository   ...
# 22  Disable OS-level autocorrect in the interactiv...  ...
# 23         Remove easy_install from installation docs  ...
# 24  Use pip in upgrade documentation instead of ea...  ...
# 25                          Wrong import json library  ...
# 26                            `flask --version` fails  ...
# 27           Unify versionadded markers (0.11 vs 1.0)  ...
# 28  flaskr example seems to loose data on every la...  ...
# 29  Please update mod_wsgi documentation to use ht...  ...
# 30                            packaging docs outdated  ...
# 31         small inaccuracy in get_json documentation  ...
# 32  flask.Request should have an is_static field f...  ...
# 33                         bad content-length default  ...
# 34                Mention Extensions in the Docs more  ...
# 35  sessions documentation (client side vs server ...  ...
# 36    Blueprint template lookup not documented enough  ...
#
#                     closed_at author_association active_lock_reason  \
# 1   2021-12-23 01:49:46+00:00             MEMBER           resolved
# 2   2020-10-12 02:15:27+00:00               NONE           resolved
# 3   2019-05-31 16:56:44+00:00             MEMBER           resolved
# 4   2019-05-31 17:03:17+00:00             MEMBER           resolved
# 5   2019-05-31 17:46:19+00:00             MEMBER           resolved
# 6   2019-06-12 21:04:05+00:00             MEMBER           resolved
# 7   2019-06-01 13:37:56+00:00             MEMBER           resolved
# 8   2019-01-06 18:37:17+00:00               NONE           resolved
# 9   2019-06-01 13:38:34+00:00               NONE           resolved
# 10  2017-11-17 20:05:35+00:00               NONE           resolved
# 11  2017-06-15 01:42:15+00:00               NONE           resolved
# 12  2017-05-24 00:53:22+00:00        CONTRIBUTOR           resolved
# 13  2017-05-23 22:18:40+00:00        CONTRIBUTOR           resolved
# 14  2017-05-27 17:08:18+00:00             MEMBER           resolved
# 15  2017-05-24 00:21:45+00:00             MEMBER           resolved
# 16  2017-05-22 23:16:28+00:00             MEMBER           resolved
# 17  2017-05-22 18:49:13+00:00               NONE           resolved
# 18  2017-04-23 20:44:11+00:00             MEMBER           resolved
# 19  2017-05-23 19:46:44+00:00             MEMBER           resolved
# 20  2017-05-12 14:26:01+00:00             MEMBER           resolved
# 21  2016-10-14 08:13:53+00:00               NONE           resolved
# 22  2016-08-22 23:47:57+00:00        CONTRIBUTOR           resolved
# 23  2016-07-05 19:01:27+00:00        CONTRIBUTOR           resolved
# 24  2016-06-22 20:27:08+00:00               NONE           resolved
# 25  2017-05-22 19:37:58+00:00               NONE           resolved
# 26  2016-06-02 12:24:07+00:00        CONTRIBUTOR           resolved
# 27  2016-05-23 12:43:42+00:00             MEMBER           resolved
# 28  2016-05-13 21:58:50+00:00               NONE           resolved
# 29  2015-12-10 05:09:13+00:00               NONE           resolved
# 30  2015-10-31 21:40:34+00:00        CONTRIBUTOR           resolved
# 31  2015-04-28 07:38:48+00:00               NONE           resolved
# 32  2015-03-30 22:14:53+00:00               NONE           resolved
# 33  2016-12-12 22:03:52+00:00               NONE           resolved
# 34  2017-05-22 22:58:49+00:00        CONTRIBUTOR           resolved
# 35  2016-10-26 18:41:43+00:00        CONTRIBUTOR           resolved
# 36  2016-06-04 06:25:27+00:00             MEMBER           resolved
#
#                                                  body  \
# 1   https://github.com/pallets/flask/blob/9039534e...
# 2   Just a small contribution, in documentation se...
# 3   The following two lines:\r\nhttps://github.com...
# 4   The following line contains an unused import:\...
# 5   A bunch of properties in the codebase are defi...
# 6   `Blueprint` does not have reStructuredText mar...
# 7   Python can be compiled without certain modules...
# 8   ---\r\n\r\n### Expected Behavior\r\n\r\n`yum i...
# 9   The `flask.testing` `FlaskClient` has clean-up...
# 10  ### Expected Behavior\r\n\r\nExamples in the d...
# 11  ``flask.json.JSONEncoder()`` encodes aware dat...
# 12  https://github.com/pallets/flask/blob/c8e56d58...
# 13  The test suite is a bit of a mess as far as ho...
# 14  We should make sure we're providing good, thor...
# 15  PowerShell's syntax is different than CMD's.\r...
# 16  `find_best_app` only looks for `app` and `appl...
# 17  I'm doing some work which requires defining so...
# 18  This is a pattern to generate the url to pass ...
# 19  ~Deprecate in favor of #2249, #1489, #1488, wh...
# 20  [Python 3.6 added support for loading json fro...
# 21  After cloning this repository with git and you...
# 22  If you’re using the interactive debugger in th...
# 23  As pointed out in #1915, http://flask.pocoo.or...
# 24  In the upgrade docs, `easy_install` is listed ...
# 25  [This code](https://github.com/pallets/flask/b...
# 26  The `flask` CLI utility that ships with Flask ...
# 27  There are a few `versionadded::` markers that ...
# 28  Branch: 0.10\nExample - flaskr\nDescription: E...
# 29  This is my own fault as I was looking for othe...
# 30  from here ->  http://flask.pocoo.org/docs/0.10...
# 31  In the documentation for [`get_json`](http://f...
# 32  It would be nice to be able to easily tell sta...
# 33  In werkzeug's WSGIRequestHandler, CONTENT-LENG...
# 34  I had a friend that was going through the quic...
# 35  more explicit docs on client side sessions vs ...
# 36  The new blueprint template lookup scheme where...
#
#                                             reactions  \
# 1   {'url': 'https://api.github.com/repos/pallets/...
# 2   {'url': 'https://api.github.com/repos/pallets/...
# 3   {'url': 'https://api.github.com/repos/pallets/...
# 4   {'url': 'https://api.github.com/repos/pallets/...
# 5   {'url': 'https://api.github.com/repos/pallets/...
# 6   {'url': 'https://api.github.com/repos/pallets/...
# 7   {'url': 'https://api.github.com/repos/pallets/...
# 8   {'url': 'https://api.github.com/repos/pallets/...
# 9   {'url': 'https://api.github.com/repos/pallets/...
# 10  {'url': 'https://api.github.com/repos/pallets/...
# 11  {'url': 'https://api.github.com/repos/pallets/...
# 12  {'url': 'https://api.github.com/repos/pallets/...
# 13  {'url': 'https://api.github.com/repos/pallets/...
# 14  {'url': 'https://api.github.com/repos/pallets/...
# 15  {'url': 'https://api.github.com/repos/pallets/...
# 16  {'url': 'https://api.github.com/repos/pallets/...
# 17  {'url': 'https://api.github.com/repos/pallets/...
# 18  {'url': 'https://api.github.com/repos/pallets/...
# 19  {'url': 'https://api.github.com/repos/pallets/...
# 20  {'url': 'https://api.github.com/repos/pallets/...
# 21  {'url': 'https://api.github.com/repos/pallets/...
# 22  {'url': 'https://api.github.com/repos/pallets/...
# 23  {'url': 'https://api.github.com/repos/pallets/...
# 24  {'url': 'https://api.github.com/repos/pallets/...
# 25  {'url': 'https://api.github.com/repos/pallets/...
# 26  {'url': 'https://api.github.com/repos/pallets/...
# 27  {'url': 'https://api.github.com/repos/pallets/...
# 28  {'url': 'https://api.github.com/repos/pallets/...
# 29  {'url': 'https://api.github.com/repos/pallets/...
# 30  {'url': 'https://api.github.com/repos/pallets/...
# 31  {'url': 'https://api.github.com/repos/pallets/...
# 32  {'url': 'https://api.github.com/repos/pallets/...
# 33  {'url': 'https://api.github.com/repos/pallets/...
# 34  {'url': 'https://api.github.com/repos/pallets/...
# 35  {'url': 'https://api.github.com/repos/pallets/...
# 36  {'url': 'https://api.github.com/repos/pallets/...
#
#                                          timeline_url  \
# 1   https://api.github.com/repos/pallets/flask/iss...
# 2   https://api.github.com/repos/pallets/flask/iss...
# 3   https://api.github.com/repos/pallets/flask/iss...
# 4   https://api.github.com/repos/pallets/flask/iss...
# 5   https://api.github.com/repos/pallets/flask/iss...
# 6   https://api.github.com/repos/pallets/flask/iss...
# 7   https://api.github.com/repos/pallets/flask/iss...
# 8   https://api.github.com/repos/pallets/flask/iss...
# 9   https://api.github.com/repos/pallets/flask/iss...
# 10  https://api.github.com/repos/pallets/flask/iss...
# 11  https://api.github.com/repos/pallets/flask/iss...
# 12  https://api.github.com/repos/pallets/flask/iss...
# 13  https://api.github.com/repos/pallets/flask/iss...
# 14  https://api.github.com/repos/pallets/flask/iss...
# 15  https://api.github.com/repos/pallets/flask/iss...
# 16  https://api.github.com/repos/pallets/flask/iss...
# 17  https://api.github.com/repos/pallets/flask/iss...
# 18  https://api.github.com/repos/pallets/flask/iss...
# 19  https://api.github.com/repos/pallets/flask/iss...
# 20  https://api.github.com/repos/pallets/flask/iss...
# 21  https://api.github.com/repos/pallets/flask/iss...
# 22  https://api.github.com/repos/pallets/flask/iss...
# 23  https://api.github.com/repos/pallets/flask/iss...
# 24  https://api.github.com/repos/pallets/flask/iss...
# 25  https://api.github.com/repos/pallets/flask/iss...
# 26  https://api.github.com/repos/pallets/flask/iss...
# 27  https://api.github.com/repos/pallets/flask/iss...
# 28  https://api.github.com/repos/pallets/flask/iss...
# 29  https://api.github.com/repos/pallets/flask/iss...
# 30  https://api.github.com/repos/pallets/flask/iss...
# 31  https://api.github.com/repos/pallets/flask/iss...
# 32  https://api.github.com/repos/pallets/flask/iss...
# 33  https://api.github.com/repos/pallets/flask/iss...
# 34  https://api.github.com/repos/pallets/flask/iss...
# 35  https://api.github.com/repos/pallets/flask/iss...
# 36  https://api.github.com/repos/pallets/flask/iss...
#
#    performed_via_github_app  state_reason draft pull_request
# 1                       NaN     completed   NaN          NaN
# 2                       NaN     completed   NaN          NaN
# 3                       NaN     completed   NaN          NaN
# 4                       NaN     completed   NaN          NaN
# 5                       NaN     completed   NaN          NaN
# 6                       NaN     completed   NaN          NaN
# 7                       NaN     completed   NaN          NaN
# 8                       NaN     completed   NaN          NaN
# 9                       NaN     completed   NaN          NaN
# 10                      NaN     completed   NaN          NaN
# 11                      NaN     completed   NaN          NaN
# 12                      NaN     completed   NaN          NaN
# 13                      NaN     completed   NaN          NaN
# 14                      NaN     completed   NaN          NaN
# 15                      NaN     completed   NaN          NaN
# 16                      NaN     completed   NaN          NaN
# 17                      NaN     completed   NaN          NaN
# 18                      NaN     completed   NaN          NaN
# 19                      NaN     completed   NaN          NaN
# 20                      NaN     completed   NaN          NaN
# 21                      NaN     completed   NaN          NaN
# 22                      NaN     completed   NaN          NaN
# 23                      NaN     completed   NaN          NaN
# 24                      NaN     completed   NaN          NaN
# 25                      NaN     completed   NaN          NaN
# 26                      NaN     completed   NaN          NaN
# 27                      NaN     completed   NaN          NaN
# 28                      NaN     completed   NaN          NaN
# 29                      NaN     completed   NaN          NaN
# 30                      NaN     completed   NaN          NaN
# 31                      NaN     completed   NaN          NaN
# 32                      NaN     completed   NaN          NaN
# 33                      NaN     completed   NaN          NaN
# 34                      NaN     completed   NaN          NaN
# 35                      NaN     completed   NaN          NaN
# 36                      NaN     completed   NaN          NaN
#
# [36 rows x 30 columns]

# %% [markdown]
# Save the data newcomers

# %%
data_newcomers_closed.to_csv("data_newcomers_closed_index.csv")

# %% [markdown]
# ## Expert

# %% [markdown]
# Make dataset csv according experts labels

# %%
df2_expert_labels.to_csv("data_experts.csv", index=False)

# %% [markdown]
# Read dataset csv according experts labels

# %%
data_experts = pd.read_csv("data_experts.csv")
data_experts
# Out:
#                                                    url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 127  https://api.github.com/repos/pallets/flask/iss...
# 128  https://api.github.com/repos/pallets/flask/iss...
# 129  https://api.github.com/repos/pallets/flask/iss...
# 130  https://api.github.com/repos/pallets/flask/iss...
# 131  https://api.github.com/repos/pallets/flask/iss...
#
#                                  repository_url  \
# 0    https://api.github.com/repos/pallets/flask
# 1    https://api.github.com/repos/pallets/flask
# 2    https://api.github.com/repos/pallets/flask
# 3    https://api.github.com/repos/pallets/flask
# 4    https://api.github.com/repos/pallets/flask
# ..                                          ...
# 127  https://api.github.com/repos/pallets/flask
# 128  https://api.github.com/repos/pallets/flask
# 129  https://api.github.com/repos/pallets/flask
# 130  https://api.github.com/repos/pallets/flask
# 131  https://api.github.com/repos/pallets/flask
#
#                                             labels_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 127  https://api.github.com/repos/pallets/flask/iss...
# 128  https://api.github.com/repos/pallets/flask/iss...
# 129  https://api.github.com/repos/pallets/flask/iss...
# 130  https://api.github.com/repos/pallets/flask/iss...
# 131  https://api.github.com/repos/pallets/flask/iss...
#
#                                           comments_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 127  https://api.github.com/repos/pallets/flask/iss...
# 128  https://api.github.com/repos/pallets/flask/iss...
# 129  https://api.github.com/repos/pallets/flask/iss...
# 130  https://api.github.com/repos/pallets/flask/iss...
# 131  https://api.github.com/repos/pallets/flask/iss...
#
#                                             events_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 127  https://api.github.com/repos/pallets/flask/iss...
# 128  https://api.github.com/repos/pallets/flask/iss...
# 129  https://api.github.com/repos/pallets/flask/iss...
# 130  https://api.github.com/repos/pallets/flask/iss...
# 131  https://api.github.com/repos/pallets/flask/iss...
#
#                                          html_url          id  \
# 0    https://github.com/pallets/flask/issues/4553  1217524246
# 1    https://github.com/pallets/flask/issues/4086   897835929
# 2      https://github.com/pallets/flask/pull/4074   894336512
# 3    https://github.com/pallets/flask/issues/4069   893301608
# 4      https://github.com/pallets/flask/pull/4063   892731375
# ..                                            ...         ...
# 127   https://github.com/pallets/flask/issues/422     3572659
# 128   https://github.com/pallets/flask/issues/348     2177145
# 129   https://github.com/pallets/flask/issues/289     1314399
# 130   https://github.com/pallets/flask/issues/266     1133381
# 131   https://github.com/pallets/flask/issues/175      607742
#
#                               node_id  number  \
# 0                  I_kwDOAAkbnM5IkfIW    4553
# 1            MDU6SXNzdWU4OTc4MzU5Mjk=    4086
# 2    MDExOlB1bGxSZXF1ZXN0NjQ2NzE1NTAx    4074
# 3            MDU6SXNzdWU4OTMzMDE2MDg=    4069
# 4    MDExOlB1bGxSZXF1ZXN0NjQ1MzU5NjAw    4063
# ..                                ...     ...
# 127              MDU6SXNzdWUzNTcyNjU5     422
# 128              MDU6SXNzdWUyMTc3MTQ1     348
# 129              MDU6SXNzdWUxMzE0Mzk5     289
# 130              MDU6SXNzdWUxMTMzMzgx     266
# 131              MDU6SXNzdWU2MDc3NDI=     175
#
#                                                  title  ...  \
# 0    asserts with `pytest.raises` should be outside...  ...
# 1    Registering a blueprint does not update the ur...  ...
# 2    blueprints are registered with nested names, c...  ...
# 3    Nested blueprint should be able to have same name  ...
# 4                                               Bp fix  ...
# ..                                                 ...  ...
# 127  Allow specifying request_class on a per-bluepr...  ...
# 128  Static files only work for blueprints register...  ...
# 129           Blueprints and Extensions and SQLAlchemy  ...
# 130    Blueprint template lookup not documented enough  ...
# 131          Error Handlers versus Werkzeug Exceptions  ...
#
#                      closed_at author_association active_lock_reason  \
# 0    2022-04-28 16:35:56+00:00               NONE           resolved
# 1    2021-05-21 12:09:50+00:00               NONE           resolved
# 2    2021-05-21 14:09:02+00:00             MEMBER           resolved
# 3    2021-05-21 14:14:51+00:00               NONE           resolved
# 4    2021-05-17 14:56:20+00:00             MEMBER           resolved
# ..                         ...                ...                ...
# 127  2017-06-02 18:40:05+00:00        CONTRIBUTOR           resolved
# 128  2018-04-09 08:27:26+00:00               NONE           resolved
# 129  2022-06-28 23:38:15+00:00             MEMBER           resolved
# 130  2016-06-04 06:25:27+00:00             MEMBER           resolved
# 131  2017-04-26 06:14:51+00:00             MEMBER           resolved
#
#                                                   body  \
# 0    I've been using Flask's test suite to evaluate...
# 1    When setting `url_prefix` in `app.register_blu...
# 2    - Blueprints are registered with the full nest...
# 3    <!--\r\nDescribe how to replicate the bug.\r\n...
# 4    Note for the Changelog the existing entry will...
# ..                                                 ...
# 127  Suppose we have a situation in which a user cr...
# 128  The option `static_folder` for blueprints only...
# 129  We do not encourage people to create more than...
# 130  The new blueprint template lookup scheme where...
# 131  Currently you can only declare error handler f...
#
#                                              reactions  \
# 0    {'url': 'https://api.github.com/repos/pallets/...
# 1    {'url': 'https://api.github.com/repos/pallets/...
# 2    {'url': 'https://api.github.com/repos/pallets/...
# 3    {'url': 'https://api.github.com/repos/pallets/...
# 4    {'url': 'https://api.github.com/repos/pallets/...
# ..                                                 ...
# 127  {'url': 'https://api.github.com/repos/pallets/...
# 128  {'url': 'https://api.github.com/repos/pallets/...
# 129  {'url': 'https://api.github.com/repos/pallets/...
# 130  {'url': 'https://api.github.com/repos/pallets/...
# 131  {'url': 'https://api.github.com/repos/pallets/...
#
#                                           timeline_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 127  https://api.github.com/repos/pallets/flask/iss...
# 128  https://api.github.com/repos/pallets/flask/iss...
# 129  https://api.github.com/repos/pallets/flask/iss...
# 130  https://api.github.com/repos/pallets/flask/iss...
# 131  https://api.github.com/repos/pallets/flask/iss...
#
#     performed_via_github_app  state_reason draft  \
# 0                        NaN     completed   NaN
# 1                        NaN     completed   NaN
# 2                        NaN           NaN   0.0
# 3                        NaN     completed   NaN
# 4                        NaN           NaN   0.0
# ..                       ...           ...   ...
# 127                      NaN     completed   NaN
# 128                      NaN     completed   NaN
# 129                      NaN     completed   NaN
# 130                      NaN     completed   NaN
# 131                      NaN     completed   NaN
#
#                                           pull_request
# 0                                                  NaN
# 1                                                  NaN
# 2    {'url': 'https://api.github.com/repos/pallets/...
# 3                                                  NaN
# 4    {'url': 'https://api.github.com/repos/pallets/...
# ..                                                 ...
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
#
# [132 rows x 30 columns]

# %% [markdown]
# Took data experts which is closed issue

# %%
data_experts_closed = data_experts[data_experts.state == "closed"]

# %% [markdown]
# Show closed data experts

# %%
data_experts_closed.reset_index(drop=True, inplace=True)
data_experts_closed.index += 1 
data_experts_closed
# Out:
#                                                    url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 128  https://api.github.com/repos/pallets/flask/iss...
# 129  https://api.github.com/repos/pallets/flask/iss...
# 130  https://api.github.com/repos/pallets/flask/iss...
# 131  https://api.github.com/repos/pallets/flask/iss...
# 132  https://api.github.com/repos/pallets/flask/iss...
#
#                                  repository_url  \
# 1    https://api.github.com/repos/pallets/flask
# 2    https://api.github.com/repos/pallets/flask
# 3    https://api.github.com/repos/pallets/flask
# 4    https://api.github.com/repos/pallets/flask
# 5    https://api.github.com/repos/pallets/flask
# ..                                          ...
# 128  https://api.github.com/repos/pallets/flask
# 129  https://api.github.com/repos/pallets/flask
# 130  https://api.github.com/repos/pallets/flask
# 131  https://api.github.com/repos/pallets/flask
# 132  https://api.github.com/repos/pallets/flask
#
#                                             labels_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 128  https://api.github.com/repos/pallets/flask/iss...
# 129  https://api.github.com/repos/pallets/flask/iss...
# 130  https://api.github.com/repos/pallets/flask/iss...
# 131  https://api.github.com/repos/pallets/flask/iss...
# 132  https://api.github.com/repos/pallets/flask/iss...
#
#                                           comments_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 128  https://api.github.com/repos/pallets/flask/iss...
# 129  https://api.github.com/repos/pallets/flask/iss...
# 130  https://api.github.com/repos/pallets/flask/iss...
# 131  https://api.github.com/repos/pallets/flask/iss...
# 132  https://api.github.com/repos/pallets/flask/iss...
#
#                                             events_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 128  https://api.github.com/repos/pallets/flask/iss...
# 129  https://api.github.com/repos/pallets/flask/iss...
# 130  https://api.github.com/repos/pallets/flask/iss...
# 131  https://api.github.com/repos/pallets/flask/iss...
# 132  https://api.github.com/repos/pallets/flask/iss...
#
#                                          html_url          id  \
# 1    https://github.com/pallets/flask/issues/4553  1217524246
# 2    https://github.com/pallets/flask/issues/4086   897835929
# 3      https://github.com/pallets/flask/pull/4074   894336512
# 4    https://github.com/pallets/flask/issues/4069   893301608
# 5      https://github.com/pallets/flask/pull/4063   892731375
# ..                                            ...         ...
# 128   https://github.com/pallets/flask/issues/422     3572659
# 129   https://github.com/pallets/flask/issues/348     2177145
# 130   https://github.com/pallets/flask/issues/289     1314399
# 131   https://github.com/pallets/flask/issues/266     1133381
# 132   https://github.com/pallets/flask/issues/175      607742
#
#                               node_id  number  \
# 1                  I_kwDOAAkbnM5IkfIW    4553
# 2            MDU6SXNzdWU4OTc4MzU5Mjk=    4086
# 3    MDExOlB1bGxSZXF1ZXN0NjQ2NzE1NTAx    4074
# 4            MDU6SXNzdWU4OTMzMDE2MDg=    4069
# 5    MDExOlB1bGxSZXF1ZXN0NjQ1MzU5NjAw    4063
# ..                                ...     ...
# 128              MDU6SXNzdWUzNTcyNjU5     422
# 129              MDU6SXNzdWUyMTc3MTQ1     348
# 130              MDU6SXNzdWUxMzE0Mzk5     289
# 131              MDU6SXNzdWUxMTMzMzgx     266
# 132              MDU6SXNzdWU2MDc3NDI=     175
#
#                                                  title  ...  \
# 1    asserts with `pytest.raises` should be outside...  ...
# 2    Registering a blueprint does not update the ur...  ...
# 3    blueprints are registered with nested names, c...  ...
# 4    Nested blueprint should be able to have same name  ...
# 5                                               Bp fix  ...
# ..                                                 ...  ...
# 128  Allow specifying request_class on a per-bluepr...  ...
# 129  Static files only work for blueprints register...  ...
# 130           Blueprints and Extensions and SQLAlchemy  ...
# 131    Blueprint template lookup not documented enough  ...
# 132          Error Handlers versus Werkzeug Exceptions  ...
#
#                      closed_at author_association active_lock_reason  \
# 1    2022-04-28 16:35:56+00:00               NONE           resolved
# 2    2021-05-21 12:09:50+00:00               NONE           resolved
# 3    2021-05-21 14:09:02+00:00             MEMBER           resolved
# 4    2021-05-21 14:14:51+00:00               NONE           resolved
# 5    2021-05-17 14:56:20+00:00             MEMBER           resolved
# ..                         ...                ...                ...
# 128  2017-06-02 18:40:05+00:00        CONTRIBUTOR           resolved
# 129  2018-04-09 08:27:26+00:00               NONE           resolved
# 130  2022-06-28 23:38:15+00:00             MEMBER           resolved
# 131  2016-06-04 06:25:27+00:00             MEMBER           resolved
# 132  2017-04-26 06:14:51+00:00             MEMBER           resolved
#
#                                                   body  \
# 1    I've been using Flask's test suite to evaluate...
# 2    When setting `url_prefix` in `app.register_blu...
# 3    - Blueprints are registered with the full nest...
# 4    <!--\r\nDescribe how to replicate the bug.\r\n...
# 5    Note for the Changelog the existing entry will...
# ..                                                 ...
# 128  Suppose we have a situation in which a user cr...
# 129  The option `static_folder` for blueprints only...
# 130  We do not encourage people to create more than...
# 131  The new blueprint template lookup scheme where...
# 132  Currently you can only declare error handler f...
#
#                                              reactions  \
# 1    {'url': 'https://api.github.com/repos/pallets/...
# 2    {'url': 'https://api.github.com/repos/pallets/...
# 3    {'url': 'https://api.github.com/repos/pallets/...
# 4    {'url': 'https://api.github.com/repos/pallets/...
# 5    {'url': 'https://api.github.com/repos/pallets/...
# ..                                                 ...
# 128  {'url': 'https://api.github.com/repos/pallets/...
# 129  {'url': 'https://api.github.com/repos/pallets/...
# 130  {'url': 'https://api.github.com/repos/pallets/...
# 131  {'url': 'https://api.github.com/repos/pallets/...
# 132  {'url': 'https://api.github.com/repos/pallets/...
#
#                                           timeline_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 128  https://api.github.com/repos/pallets/flask/iss...
# 129  https://api.github.com/repos/pallets/flask/iss...
# 130  https://api.github.com/repos/pallets/flask/iss...
# 131  https://api.github.com/repos/pallets/flask/iss...
# 132  https://api.github.com/repos/pallets/flask/iss...
#
#     performed_via_github_app  state_reason draft  \
# 1                        NaN     completed   NaN
# 2                        NaN     completed   NaN
# 3                        NaN           NaN   0.0
# 4                        NaN     completed   NaN
# 5                        NaN           NaN   0.0
# ..                       ...           ...   ...
# 128                      NaN     completed   NaN
# 129                      NaN     completed   NaN
# 130                      NaN     completed   NaN
# 131                      NaN     completed   NaN
# 132                      NaN     completed   NaN
#
#                                           pull_request
# 1                                                  NaN
# 2                                                  NaN
# 3    {'url': 'https://api.github.com/repos/pallets/...
# 4                                                  NaN
# 5    {'url': 'https://api.github.com/repos/pallets/...
# ..                                                 ...
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
# [132 rows x 30 columns]

# %% [markdown]
# Save the data experts

# %%
data_experts_closed.to_csv("data_experts_closed_index.csv")

# %% [markdown]
# ## Both

# %% [markdown]
# Make dataset csv according experts and newcomers labels

# %%
df2_expert_newcomers_labels.to_csv("data_expert_newcomers.csv", index=False)

# %% [markdown]
# Read dataset csv according experts and newcomers labels

# %%
data_expert_newcomers = pd.read_csv("data_expert_newcomers.csv")
data_expert_newcomers
# Out:
#                                                    url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 585  https://api.github.com/repos/pallets/flask/iss...
# 586  https://api.github.com/repos/pallets/flask/iss...
# 587  https://api.github.com/repos/pallets/flask/iss...
# 588  https://api.github.com/repos/pallets/flask/iss...
# 589  https://api.github.com/repos/pallets/flask/iss...
#
#                                  repository_url  \
# 0    https://api.github.com/repos/pallets/flask
# 1    https://api.github.com/repos/pallets/flask
# 2    https://api.github.com/repos/pallets/flask
# 3    https://api.github.com/repos/pallets/flask
# 4    https://api.github.com/repos/pallets/flask
# ..                                          ...
# 585  https://api.github.com/repos/pallets/flask
# 586  https://api.github.com/repos/pallets/flask
# 587  https://api.github.com/repos/pallets/flask
# 588  https://api.github.com/repos/pallets/flask
# 589  https://api.github.com/repos/pallets/flask
#
#                                             labels_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 585  https://api.github.com/repos/pallets/flask/iss...
# 586  https://api.github.com/repos/pallets/flask/iss...
# 587  https://api.github.com/repos/pallets/flask/iss...
# 588  https://api.github.com/repos/pallets/flask/iss...
# 589  https://api.github.com/repos/pallets/flask/iss...
#
#                                           comments_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 585  https://api.github.com/repos/pallets/flask/iss...
# 586  https://api.github.com/repos/pallets/flask/iss...
# 587  https://api.github.com/repos/pallets/flask/iss...
# 588  https://api.github.com/repos/pallets/flask/iss...
# 589  https://api.github.com/repos/pallets/flask/iss...
#
#                                             events_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 585  https://api.github.com/repos/pallets/flask/iss...
# 586  https://api.github.com/repos/pallets/flask/iss...
# 587  https://api.github.com/repos/pallets/flask/iss...
# 588  https://api.github.com/repos/pallets/flask/iss...
# 589  https://api.github.com/repos/pallets/flask/iss...
#
#                                          html_url          id  \
# 0    https://github.com/pallets/flask/issues/4791  1354294387
# 1      https://github.com/pallets/flask/pull/4783  1346644659
# 2      https://github.com/pallets/flask/pull/4772  1341992402
# 3    https://github.com/pallets/flask/issues/4771  1341992063
# 4      https://github.com/pallets/flask/pull/4748  1330245442
# ..                                            ...         ...
# 585   https://github.com/pallets/flask/issues/176      607792
# 586   https://github.com/pallets/flask/issues/173      607724
# 587   https://github.com/pallets/flask/issues/129      376878
# 588    https://github.com/pallets/flask/issues/68      227393
# 589    https://github.com/pallets/flask/issues/27      186287
#
#                   node_id  number  \
# 0      I_kwDOAAkbnM5QuORz    4791
# 1     PR_kwDOAAkbnM49kwS7    4783
# 2     PR_kwDOAAkbnM49Ve8p    4772
# 3      I_kwDOAAkbnM5P_Sx_    4771
# 4     PR_kwDOAAkbnM48vAtk    4748
# ..                    ...     ...
# 585  MDU6SXNzdWU2MDc3OTI=     176
# 586  MDU6SXNzdWU2MDc3MjQ=     173
# 587  MDU6SXNzdWUzNzY4Nzg=     129
# 588  MDU6SXNzdWUyMjczOTM=      68
# 589  MDU6SXNzdWUxODYyODc=      27
#
#                                                  title  ...  \
# 0    Link to example project in tutorial is dead (l...  ...
# 1                      fix: remove obsolete `zip_safe`  ...
# 2                     correct `waitress-serve` command  ...
# 3                        waitress command doesn't work  ...
# 4                          refactor or remove old docs  ...
# ..                                                 ...  ...
# 585                      Example Application too Basic  ...
# 586  Documentation needs to explain Circular Depend...  ...
# 587                     Thoughts about the fabric docs  ...
# 588            Example App based on Flask + Extensions  ...
# 589                                  Document setup.py  ...
#
#                      closed_at author_association active_lock_reason  \
# 0    2022-09-02 15:57:45+00:00               NONE                NaN
# 1    2022-08-22 16:05:53+00:00        CONTRIBUTOR                NaN
# 2    2022-08-17 16:24:58+00:00        CONTRIBUTOR           resolved
# 3    2022-08-17 16:25:06+00:00        CONTRIBUTOR           resolved
# 4    2022-08-05 18:28:23+00:00             MEMBER           resolved
# ..                         ...                ...                ...
# 585  2015-11-03 14:39:22+00:00             MEMBER           resolved
# 586  2016-06-03 22:19:13+00:00             MEMBER           resolved
# 587  2016-06-05 20:13:59+00:00        CONTRIBUTOR           resolved
# 588  2014-09-29 12:03:03+00:00             MEMBER           resolved
# 589  2010-05-16 23:59:55+00:00             MEMBER           resolved
#
#                                                   body  \
# 0    From docs page : https://flask.palletsprojects...
# 1    X-Ref: #4782\r\n\r\nThe only other `zip_safe` ...
# 2    Fix the `waitress-serve` command on the docs.\...
# 3    The `waitress-serve` command in the documentat...
# 4    * HTML FAQ was pretty outdated, and not partic...
# ..                                                 ...
# 585  There should be a larger tutorial that not onl...
# 586  Currently the documentation does not explain w...
# 587  Maybe use of one of these should be suggested:...
# 588  It would be nice to see an example application...
# 589  Documentation should show how a typical setup....
#
#                                              reactions  \
# 0    {'url': 'https://api.github.com/repos/pallets/...
# 1    {'url': 'https://api.github.com/repos/pallets/...
# 2    {'url': 'https://api.github.com/repos/pallets/...
# 3    {'url': 'https://api.github.com/repos/pallets/...
# 4    {'url': 'https://api.github.com/repos/pallets/...
# ..                                                 ...
# 585  {'url': 'https://api.github.com/repos/pallets/...
# 586  {'url': 'https://api.github.com/repos/pallets/...
# 587  {'url': 'https://api.github.com/repos/pallets/...
# 588  {'url': 'https://api.github.com/repos/pallets/...
# 589  {'url': 'https://api.github.com/repos/pallets/...
#
#                                           timeline_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 585  https://api.github.com/repos/pallets/flask/iss...
# 586  https://api.github.com/repos/pallets/flask/iss...
# 587  https://api.github.com/repos/pallets/flask/iss...
# 588  https://api.github.com/repos/pallets/flask/iss...
# 589  https://api.github.com/repos/pallets/flask/iss...
#
#     performed_via_github_app  state_reason draft  \
# 0                        NaN     completed   NaN
# 1                        NaN           NaN   0.0
# 2                        NaN           NaN   0.0
# 3                        NaN     completed   NaN
# 4                        NaN           NaN   0.0
# ..                       ...           ...   ...
# 585                      NaN     completed   NaN
# 586                      NaN     completed   NaN
# 587                      NaN     completed   NaN
# 588                      NaN     completed   NaN
# 589                      NaN     completed   NaN
#
#                                           pull_request
# 0                                                  NaN
# 1    {'url': 'https://api.github.com/repos/pallets/...
# 2    {'url': 'https://api.github.com/repos/pallets/...
# 3                                                  NaN
# 4    {'url': 'https://api.github.com/repos/pallets/...
# ..                                                 ...
# 585                                                NaN
# 586                                                NaN
# 587                                                NaN
# 588                                                NaN
# 589                                                NaN
#
# [590 rows x 30 columns]

# %% [markdown]
# Took data newcomers and experts which is closed issue

# %%
data_expert_newcomers_closed = data_expert_newcomers[data_expert_newcomers.state == "closed"]

# %% [markdown]
# Show closed data newcomers and experts

# %%
data_expert_newcomers_closed.reset_index(drop=True, inplace=True)
data_expert_newcomers_closed.index += 1 
data_expert_newcomers_closed
# Out:
#                                                    url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 586  https://api.github.com/repos/pallets/flask/iss...
# 587  https://api.github.com/repos/pallets/flask/iss...
# 588  https://api.github.com/repos/pallets/flask/iss...
# 589  https://api.github.com/repos/pallets/flask/iss...
# 590  https://api.github.com/repos/pallets/flask/iss...
#
#                                  repository_url  \
# 1    https://api.github.com/repos/pallets/flask
# 2    https://api.github.com/repos/pallets/flask
# 3    https://api.github.com/repos/pallets/flask
# 4    https://api.github.com/repos/pallets/flask
# 5    https://api.github.com/repos/pallets/flask
# ..                                          ...
# 586  https://api.github.com/repos/pallets/flask
# 587  https://api.github.com/repos/pallets/flask
# 588  https://api.github.com/repos/pallets/flask
# 589  https://api.github.com/repos/pallets/flask
# 590  https://api.github.com/repos/pallets/flask
#
#                                             labels_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 586  https://api.github.com/repos/pallets/flask/iss...
# 587  https://api.github.com/repos/pallets/flask/iss...
# 588  https://api.github.com/repos/pallets/flask/iss...
# 589  https://api.github.com/repos/pallets/flask/iss...
# 590  https://api.github.com/repos/pallets/flask/iss...
#
#                                           comments_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 586  https://api.github.com/repos/pallets/flask/iss...
# 587  https://api.github.com/repos/pallets/flask/iss...
# 588  https://api.github.com/repos/pallets/flask/iss...
# 589  https://api.github.com/repos/pallets/flask/iss...
# 590  https://api.github.com/repos/pallets/flask/iss...
#
#                                             events_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 586  https://api.github.com/repos/pallets/flask/iss...
# 587  https://api.github.com/repos/pallets/flask/iss...
# 588  https://api.github.com/repos/pallets/flask/iss...
# 589  https://api.github.com/repos/pallets/flask/iss...
# 590  https://api.github.com/repos/pallets/flask/iss...
#
#                                          html_url          id  \
# 1    https://github.com/pallets/flask/issues/4791  1354294387
# 2      https://github.com/pallets/flask/pull/4783  1346644659
# 3      https://github.com/pallets/flask/pull/4772  1341992402
# 4    https://github.com/pallets/flask/issues/4771  1341992063
# 5      https://github.com/pallets/flask/pull/4748  1330245442
# ..                                            ...         ...
# 586   https://github.com/pallets/flask/issues/176      607792
# 587   https://github.com/pallets/flask/issues/173      607724
# 588   https://github.com/pallets/flask/issues/129      376878
# 589    https://github.com/pallets/flask/issues/68      227393
# 590    https://github.com/pallets/flask/issues/27      186287
#
#                   node_id  number  \
# 1      I_kwDOAAkbnM5QuORz    4791
# 2     PR_kwDOAAkbnM49kwS7    4783
# 3     PR_kwDOAAkbnM49Ve8p    4772
# 4      I_kwDOAAkbnM5P_Sx_    4771
# 5     PR_kwDOAAkbnM48vAtk    4748
# ..                    ...     ...
# 586  MDU6SXNzdWU2MDc3OTI=     176
# 587  MDU6SXNzdWU2MDc3MjQ=     173
# 588  MDU6SXNzdWUzNzY4Nzg=     129
# 589  MDU6SXNzdWUyMjczOTM=      68
# 590  MDU6SXNzdWUxODYyODc=      27
#
#                                                  title  ...  \
# 1    Link to example project in tutorial is dead (l...  ...
# 2                      fix: remove obsolete `zip_safe`  ...
# 3                     correct `waitress-serve` command  ...
# 4                        waitress command doesn't work  ...
# 5                          refactor or remove old docs  ...
# ..                                                 ...  ...
# 586                      Example Application too Basic  ...
# 587  Documentation needs to explain Circular Depend...  ...
# 588                     Thoughts about the fabric docs  ...
# 589            Example App based on Flask + Extensions  ...
# 590                                  Document setup.py  ...
#
#                      closed_at author_association active_lock_reason  \
# 1    2022-09-02 15:57:45+00:00               NONE                NaN
# 2    2022-08-22 16:05:53+00:00        CONTRIBUTOR                NaN
# 3    2022-08-17 16:24:58+00:00        CONTRIBUTOR           resolved
# 4    2022-08-17 16:25:06+00:00        CONTRIBUTOR           resolved
# 5    2022-08-05 18:28:23+00:00             MEMBER           resolved
# ..                         ...                ...                ...
# 586  2015-11-03 14:39:22+00:00             MEMBER           resolved
# 587  2016-06-03 22:19:13+00:00             MEMBER           resolved
# 588  2016-06-05 20:13:59+00:00        CONTRIBUTOR           resolved
# 589  2014-09-29 12:03:03+00:00             MEMBER           resolved
# 590  2010-05-16 23:59:55+00:00             MEMBER           resolved
#
#                                                   body  \
# 1    From docs page : https://flask.palletsprojects...
# 2    X-Ref: #4782\r\n\r\nThe only other `zip_safe` ...
# 3    Fix the `waitress-serve` command on the docs.\...
# 4    The `waitress-serve` command in the documentat...
# 5    * HTML FAQ was pretty outdated, and not partic...
# ..                                                 ...
# 586  There should be a larger tutorial that not onl...
# 587  Currently the documentation does not explain w...
# 588  Maybe use of one of these should be suggested:...
# 589  It would be nice to see an example application...
# 590  Documentation should show how a typical setup....
#
#                                              reactions  \
# 1    {'url': 'https://api.github.com/repos/pallets/...
# 2    {'url': 'https://api.github.com/repos/pallets/...
# 3    {'url': 'https://api.github.com/repos/pallets/...
# 4    {'url': 'https://api.github.com/repos/pallets/...
# 5    {'url': 'https://api.github.com/repos/pallets/...
# ..                                                 ...
# 586  {'url': 'https://api.github.com/repos/pallets/...
# 587  {'url': 'https://api.github.com/repos/pallets/...
# 588  {'url': 'https://api.github.com/repos/pallets/...
# 589  {'url': 'https://api.github.com/repos/pallets/...
# 590  {'url': 'https://api.github.com/repos/pallets/...
#
#                                           timeline_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 586  https://api.github.com/repos/pallets/flask/iss...
# 587  https://api.github.com/repos/pallets/flask/iss...
# 588  https://api.github.com/repos/pallets/flask/iss...
# 589  https://api.github.com/repos/pallets/flask/iss...
# 590  https://api.github.com/repos/pallets/flask/iss...
#
#     performed_via_github_app  state_reason draft  \
# 1                        NaN     completed   NaN
# 2                        NaN           NaN   0.0
# 3                        NaN           NaN   0.0
# 4                        NaN     completed   NaN
# 5                        NaN           NaN   0.0
# ..                       ...           ...   ...
# 586                      NaN     completed   NaN
# 587                      NaN     completed   NaN
# 588                      NaN     completed   NaN
# 589                      NaN     completed   NaN
# 590                      NaN     completed   NaN
#
#                                           pull_request
# 1                                                  NaN
# 2    {'url': 'https://api.github.com/repos/pallets/...
# 3    {'url': 'https://api.github.com/repos/pallets/...
# 4                                                  NaN
# 5    {'url': 'https://api.github.com/repos/pallets/...
# ..                                                 ...
# 586                                                NaN
# 587                                                NaN
# 588                                                NaN
# 589                                                NaN
# 590                                                NaN
#
# [590 rows x 30 columns]

# %% [markdown]
# Save the data newcomers and experts

# %%
data_expert_newcomers_closed.to_csv("data_expert_newcomers_closed_index.csv")

# %% [markdown]
# ## Combined

# %% [markdown]
# Make dataset csv according experts and newcomers combined labels

# %%
df2_expert_newcomers_labels_combined.to_csv("data_expert_newcomers_combined.csv", index=False)

# %% [markdown]
# Read dataset csv according experts and newcomers labels

# %%
data_expert_newcomers_combined = pd.read_csv("data_expert_newcomers_combined.csv")
data_expert_newcomers_combined
# Out:
#                                                    url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 163  https://api.github.com/repos/pallets/flask/iss...
# 164  https://api.github.com/repos/pallets/flask/iss...
# 165  https://api.github.com/repos/pallets/flask/iss...
# 166  https://api.github.com/repos/pallets/flask/iss...
# 167  https://api.github.com/repos/pallets/flask/iss...
#
#                                  repository_url  \
# 0    https://api.github.com/repos/pallets/flask
# 1    https://api.github.com/repos/pallets/flask
# 2    https://api.github.com/repos/pallets/flask
# 3    https://api.github.com/repos/pallets/flask
# 4    https://api.github.com/repos/pallets/flask
# ..                                          ...
# 163  https://api.github.com/repos/pallets/flask
# 164  https://api.github.com/repos/pallets/flask
# 165  https://api.github.com/repos/pallets/flask
# 166  https://api.github.com/repos/pallets/flask
# 167  https://api.github.com/repos/pallets/flask
#
#                                             labels_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 163  https://api.github.com/repos/pallets/flask/iss...
# 164  https://api.github.com/repos/pallets/flask/iss...
# 165  https://api.github.com/repos/pallets/flask/iss...
# 166  https://api.github.com/repos/pallets/flask/iss...
# 167  https://api.github.com/repos/pallets/flask/iss...
#
#                                           comments_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 163  https://api.github.com/repos/pallets/flask/iss...
# 164  https://api.github.com/repos/pallets/flask/iss...
# 165  https://api.github.com/repos/pallets/flask/iss...
# 166  https://api.github.com/repos/pallets/flask/iss...
# 167  https://api.github.com/repos/pallets/flask/iss...
#
#                                             events_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 163  https://api.github.com/repos/pallets/flask/iss...
# 164  https://api.github.com/repos/pallets/flask/iss...
# 165  https://api.github.com/repos/pallets/flask/iss...
# 166  https://api.github.com/repos/pallets/flask/iss...
# 167  https://api.github.com/repos/pallets/flask/iss...
#
#                                          html_url          id  \
# 0    https://github.com/pallets/flask/issues/4333  1049595014
# 1    https://github.com/pallets/flask/issues/3787   718946947
# 2    https://github.com/pallets/flask/issues/3227   450343888
# 3    https://github.com/pallets/flask/issues/3226   450340069
# 4    https://github.com/pallets/flask/issues/3218   448470200
# ..                                            ...         ...
# 163   https://github.com/pallets/flask/issues/422     3572659
# 164   https://github.com/pallets/flask/issues/348     2177145
# 165   https://github.com/pallets/flask/issues/289     1314399
# 166   https://github.com/pallets/flask/issues/266     1133381
# 167   https://github.com/pallets/flask/issues/175      607742
#
#                       node_id  number  \
# 0          I_kwDOAAkbnM4-j4yG    4333
# 1    MDU6SXNzdWU3MTg5NDY5NDc=    3787
# 2    MDU6SXNzdWU0NTAzNDM4ODg=    3227
# 3    MDU6SXNzdWU0NTAzNDAwNjk=    3226
# 4    MDU6SXNzdWU0NDg0NzAyMDA=    3218
# ..                        ...     ...
# 163      MDU6SXNzdWUzNTcyNjU5     422
# 164      MDU6SXNzdWUyMTc3MTQ1     348
# 165      MDU6SXNzdWUxMzE0Mzk5     289
# 166      MDU6SXNzdWUxMTMzMzgx     266
# 167      MDU6SXNzdWU2MDc3NDI=     175
#
#                                                  title  ...  \
# 0    `after_this_request` fails with a meaningless ...  ...
# 1    Outdated external link in errorhandling docume...  ...
# 2               suspicious unexplained `except: raise`  ...
# 3         unused import: werkzeug.datastructures:Range  ...
# 4                         Use @property as a decorator  ...
# ..                                                 ...  ...
# 163  Allow specifying request_class on a per-bluepr...  ...
# 164  Static files only work for blueprints register...  ...
# 165           Blueprints and Extensions and SQLAlchemy  ...
# 166    Blueprint template lookup not documented enough  ...
# 167          Error Handlers versus Werkzeug Exceptions  ...
#
#                      closed_at author_association active_lock_reason  \
# 0    2021-12-23 01:49:46+00:00             MEMBER           resolved
# 1    2020-10-12 02:15:27+00:00               NONE           resolved
# 2    2019-05-31 16:56:44+00:00             MEMBER           resolved
# 3    2019-05-31 17:03:17+00:00             MEMBER           resolved
# 4    2019-05-31 17:46:19+00:00             MEMBER           resolved
# ..                         ...                ...                ...
# 163  2017-06-02 18:40:05+00:00        CONTRIBUTOR           resolved
# 164  2018-04-09 08:27:26+00:00               NONE           resolved
# 165  2022-06-28 23:38:15+00:00             MEMBER           resolved
# 166  2016-06-04 06:25:27+00:00             MEMBER           resolved
# 167  2017-04-26 06:14:51+00:00             MEMBER           resolved
#
#                                                   body  \
# 0    https://github.com/pallets/flask/blob/9039534e...
# 1    Just a small contribution, in documentation se...
# 2    The following two lines:\r\nhttps://github.com...
# 3    The following line contains an unused import:\...
# 4    A bunch of properties in the codebase are defi...
# ..                                                 ...
# 163  Suppose we have a situation in which a user cr...
# 164  The option `static_folder` for blueprints only...
# 165  We do not encourage people to create more than...
# 166  The new blueprint template lookup scheme where...
# 167  Currently you can only declare error handler f...
#
#                                              reactions  \
# 0    {'url': 'https://api.github.com/repos/pallets/...
# 1    {'url': 'https://api.github.com/repos/pallets/...
# 2    {'url': 'https://api.github.com/repos/pallets/...
# 3    {'url': 'https://api.github.com/repos/pallets/...
# 4    {'url': 'https://api.github.com/repos/pallets/...
# ..                                                 ...
# 163  {'url': 'https://api.github.com/repos/pallets/...
# 164  {'url': 'https://api.github.com/repos/pallets/...
# 165  {'url': 'https://api.github.com/repos/pallets/...
# 166  {'url': 'https://api.github.com/repos/pallets/...
# 167  {'url': 'https://api.github.com/repos/pallets/...
#
#                                           timeline_url  \
# 0    https://api.github.com/repos/pallets/flask/iss...
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 163  https://api.github.com/repos/pallets/flask/iss...
# 164  https://api.github.com/repos/pallets/flask/iss...
# 165  https://api.github.com/repos/pallets/flask/iss...
# 166  https://api.github.com/repos/pallets/flask/iss...
# 167  https://api.github.com/repos/pallets/flask/iss...
#
#     performed_via_github_app  state_reason draft pull_request
# 0                        NaN     completed   NaN          NaN
# 1                        NaN     completed   NaN          NaN
# 2                        NaN     completed   NaN          NaN
# 3                        NaN     completed   NaN          NaN
# 4                        NaN     completed   NaN          NaN
# ..                       ...           ...   ...          ...
# 163                      NaN     completed   NaN          NaN
# 164                      NaN     completed   NaN          NaN
# 165                      NaN     completed   NaN          NaN
# 166                      NaN     completed   NaN          NaN
# 167                      NaN     completed   NaN          NaN
#
# [168 rows x 30 columns]

# %% [markdown]
# Took data newcomers and experts combined which is closed issue

# %%
data_expert_newcomers_combined_closed = data_expert_newcomers_combined[data_expert_newcomers_combined.state == "closed"]

# %% [markdown]
# Show closed data newcomers and experts combined

# %%
data_expert_newcomers_combined_closed.reset_index(drop=True, inplace=True)
data_expert_newcomers_combined_closed.index += 1 
data_expert_newcomers_combined_closed
# Out:
#                                                    url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 164  https://api.github.com/repos/pallets/flask/iss...
# 165  https://api.github.com/repos/pallets/flask/iss...
# 166  https://api.github.com/repos/pallets/flask/iss...
# 167  https://api.github.com/repos/pallets/flask/iss...
# 168  https://api.github.com/repos/pallets/flask/iss...
#
#                                  repository_url  \
# 1    https://api.github.com/repos/pallets/flask
# 2    https://api.github.com/repos/pallets/flask
# 3    https://api.github.com/repos/pallets/flask
# 4    https://api.github.com/repos/pallets/flask
# 5    https://api.github.com/repos/pallets/flask
# ..                                          ...
# 164  https://api.github.com/repos/pallets/flask
# 165  https://api.github.com/repos/pallets/flask
# 166  https://api.github.com/repos/pallets/flask
# 167  https://api.github.com/repos/pallets/flask
# 168  https://api.github.com/repos/pallets/flask
#
#                                             labels_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 164  https://api.github.com/repos/pallets/flask/iss...
# 165  https://api.github.com/repos/pallets/flask/iss...
# 166  https://api.github.com/repos/pallets/flask/iss...
# 167  https://api.github.com/repos/pallets/flask/iss...
# 168  https://api.github.com/repos/pallets/flask/iss...
#
#                                           comments_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 164  https://api.github.com/repos/pallets/flask/iss...
# 165  https://api.github.com/repos/pallets/flask/iss...
# 166  https://api.github.com/repos/pallets/flask/iss...
# 167  https://api.github.com/repos/pallets/flask/iss...
# 168  https://api.github.com/repos/pallets/flask/iss...
#
#                                             events_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 164  https://api.github.com/repos/pallets/flask/iss...
# 165  https://api.github.com/repos/pallets/flask/iss...
# 166  https://api.github.com/repos/pallets/flask/iss...
# 167  https://api.github.com/repos/pallets/flask/iss...
# 168  https://api.github.com/repos/pallets/flask/iss...
#
#                                          html_url          id  \
# 1    https://github.com/pallets/flask/issues/4333  1049595014
# 2    https://github.com/pallets/flask/issues/3787   718946947
# 3    https://github.com/pallets/flask/issues/3227   450343888
# 4    https://github.com/pallets/flask/issues/3226   450340069
# 5    https://github.com/pallets/flask/issues/3218   448470200
# ..                                            ...         ...
# 164   https://github.com/pallets/flask/issues/422     3572659
# 165   https://github.com/pallets/flask/issues/348     2177145
# 166   https://github.com/pallets/flask/issues/289     1314399
# 167   https://github.com/pallets/flask/issues/266     1133381
# 168   https://github.com/pallets/flask/issues/175      607742
#
#                       node_id  number  \
# 1          I_kwDOAAkbnM4-j4yG    4333
# 2    MDU6SXNzdWU3MTg5NDY5NDc=    3787
# 3    MDU6SXNzdWU0NTAzNDM4ODg=    3227
# 4    MDU6SXNzdWU0NTAzNDAwNjk=    3226
# 5    MDU6SXNzdWU0NDg0NzAyMDA=    3218
# ..                        ...     ...
# 164      MDU6SXNzdWUzNTcyNjU5     422
# 165      MDU6SXNzdWUyMTc3MTQ1     348
# 166      MDU6SXNzdWUxMzE0Mzk5     289
# 167      MDU6SXNzdWUxMTMzMzgx     266
# 168      MDU6SXNzdWU2MDc3NDI=     175
#
#                                                  title  ...  \
# 1    `after_this_request` fails with a meaningless ...  ...
# 2    Outdated external link in errorhandling docume...  ...
# 3               suspicious unexplained `except: raise`  ...
# 4         unused import: werkzeug.datastructures:Range  ...
# 5                         Use @property as a decorator  ...
# ..                                                 ...  ...
# 164  Allow specifying request_class on a per-bluepr...  ...
# 165  Static files only work for blueprints register...  ...
# 166           Blueprints and Extensions and SQLAlchemy  ...
# 167    Blueprint template lookup not documented enough  ...
# 168          Error Handlers versus Werkzeug Exceptions  ...
#
#                      closed_at author_association active_lock_reason  \
# 1    2021-12-23 01:49:46+00:00             MEMBER           resolved
# 2    2020-10-12 02:15:27+00:00               NONE           resolved
# 3    2019-05-31 16:56:44+00:00             MEMBER           resolved
# 4    2019-05-31 17:03:17+00:00             MEMBER           resolved
# 5    2019-05-31 17:46:19+00:00             MEMBER           resolved
# ..                         ...                ...                ...
# 164  2017-06-02 18:40:05+00:00        CONTRIBUTOR           resolved
# 165  2018-04-09 08:27:26+00:00               NONE           resolved
# 166  2022-06-28 23:38:15+00:00             MEMBER           resolved
# 167  2016-06-04 06:25:27+00:00             MEMBER           resolved
# 168  2017-04-26 06:14:51+00:00             MEMBER           resolved
#
#                                                   body  \
# 1    https://github.com/pallets/flask/blob/9039534e...
# 2    Just a small contribution, in documentation se...
# 3    The following two lines:\r\nhttps://github.com...
# 4    The following line contains an unused import:\...
# 5    A bunch of properties in the codebase are defi...
# ..                                                 ...
# 164  Suppose we have a situation in which a user cr...
# 165  The option `static_folder` for blueprints only...
# 166  We do not encourage people to create more than...
# 167  The new blueprint template lookup scheme where...
# 168  Currently you can only declare error handler f...
#
#                                              reactions  \
# 1    {'url': 'https://api.github.com/repos/pallets/...
# 2    {'url': 'https://api.github.com/repos/pallets/...
# 3    {'url': 'https://api.github.com/repos/pallets/...
# 4    {'url': 'https://api.github.com/repos/pallets/...
# 5    {'url': 'https://api.github.com/repos/pallets/...
# ..                                                 ...
# 164  {'url': 'https://api.github.com/repos/pallets/...
# 165  {'url': 'https://api.github.com/repos/pallets/...
# 166  {'url': 'https://api.github.com/repos/pallets/...
# 167  {'url': 'https://api.github.com/repos/pallets/...
# 168  {'url': 'https://api.github.com/repos/pallets/...
#
#                                           timeline_url  \
# 1    https://api.github.com/repos/pallets/flask/iss...
# 2    https://api.github.com/repos/pallets/flask/iss...
# 3    https://api.github.com/repos/pallets/flask/iss...
# 4    https://api.github.com/repos/pallets/flask/iss...
# 5    https://api.github.com/repos/pallets/flask/iss...
# ..                                                 ...
# 164  https://api.github.com/repos/pallets/flask/iss...
# 165  https://api.github.com/repos/pallets/flask/iss...
# 166  https://api.github.com/repos/pallets/flask/iss...
# 167  https://api.github.com/repos/pallets/flask/iss...
# 168  https://api.github.com/repos/pallets/flask/iss...
#
#     performed_via_github_app  state_reason draft pull_request
# 1                        NaN     completed   NaN          NaN
# 2                        NaN     completed   NaN          NaN
# 3                        NaN     completed   NaN          NaN
# 4                        NaN     completed   NaN          NaN
# 5                        NaN     completed   NaN          NaN
# ..                       ...           ...   ...          ...
# 164                      NaN     completed   NaN          NaN
# 165                      NaN     completed   NaN          NaN
# 166                      NaN     completed   NaN          NaN
# 167                      NaN     completed   NaN          NaN
# 168                      NaN     completed   NaN          NaN
#
# [168 rows x 30 columns]

# %% [markdown]
# Save the data newcomers and experts combined

# %%
data_expert_newcomers_combined_closed.to_csv("data_expert_newcomers_combined_closed_index.csv")

# %% [markdown]
# ## Take title and body

# %% [markdown]
# ### Newcomers

# %% [markdown]
# #### Title

# %% [markdown]
# This code for take title of datasets of newcomers and save it in to csv file.

# %%
data_newcomers_closed['title']
# Out:
# 1     `after_this_request` fails with a meaningless ...
# 2     Outdated external link in errorhandling docume...
# 3                suspicious unexplained `except: raise`
# 4          unused import: werkzeug.datastructures:Range
# 5                          Use @property as a decorator
# 6                         Document Blueprint parameters
# 7                              Don't require ssl module
# 8     yum install virtualenv instead of python-virtu...
# 9     Documentation "Testing Flask Applications" sho...
# 10    Missing import statement in "Uploading Files" ...
# 11    JSONEncoder encodes aware datetime objects in ...
# 12        Organize the gevent tests into a single class
# 13          DRY up the test suite using pytest fixtures
# 14                                 Review HTTP security
# 15          Document how to set env vars for PowerShell
# 16    Detect `create_app` when FLASK_APP doesn't spe...
# 17    Documentation: Term "development mode" is unclear
# 18    Generating relative url with app context shoul...
# 19    Class-based View should set provide_automatic_...
# 20       Take advantage of Py3.6 json support for bytes
# 21                Zero-padded file modes in repository
# 22    Disable OS-level autocorrect in the interactiv...
# 23           Remove easy_install from installation docs
# 24    Use pip in upgrade documentation instead of ea...
# 25                            Wrong import json library
# 26                              `flask --version` fails
# 27             Unify versionadded markers (0.11 vs 1.0)
# 28    flaskr example seems to loose data on every la...
# 29    Please update mod_wsgi documentation to use ht...
# 30                              packaging docs outdated
# 31           small inaccuracy in get_json documentation
# 32    flask.Request should have an is_static field f...
# 33                           bad content-length default
# 34                  Mention Extensions in the Docs more
# 35    sessions documentation (client side vs server ...
# 36      Blueprint template lookup not documented enough
# Name: title, dtype: object

# %%
data_title_newcomers = data_newcomers_closed['title']

# %%
pd.DataFrame(data_title_newcomers)
# Out:
#                                                 title
# 1   `after_this_request` fails with a meaningless ...
# 2   Outdated external link in errorhandling docume...
# 3              suspicious unexplained `except: raise`
# 4        unused import: werkzeug.datastructures:Range
# 5                        Use @property as a decorator
# 6                       Document Blueprint parameters
# 7                            Don't require ssl module
# 8   yum install virtualenv instead of python-virtu...
# 9   Documentation "Testing Flask Applications" sho...
# 10  Missing import statement in "Uploading Files" ...
# 11  JSONEncoder encodes aware datetime objects in ...
# 12      Organize the gevent tests into a single class
# 13        DRY up the test suite using pytest fixtures
# 14                               Review HTTP security
# 15        Document how to set env vars for PowerShell
# 16  Detect `create_app` when FLASK_APP doesn't spe...
# 17  Documentation: Term "development mode" is unclear
# 18  Generating relative url with app context shoul...
# 19  Class-based View should set provide_automatic_...
# 20     Take advantage of Py3.6 json support for bytes
# 21              Zero-padded file modes in repository
# 22  Disable OS-level autocorrect in the interactiv...
# 23         Remove easy_install from installation docs
# 24  Use pip in upgrade documentation instead of ea...
# 25                          Wrong import json library
# 26                            `flask --version` fails
# 27           Unify versionadded markers (0.11 vs 1.0)
# 28  flaskr example seems to loose data on every la...
# 29  Please update mod_wsgi documentation to use ht...
# 30                            packaging docs outdated
# 31         small inaccuracy in get_json documentation
# 32  flask.Request should have an is_static field f...
# 33                         bad content-length default
# 34                Mention Extensions in the Docs more
# 35  sessions documentation (client side vs server ...
# 36    Blueprint template lookup not documented enough

# %%
data_title_newcomers.to_csv("data_title_newcomers.csv", index=False)

# %% [markdown]
# #### Body

# %% [markdown]
# This code for take body from datasets of newcomers and save it to csv file

# %%
data_newcomers_closed['body']
# Out:
# 1     https://github.com/pallets/flask/blob/9039534e...
# 2     Just a small contribution, in documentation se...
# 3     The following two lines:\r\nhttps://github.com...
# 4     The following line contains an unused import:\...
# 5     A bunch of properties in the codebase are defi...
# 6     `Blueprint` does not have reStructuredText mar...
# 7     Python can be compiled without certain modules...
# 8     ---\r\n\r\n### Expected Behavior\r\n\r\n`yum i...
# 9     The `flask.testing` `FlaskClient` has clean-up...
# 10    ### Expected Behavior\r\n\r\nExamples in the d...
# 11    ``flask.json.JSONEncoder()`` encodes aware dat...
# 12    https://github.com/pallets/flask/blob/c8e56d58...
# 13    The test suite is a bit of a mess as far as ho...
# 14    We should make sure we're providing good, thor...
# 15    PowerShell's syntax is different than CMD's.\r...
# 16    `find_best_app` only looks for `app` and `appl...
# 17    I'm doing some work which requires defining so...
# 18    This is a pattern to generate the url to pass ...
# 19    ~Deprecate in favor of #2249, #1489, #1488, wh...
# 20    [Python 3.6 added support for loading json fro...
# 21    After cloning this repository with git and you...
# 22    If you’re using the interactive debugger in th...
# 23    As pointed out in #1915, http://flask.pocoo.or...
# 24    In the upgrade docs, `easy_install` is listed ...
# 25    [This code](https://github.com/pallets/flask/b...
# 26    The `flask` CLI utility that ships with Flask ...
# 27    There are a few `versionadded::` markers that ...
# 28    Branch: 0.10\nExample - flaskr\nDescription: E...
# 29    This is my own fault as I was looking for othe...
# 30    from here ->  http://flask.pocoo.org/docs/0.10...
# 31    In the documentation for [`get_json`](http://f...
# 32    It would be nice to be able to easily tell sta...
# 33    In werkzeug's WSGIRequestHandler, CONTENT-LENG...
# 34    I had a friend that was going through the quic...
# 35    more explicit docs on client side sessions vs ...
# 36    The new blueprint template lookup scheme where...
# Name: body, dtype: object

# %%
data_body_newcomers = data_newcomers_closed['body']

# %%
pd.DataFrame(data_body_newcomers)
# Out:
#                                                  body
# 1   https://github.com/pallets/flask/blob/9039534e...
# 2   Just a small contribution, in documentation se...
# 3   The following two lines:\r\nhttps://github.com...
# 4   The following line contains an unused import:\...
# 5   A bunch of properties in the codebase are defi...
# 6   `Blueprint` does not have reStructuredText mar...
# 7   Python can be compiled without certain modules...
# 8   ---\r\n\r\n### Expected Behavior\r\n\r\n`yum i...
# 9   The `flask.testing` `FlaskClient` has clean-up...
# 10  ### Expected Behavior\r\n\r\nExamples in the d...
# 11  ``flask.json.JSONEncoder()`` encodes aware dat...
# 12  https://github.com/pallets/flask/blob/c8e56d58...
# 13  The test suite is a bit of a mess as far as ho...
# 14  We should make sure we're providing good, thor...
# 15  PowerShell's syntax is different than CMD's.\r...
# 16  `find_best_app` only looks for `app` and `appl...
# 17  I'm doing some work which requires defining so...
# 18  This is a pattern to generate the url to pass ...
# 19  ~Deprecate in favor of #2249, #1489, #1488, wh...
# 20  [Python 3.6 added support for loading json fro...
# 21  After cloning this repository with git and you...
# 22  If you’re using the interactive debugger in th...
# 23  As pointed out in #1915, http://flask.pocoo.or...
# 24  In the upgrade docs, `easy_install` is listed ...
# 25  [This code](https://github.com/pallets/flask/b...
# 26  The `flask` CLI utility that ships with Flask ...
# 27  There are a few `versionadded::` markers that ...
# 28  Branch: 0.10\nExample - flaskr\nDescription: E...
# 29  This is my own fault as I was looking for othe...
# 30  from here ->  http://flask.pocoo.org/docs/0.10...
# 31  In the documentation for [`get_json`](http://f...
# 32  It would be nice to be able to easily tell sta...
# 33  In werkzeug's WSGIRequestHandler, CONTENT-LENG...
# 34  I had a friend that was going through the quic...
# 35  more explicit docs on client side sessions vs ...
# 36  The new blueprint template lookup scheme where...

# %%
data_body_newcomers.to_csv("data_body_newcomers.csv", index=False)

# %% [markdown]
# ### Expert

# %% [markdown]
# #### Title

# %% [markdown]
# This code for take body of datasets of newcomers and save it in to csv file

# %%
data_experts_closed['title']
# Out:
# 1      asserts with `pytest.raises` should be outside...
# 2      Registering a blueprint does not update the ur...
# 3      blueprints are registered with nested names, c...
# 4      Nested blueprint should be able to have same name
# 5                                                 Bp fix
#                              ...
# 128    Allow specifying request_class on a per-bluepr...
# 129    Static files only work for blueprints register...
# 130             Blueprints and Extensions and SQLAlchemy
# 131      Blueprint template lookup not documented enough
# 132            Error Handlers versus Werkzeug Exceptions
# Name: title, Length: 132, dtype: object

# %%
data_title_experts = data_experts_closed['title']

# %%
pd.DataFrame(data_title_experts)
# Out:
#                                                  title
# 1    asserts with `pytest.raises` should be outside...
# 2    Registering a blueprint does not update the ur...
# 3    blueprints are registered with nested names, c...
# 4    Nested blueprint should be able to have same name
# 5                                               Bp fix
# ..                                                 ...
# 128  Allow specifying request_class on a per-bluepr...
# 129  Static files only work for blueprints register...
# 130           Blueprints and Extensions and SQLAlchemy
# 131    Blueprint template lookup not documented enough
# 132          Error Handlers versus Werkzeug Exceptions
#
# [132 rows x 1 columns]

# %%
data_title_experts.to_csv("data_title_experts.csv", index=False)

# %% [markdown]
# #### Body

# %% [markdown]
# This code for take body of datasets of experts and save it in to csv file

# %%
data_experts_closed['body']
# Out:
# 1      I've been using Flask's test suite to evaluate...
# 2      When setting `url_prefix` in `app.register_blu...
# 3      - Blueprints are registered with the full nest...
# 4      <!--\r\nDescribe how to replicate the bug.\r\n...
# 5      Note for the Changelog the existing entry will...
#                              ...
# 128    Suppose we have a situation in which a user cr...
# 129    The option `static_folder` for blueprints only...
# 130    We do not encourage people to create more than...
# 131    The new blueprint template lookup scheme where...
# 132    Currently you can only declare error handler f...
# Name: body, Length: 132, dtype: object

# %%
data_body_experts = data_experts_closed['body']

# %%
pd.DataFrame(data_body_experts)
# Out:
#                                                   body
# 1    I've been using Flask's test suite to evaluate...
# 2    When setting `url_prefix` in `app.register_blu...
# 3    - Blueprints are registered with the full nest...
# 4    <!--\r\nDescribe how to replicate the bug.\r\n...
# 5    Note for the Changelog the existing entry will...
# ..                                                 ...
# 128  Suppose we have a situation in which a user cr...
# 129  The option `static_folder` for blueprints only...
# 130  We do not encourage people to create more than...
# 131  The new blueprint template lookup scheme where...
# 132  Currently you can only declare error handler f...
#
# [132 rows x 1 columns]

# %%
data_body_experts.to_csv("data_body_experts.csv", index=False)

# %% [markdown]
# ### Both

# %% [markdown]
# #### Title

# %% [markdown]
# This code for take body of datasets of experts and newcomers and save it in to csv file

# %%
data_expert_newcomers_closed['title']
# Out:
# 1      Link to example project in tutorial is dead (l...
# 2                        fix: remove obsolete `zip_safe`
# 3                       correct `waitress-serve` command
# 4                          waitress command doesn't work
# 5                            refactor or remove old docs
#                              ...
# 586                        Example Application too Basic
# 587    Documentation needs to explain Circular Depend...
# 588                       Thoughts about the fabric docs
# 589              Example App based on Flask + Extensions
# 590                                    Document setup.py
# Name: title, Length: 590, dtype: object

# %%
data_title_expert_newcomers = data_expert_newcomers_closed['title']

# %%
pd.DataFrame(data_title_expert_newcomers)
# Out:
#                                                  title
# 1    Link to example project in tutorial is dead (l...
# 2                      fix: remove obsolete `zip_safe`
# 3                     correct `waitress-serve` command
# 4                        waitress command doesn't work
# 5                          refactor or remove old docs
# ..                                                 ...
# 586                      Example Application too Basic
# 587  Documentation needs to explain Circular Depend...
# 588                     Thoughts about the fabric docs
# 589            Example App based on Flask + Extensions
# 590                                  Document setup.py
#
# [590 rows x 1 columns]

# %%
data_title_expert_newcomers.to_csv("data_title_expert_newcomers.csv", index=False)

# %% [markdown]
# #### Body

# %% [markdown]
# This code for take body of datasets of experts and newcomers and save it in to csv file

# %%
data_expert_newcomers_closed['body']
# Out:
# 1      From docs page : https://flask.palletsprojects...
# 2      X-Ref: #4782\r\n\r\nThe only other `zip_safe` ...
# 3      Fix the `waitress-serve` command on the docs.\...
# 4      The `waitress-serve` command in the documentat...
# 5      * HTML FAQ was pretty outdated, and not partic...
#                              ...
# 586    There should be a larger tutorial that not onl...
# 587    Currently the documentation does not explain w...
# 588    Maybe use of one of these should be suggested:...
# 589    It would be nice to see an example application...
# 590    Documentation should show how a typical setup....
# Name: body, Length: 590, dtype: object

# %%
data_body_expert_newcomers = data_expert_newcomers_closed['body']

# %%
pd.DataFrame(data_body_expert_newcomers)
# Out:
#                                                   body
# 1    From docs page : https://flask.palletsprojects...
# 2    X-Ref: #4782\r\n\r\nThe only other `zip_safe` ...
# 3    Fix the `waitress-serve` command on the docs.\...
# 4    The `waitress-serve` command in the documentat...
# 5    * HTML FAQ was pretty outdated, and not partic...
# ..                                                 ...
# 586  There should be a larger tutorial that not onl...
# 587  Currently the documentation does not explain w...
# 588  Maybe use of one of these should be suggested:...
# 589  It would be nice to see an example application...
# 590  Documentation should show how a typical setup....
#
# [590 rows x 1 columns]

# %%
data_body_expert_newcomers.to_csv("data_body_expert_newcomers.csv", index=False)

# %% [markdown]
# # Combined

# %% [markdown]
# ## Title

# %%
data_title_expert_newcomers_combined = data_title_newcomers.append(data_title_experts)

# %%
data_title_expert_newcomers_combined
# Out:
# 1      `after_this_request` fails with a meaningless ...
# 2      Outdated external link in errorhandling docume...
# 3                 suspicious unexplained `except: raise`
# 4           unused import: werkzeug.datastructures:Range
# 5                           Use @property as a decorator
#                              ...
# 128    Allow specifying request_class on a per-bluepr...
# 129    Static files only work for blueprints register...
# 130             Blueprints and Extensions and SQLAlchemy
# 131      Blueprint template lookup not documented enough
# 132            Error Handlers versus Werkzeug Exceptions
# Name: title, Length: 168, dtype: object

# %%
pd.DataFrame(data_title_expert_newcomers_combined)
# Out:
#                                                  title
# 1    `after_this_request` fails with a meaningless ...
# 2    Outdated external link in errorhandling docume...
# 3               suspicious unexplained `except: raise`
# 4         unused import: werkzeug.datastructures:Range
# 5                         Use @property as a decorator
# ..                                                 ...
# 128  Allow specifying request_class on a per-bluepr...
# 129  Static files only work for blueprints register...
# 130           Blueprints and Extensions and SQLAlchemy
# 131    Blueprint template lookup not documented enough
# 132          Error Handlers versus Werkzeug Exceptions
#
# [168 rows x 1 columns]

# %%
data_title_expert_newcomers_combined.to_csv("data_title_expert_newcomers_combined.csv", index=False)

# %% [markdown]
# ## Body

# %%
data_body_expert_newcomers_combined = data_body_newcomers.append(data_body_experts)

# %%
data_body_expert_newcomers_combined
# Out:
# 1      https://github.com/pallets/flask/blob/9039534e...
# 2      Just a small contribution, in documentation se...
# 3      The following two lines:\r\nhttps://github.com...
# 4      The following line contains an unused import:\...
# 5      A bunch of properties in the codebase are defi...
#                              ...
# 128    Suppose we have a situation in which a user cr...
# 129    The option `static_folder` for blueprints only...
# 130    We do not encourage people to create more than...
# 131    The new blueprint template lookup scheme where...
# 132    Currently you can only declare error handler f...
# Name: body, Length: 168, dtype: object

# %%
data_body_expert_newcomers_combined.to_csv("data_body_expert_newcomers_combined.csv", index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a56fca8c-50f9-4e61-9ae7-71749be874f5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
