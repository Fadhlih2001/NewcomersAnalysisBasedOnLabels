# %% [markdown]
# # Import Library

# %% [markdown]
# This code is for importing library what I need.

# %%
# !pip install numpy
# !pip install pandas
# !pip install nltk
# !pip install beautifulsoup4
# !pip install mpld3
# !pip install -U scikit-learn
# !pip install joblib
# !pip install gensim
# Out:
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.23.4)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.2.5)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas) (2022.5)
# Requirement already satisfied: numpy>=1.16.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: nltk in /shared-libs/python3.9/py/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (2022.9.13)
# Requirement already satisfied: click in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (4.64.1)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4) (2.3.2.post1)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: mpld3 in /root/venv/lib/python3.9/site-packages (0.5.9)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from mpld3) (3.6.0)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from mpld3) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->mpld3) (2.0.0)
# Requirement already satisfied: numpy>=1.19 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (1.23.4)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (4.37.4)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->mpld3) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->mpld3) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->mpld3) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->mpld3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mpld3) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: scikit-learn in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.1.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 133.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: scipy>=1.3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.2
#     Not uninstalling scikit-learn at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
# Successfully installed scikit-learn-1.2.1
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.2.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: gensim in /root/venv/lib/python3.9/site-packages (4.3.0)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: scipy>=1.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim) (1.9.3)
# Requirement already satisfied: numpy>=1.18.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim) (1.23.4)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /root/venv/lib/python3.9/site-packages (from gensim) (2.0.5)
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (from FuzzyTM>=0.4.0->gensim) (1.2.5)
# Requirement already satisfied: pyfume in /root/venv/lib/python3.9/site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: fst-pso in /root/venv/lib/python3.9/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: simpful in /root/venv/lib/python3.9/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.10.0)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: miniful in /root/venv/lib/python3.9/site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: requests in /shared-libs/python3.9/py/lib/python3.9/site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (3.4)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from bs4 import BeautifulSoup
import re
import os 
import codecs
from sklearn import feature_extraction
import mpld3
from glob import glob 
import json
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Get all the labels

# %% [markdown]
# ## Load the datasets

# %% [markdown]
# This code is for read JSON datasets, and take the labels column

# %%
#Load Labels CSV
df = pd.read_json("benjaminp_six.json")
df
# Out:
#                                                    url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 363  https://api.github.com/repos/benjaminp/six/iss...
# 364  https://api.github.com/repos/benjaminp/six/iss...
# 365  https://api.github.com/repos/benjaminp/six/iss...
# 366  https://api.github.com/repos/benjaminp/six/iss...
# 367  https://api.github.com/repos/benjaminp/six/iss...
#
#                                  repository_url  \
# 0    https://api.github.com/repos/benjaminp/six
# 1    https://api.github.com/repos/benjaminp/six
# 2    https://api.github.com/repos/benjaminp/six
# 3    https://api.github.com/repos/benjaminp/six
# 4    https://api.github.com/repos/benjaminp/six
# ..                                          ...
# 363  https://api.github.com/repos/benjaminp/six
# 364  https://api.github.com/repos/benjaminp/six
# 365  https://api.github.com/repos/benjaminp/six
# 366  https://api.github.com/repos/benjaminp/six
# 367  https://api.github.com/repos/benjaminp/six
#
#                                             labels_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 363  https://api.github.com/repos/benjaminp/six/iss...
# 364  https://api.github.com/repos/benjaminp/six/iss...
# 365  https://api.github.com/repos/benjaminp/six/iss...
# 366  https://api.github.com/repos/benjaminp/six/iss...
# 367  https://api.github.com/repos/benjaminp/six/iss...
#
#                                           comments_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 363  https://api.github.com/repos/benjaminp/six/iss...
# 364  https://api.github.com/repos/benjaminp/six/iss...
# 365  https://api.github.com/repos/benjaminp/six/iss...
# 366  https://api.github.com/repos/benjaminp/six/iss...
# 367  https://api.github.com/repos/benjaminp/six/iss...
#
#                                             events_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 363  https://api.github.com/repos/benjaminp/six/iss...
# 364  https://api.github.com/repos/benjaminp/six/iss...
# 365  https://api.github.com/repos/benjaminp/six/iss...
# 366  https://api.github.com/repos/benjaminp/six/iss...
# 367  https://api.github.com/repos/benjaminp/six/iss...
#
#                                         html_url          id  \
# 0    https://github.com/benjaminp/six/issues/369  1356705912
# 1    https://github.com/benjaminp/six/issues/368  1333446643
# 2      https://github.com/benjaminp/six/pull/367  1318748092
# 3    https://github.com/benjaminp/six/issues/366  1275941841
# 4      https://github.com/benjaminp/six/pull/365  1058874194
# ..                                           ...         ...
# 363    https://github.com/benjaminp/six/issues/5   198391151
# 364    https://github.com/benjaminp/six/issues/4   198391148
# 365    https://github.com/benjaminp/six/issues/3   198391144
# 366    https://github.com/benjaminp/six/issues/2   198391139
# 367    https://github.com/benjaminp/six/issues/1   198391131
#
#                       node_id  number  \
# 0          I_kwDOBKQuOM5Q3bB4     369
# 1          I_kwDOBKQuOM5Pesfz     368
# 2         PR_kwDOBKQuOM48I4Qs     367
# 3          I_kwDOBKQuOM5MDVPR     366
# 4         PR_kwDOBKQuOM4uygn_     365
# ..                        ...     ...
# 363  MDU6SXNzdWUxOTgzOTExNTE=       5
# 364  MDU6SXNzdWUxOTgzOTExNDg=       4
# 365  MDU6SXNzdWUxOTgzOTExNDQ=       3
# 366  MDU6SXNzdWUxOTgzOTExMzk=       2
# 367  MDU6SXNzdWUxOTgzOTExMzE=       1
#
#                                                  title  ...  \
# 0    RuntimeError: restricted attribute setting __d...  ...
# 1    ImportWarning: _SixMetaPathImporter.find_spec(...  ...
# 2                                            Add 3.10.  ...
# 3    can i use six just like run command on cmd lik...  ...
# 4                       Fix `UserDict` move in Python2  ...
# ..                                                 ...  ...
# 363  import hook for replacing except .. as .. with...  ...
# 364                      Include test suite in tarball  ...
# 365                                  map/filter issues  ...
# 366  u() function does not support unicode characte...  ...
# 367                                         ChangeLog?  ...
#
#                     closed_at author_association active_lock_reason  \
# 0                         NaT               NONE                NaN
# 1                         NaT               NONE                NaN
# 2   2022-07-26 21:03:11+00:00              OWNER                NaN
# 3   2022-07-26 20:59:22+00:00               NONE                NaN
# 4   2021-11-21 23:00:36+00:00        CONTRIBUTOR                NaN
# ..                        ...                ...                ...
# 363 2017-01-02 23:31:12+00:00              OWNER                NaN
# 364 2017-01-02 23:31:08+00:00              OWNER                NaN
# 365 2017-01-02 23:31:05+00:00              OWNER                NaN
# 366 2017-01-02 23:31:03+00:00              OWNER                NaN
# 367 2017-01-02 23:30:58+00:00              OWNER                NaN
#
#                                                   body  \
# 0    Hi!\r\nI'm writing a python program where I ne...
# 1    ```\r\nPython version: 3.10\r\nDjango version:...
# 2                                                 None
# 3    can i use six just like run command on cmd lik...
# 4    # Background\r\n\r\nThe current implementation...
# ..                                                 ...
# 363  Originally reported by: **Ronny Pfannschmidt (...
# 364  Originally reported by: **cjwatson (Bitbucket:...
# 365  Originally reported by: **Michael Salib (Bitbu...
# 366  Originally reported by: **Matt Chaput (Bitbuck...
# 367  Originally reported by: **Sridhar Ratnakumar (...
#
#                                              reactions  \
# 0    {'url': 'https://api.github.com/repos/benjamin...
# 1    {'url': 'https://api.github.com/repos/benjamin...
# 2    {'url': 'https://api.github.com/repos/benjamin...
# 3    {'url': 'https://api.github.com/repos/benjamin...
# 4    {'url': 'https://api.github.com/repos/benjamin...
# ..                                                 ...
# 363  {'url': 'https://api.github.com/repos/benjamin...
# 364  {'url': 'https://api.github.com/repos/benjamin...
# 365  {'url': 'https://api.github.com/repos/benjamin...
# 366  {'url': 'https://api.github.com/repos/benjamin...
# 367  {'url': 'https://api.github.com/repos/benjamin...
#
#                                           timeline_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 363  https://api.github.com/repos/benjaminp/six/iss...
# 364  https://api.github.com/repos/benjaminp/six/iss...
# 365  https://api.github.com/repos/benjaminp/six/iss...
# 366  https://api.github.com/repos/benjaminp/six/iss...
# 367  https://api.github.com/repos/benjaminp/six/iss...
#
#      performed_via_github_app  state_reason draft  \
# 0                         NaN          None   NaN
# 1                         NaN          None   NaN
# 2                         NaN          None   0.0
# 3                         NaN     completed   NaN
# 4                         NaN          None   0.0
# ..                        ...           ...   ...
# 363                       NaN     completed   NaN
# 364                       NaN     completed   NaN
# 365                       NaN     completed   NaN
# 366                       NaN     completed   NaN
# 367                       NaN     completed   NaN
#
#                                           pull_request
# 0                                                  NaN
# 1                                                  NaN
# 2    {'url': 'https://api.github.com/repos/benjamin...
# 3                                                  NaN
# 4    {'url': 'https://api.github.com/repos/benjamin...
# ..                                                 ...
# 363                                                NaN
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367                                                NaN
#
# [368 rows x 30 columns]

# %% [markdown]
# ##  Take Closed Data

# %% [markdown]
# This is code to take data that is stated "close".

# %%
List = []
for ind, col in df.iterrows():
    if col["state"] == "closed":
        List.extend(col["labels"])

# %%
List
# Out:
# [{'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582535,
#   'node_id': 'MDU6TGFiZWw1MTA1ODI1MzU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/trivial',
#   'name': 'trivial',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510584171,
#   'node_id': 'MDU6TGFiZWw1MTA1ODQxNzE=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/critical',
#   'name': 'critical',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510584434,
#   'node_id': 'MDU6TGFiZWw1MTA1ODQ0MzQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/blocker',
#   'name': 'blocker',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510584171,
#   'node_id': 'MDU6TGFiZWw1MTA1ODQxNzE=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/critical',
#   'name': 'critical',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582535,
#   'node_id': 'MDU6TGFiZWw1MTA1ODI1MzU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/trivial',
#   'name': 'trivial',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510584095,
#   'node_id': 'MDU6TGFiZWw1MTA1ODQwOTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/task',
#   'name': 'task',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582535,
#   'node_id': 'MDU6TGFiZWw1MTA1ODI1MzU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/trivial',
#   'name': 'trivial',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582535,
#   'node_id': 'MDU6TGFiZWw1MTA1ODI1MzU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/trivial',
#   'name': 'trivial',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582535,
#   'node_id': 'MDU6TGFiZWw1MTA1ODI1MzU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/trivial',
#   'name': 'trivial',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582535,
#   'node_id': 'MDU6TGFiZWw1MTA1ODI1MzU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/trivial',
#   'name': 'trivial',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582535,
#   'node_id': 'MDU6TGFiZWw1MTA1ODI1MzU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/trivial',
#   'name': 'trivial',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582535,
#   'node_id': 'MDU6TGFiZWw1MTA1ODI1MzU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/trivial',
#   'name': 'trivial',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582194,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTQ=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/enhancement',
#   'name': 'enhancement',
#   'color': '84b6eb',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582299,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyOTk=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/minor',
#   'name': 'minor',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582192,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIxOTI=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/bug',
#   'name': 'bug',
#   'color': 'ee0701',
#   'default': True,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582255,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTU=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/major',
#   'name': 'major',
#   'color': 'ededed',
#   'default': False,
#   'description': None},
#  {'id': 510582256,
#   'node_id': 'MDU6TGFiZWw1MTA1ODIyNTY=',
#   'url': 'https://api.github.com/repos/benjaminp/six/labels/proposal',
#   'name': 'proposal',
#   'color': 'ededed',
#   'default': False,
#   'description': None}]

# %% [markdown]
# Try make a method to flat nested labels data and append it on empty list.Make visualization of list of labels but there is a lot of duplication.

# %%
List_Labels = []
for i in range(len(List)):
    List_Labels.append(List[i]["name"])
pd.DataFrame(List_Labels)
# Out:
#             0
# 0         bug
# 1       major
# 2         bug
# 3       major
# 4         bug
# ..        ...
# 233  proposal
# 234       bug
# 235     major
# 236     major
# 237  proposal
#
# [238 rows x 1 columns]

# %% [markdown]
# Make visualization of list of labels but there is no duplication.

# %%
mylist = list(dict.fromkeys(List_Labels))
df_list_labels = pd.DataFrame(mylist)

# %%
df_list_labels
# Out:
#              0
# 0          bug
# 1        major
# 2     proposal
# 3        minor
# 4  enhancement
# 5      trivial
# 6     critical
# 7      blocker
# 8         task

# %%
df_list_labels.to_csv("List_of_Labels_No_Duplication.csv")

# %% [markdown]
# # After Classification

# %% [markdown]
# This code for reading csv dataset with classification labels

# %%
#Load Labels CSV
df_labels_classification = pd.read_csv("List_of_Labels_No_Duplication_Six.csv")
df_labels_classification
# Out:
#         Labels  Unrelated  Experts Labels  Newcomers Labels  Critical  \
# 0          bug      False            True              True     False
# 1        major      False            True             False     False
# 2     proposal      False            True              True     False
# 3        minor      False           False              True     False
# 4  enhancement      False            True             False     False
# 5      trivial      False           False              True     False
# 6     critical      False            True             False      True
# 7      blocker      False            True             False     False
# 8         task      False            True              True     False
#
#    NonCritical
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
# 5         True
# 6        False
# 7        False
# 8        False

# %% [markdown]
# # Slice only on boolean on Expert Labels

# %%
df_labels_classification['Experts Labels']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7     True
# 8     True
# Name: Experts Labels, dtype: bool

# %% [markdown]
# Change Boolean to String on Expert Labels and Newcomers Labels item.

# %%
df_labels_classification['Experts Labels'] = df_labels_classification['Experts Labels'].map({True: 'True', False: 'False'})

# %%
df_labels_classification['Newcomers Labels'] = df_labels_classification['Newcomers Labels'].map({True: 'True', False: 'False'})

# %% [markdown]
# Make query of take all labels that is True on Expert Labels.

# %%
Expert_labels_classification = df_labels_classification[df_labels_classification['Experts Labels'].str.contains("True") & df_labels_classification['Newcomers Labels'].str.contains("False")]

# %% [markdown]
# Make column Unnamed to Labels.

# %%
Expert_labels_classification.rename( columns={'Unnamed: 0':'Labels'}, inplace=True )
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# Show the result.

# %%
Expert_labels_classification
# Out:
#         Labels  Unrelated Experts Labels Newcomers Labels  Critical  \
# 1        major      False           True            False     False
# 4  enhancement      False           True            False     False
# 6     critical      False           True            False      True
# 7      blocker      False           True            False     False
#
#    NonCritical
# 1        False
# 4         True
# 6        False
# 7        False

# %% [markdown]
# Take item labels according on Expert classification

# %%
Expert_labels_classification['Labels']
# Out:
# 1          major
# 4    enhancement
# 6       critical
# 7        blocker
# Name: Labels, dtype: object

# %% [markdown]
# This code for take item labels from Expert classification

# %%
Expert_labels = Expert_labels_classification['Labels']

# %% [markdown]
# This code for making new csv with the list of expert labels

# %%
Expert_labels.to_csv("labels_expert.csv", index=False)

# %% [markdown]
# Load data expert labels from csv

# %%
df_labels_expert = pd.read_csv("labels_expert.csv")
df_labels_expert
# Out:
#         Labels
# 0        major
# 1  enhancement
# 2     critical
# 3      blocker

# %% [markdown]
# # Make query of take all labels that is True on Newcomers Labels.

# %%
Newcomers_labels_classification = df_labels_classification[df_labels_classification['Newcomers Labels'].str.contains("True")& df_labels_classification['Experts Labels'].str.contains("False")]

# %% [markdown]
# Make column Unnamed to Labels.

# %%
Newcomers_labels_classification.rename( columns={'Unnamed: 0':'Labels'}, inplace=True )
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# Show the result.

# %%
Newcomers_labels_classification
# Out:
#     Labels  Unrelated Experts Labels Newcomers Labels  Critical  NonCritical
# 3    minor      False          False             True     False        False
# 5  trivial      False          False             True     False         True

# %% [markdown]
# Take item labels according on Expert classification

# %%
Newcomers_labels_classification['Labels']
# Out:
# 3      minor
# 5    trivial
# Name: Labels, dtype: object

# %% [markdown]
# This code for take item labels from newcomers classification

# %%
Labels_Newcomers = Newcomers_labels_classification['Labels']

# %% [markdown]
# This code for take item labels from newcomers classification

# %%
Labels_Newcomers.to_csv("labels_newcomers.csv", index=False)

# %% [markdown]
# Load data newcomers labels from csv

# %%
df_labels_newcomers = pd.read_csv("labels_newcomers.csv")
df_labels_newcomers
# Out:
#     Labels
# 0    minor
# 1  trivial

# %% [markdown]
# # Make query of take all labels that is True on Experts and Newcomers Labels. (slice)

# %%
Expert_And_Newcomers_labels_classification = df_labels_classification[df_labels_classification['Experts Labels'].str.contains("True") & df_labels_classification['Newcomers Labels'].str.contains("True")]

# %% [markdown]
# Make column Unnamed to Labels.

# %%
Expert_And_Newcomers_labels_classification.rename( columns={'Unnamed: 0':'Labels'}, inplace=True )
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# Show the result.

# %%
Expert_And_Newcomers_labels_classification
# Out:
#      Labels  Unrelated Experts Labels Newcomers Labels  Critical  NonCritical
# 0       bug      False           True             True     False        False
# 2  proposal      False           True             True     False        False
# 8      task      False           True             True     False        False

# %% [markdown]
# Take item labels according on Newcomers and Expert classification

# %%
Expert_And_Newcomers_labels_classification["Labels"]
# Out:
# 0         bug
# 2    proposal
# 8        task
# Name: Labels, dtype: object

# %% [markdown]
# This code for take item labels from newcomers and experts classification

# %%
Labels_Expert_And_Newcomers = Expert_And_Newcomers_labels_classification["Labels"]

# %% [markdown]
# This code for making new csv with the list of newcomers and experts labels

# %%
Labels_Expert_And_Newcomers.to_csv("labels_experts_newcomers.csv", index=False)

# %% [markdown]
# Load data experts and newcomers labels from csv

# %%
df_labels_experts_newcomers = pd.read_csv("labels_experts_newcomers.csv")
df_labels_experts_newcomers
# Out:
#      Labels
# 0       bug
# 1  proposal
# 2      task

# %% [markdown]
# # Combine Newcomers and Experts

# %%
result = Labels_Newcomers.append(Expert_labels)
pd.DataFrame(result)
# Out:
#         Labels
# 3        minor
# 5      trivial
# 1        major
# 4  enhancement
# 6     critical
# 7      blocker

# %% [markdown]
# make it CSV

# %%
result.to_csv("labels_experts_newcomers_combined.csv", index=False)

# %% [markdown]
# show the result

# %%
df_labels_experts_newcomers_combined = pd.read_csv("labels_experts_newcomers_combined.csv")
df_labels_experts_newcomers_combined
# Out:
#         Labels
# 0        minor
# 1      trivial
# 2        major
# 3  enhancement
# 4     critical
# 5      blocker

# %% [markdown]
# # Try Make Query for Issues according Labels Newcomers, Expert and Both

# %% [markdown]
# Convert aws_aws-cdk_close.json to csv file

# %%
df.to_csv("benjaminp_six.csv",index=False)

# %% [markdown]
# Load aws_aws-cdk_close.csv

# %%
df2 = pd.read_csv("benjaminp_six.csv")
df2.index += 1 
df2
# Out:
#                                                    url  \
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# 5    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 364  https://api.github.com/repos/benjaminp/six/iss...
# 365  https://api.github.com/repos/benjaminp/six/iss...
# 366  https://api.github.com/repos/benjaminp/six/iss...
# 367  https://api.github.com/repos/benjaminp/six/iss...
# 368  https://api.github.com/repos/benjaminp/six/iss...
#
#                                  repository_url  \
# 1    https://api.github.com/repos/benjaminp/six
# 2    https://api.github.com/repos/benjaminp/six
# 3    https://api.github.com/repos/benjaminp/six
# 4    https://api.github.com/repos/benjaminp/six
# 5    https://api.github.com/repos/benjaminp/six
# ..                                          ...
# 364  https://api.github.com/repos/benjaminp/six
# 365  https://api.github.com/repos/benjaminp/six
# 366  https://api.github.com/repos/benjaminp/six
# 367  https://api.github.com/repos/benjaminp/six
# 368  https://api.github.com/repos/benjaminp/six
#
#                                             labels_url  \
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# 5    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 364  https://api.github.com/repos/benjaminp/six/iss...
# 365  https://api.github.com/repos/benjaminp/six/iss...
# 366  https://api.github.com/repos/benjaminp/six/iss...
# 367  https://api.github.com/repos/benjaminp/six/iss...
# 368  https://api.github.com/repos/benjaminp/six/iss...
#
#                                           comments_url  \
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# 5    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 364  https://api.github.com/repos/benjaminp/six/iss...
# 365  https://api.github.com/repos/benjaminp/six/iss...
# 366  https://api.github.com/repos/benjaminp/six/iss...
# 367  https://api.github.com/repos/benjaminp/six/iss...
# 368  https://api.github.com/repos/benjaminp/six/iss...
#
#                                             events_url  \
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# 5    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 364  https://api.github.com/repos/benjaminp/six/iss...
# 365  https://api.github.com/repos/benjaminp/six/iss...
# 366  https://api.github.com/repos/benjaminp/six/iss...
# 367  https://api.github.com/repos/benjaminp/six/iss...
# 368  https://api.github.com/repos/benjaminp/six/iss...
#
#                                         html_url          id  \
# 1    https://github.com/benjaminp/six/issues/369  1356705912
# 2    https://github.com/benjaminp/six/issues/368  1333446643
# 3      https://github.com/benjaminp/six/pull/367  1318748092
# 4    https://github.com/benjaminp/six/issues/366  1275941841
# 5      https://github.com/benjaminp/six/pull/365  1058874194
# ..                                           ...         ...
# 364    https://github.com/benjaminp/six/issues/5   198391151
# 365    https://github.com/benjaminp/six/issues/4   198391148
# 366    https://github.com/benjaminp/six/issues/3   198391144
# 367    https://github.com/benjaminp/six/issues/2   198391139
# 368    https://github.com/benjaminp/six/issues/1   198391131
#
#                       node_id  number  \
# 1          I_kwDOBKQuOM5Q3bB4     369
# 2          I_kwDOBKQuOM5Pesfz     368
# 3         PR_kwDOBKQuOM48I4Qs     367
# 4          I_kwDOBKQuOM5MDVPR     366
# 5         PR_kwDOBKQuOM4uygn_     365
# ..                        ...     ...
# 364  MDU6SXNzdWUxOTgzOTExNTE=       5
# 365  MDU6SXNzdWUxOTgzOTExNDg=       4
# 366  MDU6SXNzdWUxOTgzOTExNDQ=       3
# 367  MDU6SXNzdWUxOTgzOTExMzk=       2
# 368  MDU6SXNzdWUxOTgzOTExMzE=       1
#
#                                                  title  ...  \
# 1    RuntimeError: restricted attribute setting __d...  ...
# 2    ImportWarning: _SixMetaPathImporter.find_spec(...  ...
# 3                                            Add 3.10.  ...
# 4    can i use six just like run command on cmd lik...  ...
# 5                       Fix `UserDict` move in Python2  ...
# ..                                                 ...  ...
# 364  import hook for replacing except .. as .. with...  ...
# 365                      Include test suite in tarball  ...
# 366                                  map/filter issues  ...
# 367  u() function does not support unicode characte...  ...
# 368                                         ChangeLog?  ...
#
#                      closed_at author_association active_lock_reason  \
# 1                          NaN               NONE                NaN
# 2                          NaN               NONE                NaN
# 3    2022-07-26 21:03:11+00:00              OWNER                NaN
# 4    2022-07-26 20:59:22+00:00               NONE                NaN
# 5    2021-11-21 23:00:36+00:00        CONTRIBUTOR                NaN
# ..                         ...                ...                ...
# 364  2017-01-02 23:31:12+00:00              OWNER                NaN
# 365  2017-01-02 23:31:08+00:00              OWNER                NaN
# 366  2017-01-02 23:31:05+00:00              OWNER                NaN
# 367  2017-01-02 23:31:03+00:00              OWNER                NaN
# 368  2017-01-02 23:30:58+00:00              OWNER                NaN
#
#                                                   body  \
# 1    Hi!\r\nI'm writing a python program where I ne...
# 2    ```\r\nPython version: 3.10\r\nDjango version:...
# 3                                                  NaN
# 4    can i use six just like run command on cmd lik...
# 5    # Background\r\n\r\nThe current implementation...
# ..                                                 ...
# 364  Originally reported by: **Ronny Pfannschmidt (...
# 365  Originally reported by: **cjwatson (Bitbucket:...
# 366  Originally reported by: **Michael Salib (Bitbu...
# 367  Originally reported by: **Matt Chaput (Bitbuck...
# 368  Originally reported by: **Sridhar Ratnakumar (...
#
#                                              reactions  \
# 1    {'url': 'https://api.github.com/repos/benjamin...
# 2    {'url': 'https://api.github.com/repos/benjamin...
# 3    {'url': 'https://api.github.com/repos/benjamin...
# 4    {'url': 'https://api.github.com/repos/benjamin...
# 5    {'url': 'https://api.github.com/repos/benjamin...
# ..                                                 ...
# 364  {'url': 'https://api.github.com/repos/benjamin...
# 365  {'url': 'https://api.github.com/repos/benjamin...
# 366  {'url': 'https://api.github.com/repos/benjamin...
# 367  {'url': 'https://api.github.com/repos/benjamin...
# 368  {'url': 'https://api.github.com/repos/benjamin...
#
#                                           timeline_url  \
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# 5    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 364  https://api.github.com/repos/benjaminp/six/iss...
# 365  https://api.github.com/repos/benjaminp/six/iss...
# 366  https://api.github.com/repos/benjaminp/six/iss...
# 367  https://api.github.com/repos/benjaminp/six/iss...
# 368  https://api.github.com/repos/benjaminp/six/iss...
#
#      performed_via_github_app  state_reason draft  \
# 1                         NaN           NaN   NaN
# 2                         NaN           NaN   NaN
# 3                         NaN           NaN   0.0
# 4                         NaN     completed   NaN
# 5                         NaN           NaN   0.0
# ..                        ...           ...   ...
# 364                       NaN     completed   NaN
# 365                       NaN     completed   NaN
# 366                       NaN     completed   NaN
# 367                       NaN     completed   NaN
# 368                       NaN     completed   NaN
#
#                                           pull_request
# 1                                                  NaN
# 2                                                  NaN
# 3    {'url': 'https://api.github.com/repos/benjamin...
# 4                                                  NaN
# 5    {'url': 'https://api.github.com/repos/benjamin...
# ..                                                 ...
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367                                                NaN
# 368                                                NaN
#
# [368 rows x 30 columns]

# %%
df2.to_csv("benjaminp_six_index.csv",index=False)

# %% [markdown]
# # Newcomers

# %% [markdown]
# Add items in newcomers labels to an empty list.

# %%
List_Labels_Newcomers = []
for i in range(len(df_labels_newcomers)):
    List_Labels_Newcomers.append(df_labels_newcomers['Labels'][i])

# %% [markdown]
# This code is for querrying the datasets according list of labels of newcomers

# %%
df2_newcomers_labels = df2[df2['labels'].str.contains('|'.join(List_Labels_Newcomers))]

# %% [markdown]
# Show data newcomers labels

# %%
pd.DataFrame(df2_newcomers_labels['labels'])
# Out:
#                                                 labels
# 205  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 206  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 207  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 210  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 212  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 214  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 218  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 219  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 221  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 228  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 229  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 232  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 240  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 241  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 243  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 246  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 247  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 248  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 250  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 253  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 255  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 256  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 257  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 261  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 263  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 268  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 272  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 286  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 291  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 299  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 303  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 308  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 309  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 310  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 311  [{'id': 510582535, 'node_id': 'MDU6TGFiZWw1MTA...
# 317  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 322  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 323  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 325  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 327  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 332  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 333  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 335  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 336  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 339  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 347  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 348  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 349  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 352  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 354  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 355  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 358  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 359  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 361  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 362  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 364  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 365  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...

# %% [markdown]
# # Experts

# %% [markdown]
# Add items in Expert labels to an empty list.

# %%
List_Labels_Expert = []
for i in range(len(df_labels_expert)):
    List_Labels_Expert.append(df_labels_expert['Labels'][i])

# %% [markdown]
# This code is for querrying the datasets according list of labels of experts

# %%
df2_expert_labels = df2[df2['labels'].str.contains('|'.join(List_Labels_Expert))]

# %% [markdown]
# Show data expert labels

# %%
pd.DataFrame(df2_expert_labels['labels'])
# Out:
#                                                 labels
# 204  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 207  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 208  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 209  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 211  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# ..                                                 ...
# 362  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 363  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 366  [{'id': 510582255, 'node_id': 'MDU6TGFiZWw1MTA...
# 367  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 368  [{'id': 510582255, 'node_id': 'MDU6TGFiZWw1MTA...
#
# [130 rows x 1 columns]

# %% [markdown]
# # Both but sliced

# %% [markdown]
# Add items in experts and newcomers labels to an empty list.

# %%
List_Labels_Expert_Newcomers = []
for i in range(len(df_labels_experts_newcomers)):
    List_Labels_Expert_Newcomers.append(df_labels_experts_newcomers['Labels'][i])

# %% [markdown]
# This code is for querrying the datasets according list of labels of experts and newcomers

# %%
df2_expert_newcomers_labels = df2[df2['labels'].str.contains('|'.join(List_Labels_Expert_Newcomers))]

# %% [markdown]
# Show data expert and newcomers labels

# %%
pd.DataFrame(df2_expert_newcomers_labels['labels'])
# Out:
#                                                 labels
# 204  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 205  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 206  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 208  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 209  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# ..                                                 ...
# 364  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 365  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 366  [{'id': 510582255, 'node_id': 'MDU6TGFiZWw1MTA...
# 367  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 368  [{'id': 510582255, 'node_id': 'MDU6TGFiZWw1MTA...
#
# [114 rows x 1 columns]

# %% [markdown]
# # Both combined

# %% [markdown]
# combine label newcomers and experts

# %%
df2_expert_newcomers_labels_combined = df2_newcomers_labels.append(df2_expert_labels)

# %%
pd.DataFrame(df2_expert_newcomers_labels_combined['labels'])
# Out:
#                                                 labels
# 205  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 206  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 207  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 210  [{'id': 510582256, 'node_id': 'MDU6TGFiZWw1MTA...
# 212  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# ..                                                 ...
# 362  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 363  [{'id': 510582194, 'node_id': 'MDU6TGFiZWw1MTA...
# 366  [{'id': 510582255, 'node_id': 'MDU6TGFiZWw1MTA...
# 367  [{'id': 510582192, 'node_id': 'MDU6TGFiZWw1MTA...
# 368  [{'id': 510582255, 'node_id': 'MDU6TGFiZWw1MTA...
#
# [187 rows x 1 columns]

# %% [markdown]
# # Newcomers, Expert and both Dataset

# %% [markdown]
# Make 3 dataset csv file that is newcomers dataset, expert dataset and both

# %% [markdown]
# ## Newcomers

# %% [markdown]
# Make dataset csv according newcomers labels

# %%
df2_newcomers_labels.to_csv("data_newcomers.csv", index=False)

# %% [markdown]
# Read the dataset according newcomers labels

# %%
data_newcomers = pd.read_csv("data_newcomers.csv")
data_newcomers
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/benjaminp/six/iss...
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# 6   https://api.github.com/repos/benjaminp/six/iss...
# 7   https://api.github.com/repos/benjaminp/six/iss...
# 8   https://api.github.com/repos/benjaminp/six/iss...
# 9   https://api.github.com/repos/benjaminp/six/iss...
# 10  https://api.github.com/repos/benjaminp/six/iss...
# 11  https://api.github.com/repos/benjaminp/six/iss...
# 12  https://api.github.com/repos/benjaminp/six/iss...
# 13  https://api.github.com/repos/benjaminp/six/iss...
# 14  https://api.github.com/repos/benjaminp/six/iss...
# 15  https://api.github.com/repos/benjaminp/six/iss...
# 16  https://api.github.com/repos/benjaminp/six/iss...
# 17  https://api.github.com/repos/benjaminp/six/iss...
# 18  https://api.github.com/repos/benjaminp/six/iss...
# 19  https://api.github.com/repos/benjaminp/six/iss...
# 20  https://api.github.com/repos/benjaminp/six/iss...
# 21  https://api.github.com/repos/benjaminp/six/iss...
# 22  https://api.github.com/repos/benjaminp/six/iss...
# 23  https://api.github.com/repos/benjaminp/six/iss...
# 24  https://api.github.com/repos/benjaminp/six/iss...
# 25  https://api.github.com/repos/benjaminp/six/iss...
# 26  https://api.github.com/repos/benjaminp/six/iss...
# 27  https://api.github.com/repos/benjaminp/six/iss...
# 28  https://api.github.com/repos/benjaminp/six/iss...
# 29  https://api.github.com/repos/benjaminp/six/iss...
# 30  https://api.github.com/repos/benjaminp/six/iss...
# 31  https://api.github.com/repos/benjaminp/six/iss...
# 32  https://api.github.com/repos/benjaminp/six/iss...
# 33  https://api.github.com/repos/benjaminp/six/iss...
# 34  https://api.github.com/repos/benjaminp/six/iss...
# 35  https://api.github.com/repos/benjaminp/six/iss...
# 36  https://api.github.com/repos/benjaminp/six/iss...
# 37  https://api.github.com/repos/benjaminp/six/iss...
# 38  https://api.github.com/repos/benjaminp/six/iss...
# 39  https://api.github.com/repos/benjaminp/six/iss...
# 40  https://api.github.com/repos/benjaminp/six/iss...
# 41  https://api.github.com/repos/benjaminp/six/iss...
# 42  https://api.github.com/repos/benjaminp/six/iss...
# 43  https://api.github.com/repos/benjaminp/six/iss...
# 44  https://api.github.com/repos/benjaminp/six/iss...
# 45  https://api.github.com/repos/benjaminp/six/iss...
# 46  https://api.github.com/repos/benjaminp/six/iss...
# 47  https://api.github.com/repos/benjaminp/six/iss...
# 48  https://api.github.com/repos/benjaminp/six/iss...
# 49  https://api.github.com/repos/benjaminp/six/iss...
# 50  https://api.github.com/repos/benjaminp/six/iss...
# 51  https://api.github.com/repos/benjaminp/six/iss...
# 52  https://api.github.com/repos/benjaminp/six/iss...
# 53  https://api.github.com/repos/benjaminp/six/iss...
# 54  https://api.github.com/repos/benjaminp/six/iss...
# 55  https://api.github.com/repos/benjaminp/six/iss...
# 56  https://api.github.com/repos/benjaminp/six/iss...
#
#                                 repository_url  \
# 0   https://api.github.com/repos/benjaminp/six
# 1   https://api.github.com/repos/benjaminp/six
# 2   https://api.github.com/repos/benjaminp/six
# 3   https://api.github.com/repos/benjaminp/six
# 4   https://api.github.com/repos/benjaminp/six
# 5   https://api.github.com/repos/benjaminp/six
# 6   https://api.github.com/repos/benjaminp/six
# 7   https://api.github.com/repos/benjaminp/six
# 8   https://api.github.com/repos/benjaminp/six
# 9   https://api.github.com/repos/benjaminp/six
# 10  https://api.github.com/repos/benjaminp/six
# 11  https://api.github.com/repos/benjaminp/six
# 12  https://api.github.com/repos/benjaminp/six
# 13  https://api.github.com/repos/benjaminp/six
# 14  https://api.github.com/repos/benjaminp/six
# 15  https://api.github.com/repos/benjaminp/six
# 16  https://api.github.com/repos/benjaminp/six
# 17  https://api.github.com/repos/benjaminp/six
# 18  https://api.github.com/repos/benjaminp/six
# 19  https://api.github.com/repos/benjaminp/six
# 20  https://api.github.com/repos/benjaminp/six
# 21  https://api.github.com/repos/benjaminp/six
# 22  https://api.github.com/repos/benjaminp/six
# 23  https://api.github.com/repos/benjaminp/six
# 24  https://api.github.com/repos/benjaminp/six
# 25  https://api.github.com/repos/benjaminp/six
# 26  https://api.github.com/repos/benjaminp/six
# 27  https://api.github.com/repos/benjaminp/six
# 28  https://api.github.com/repos/benjaminp/six
# 29  https://api.github.com/repos/benjaminp/six
# 30  https://api.github.com/repos/benjaminp/six
# 31  https://api.github.com/repos/benjaminp/six
# 32  https://api.github.com/repos/benjaminp/six
# 33  https://api.github.com/repos/benjaminp/six
# 34  https://api.github.com/repos/benjaminp/six
# 35  https://api.github.com/repos/benjaminp/six
# 36  https://api.github.com/repos/benjaminp/six
# 37  https://api.github.com/repos/benjaminp/six
# 38  https://api.github.com/repos/benjaminp/six
# 39  https://api.github.com/repos/benjaminp/six
# 40  https://api.github.com/repos/benjaminp/six
# 41  https://api.github.com/repos/benjaminp/six
# 42  https://api.github.com/repos/benjaminp/six
# 43  https://api.github.com/repos/benjaminp/six
# 44  https://api.github.com/repos/benjaminp/six
# 45  https://api.github.com/repos/benjaminp/six
# 46  https://api.github.com/repos/benjaminp/six
# 47  https://api.github.com/repos/benjaminp/six
# 48  https://api.github.com/repos/benjaminp/six
# 49  https://api.github.com/repos/benjaminp/six
# 50  https://api.github.com/repos/benjaminp/six
# 51  https://api.github.com/repos/benjaminp/six
# 52  https://api.github.com/repos/benjaminp/six
# 53  https://api.github.com/repos/benjaminp/six
# 54  https://api.github.com/repos/benjaminp/six
# 55  https://api.github.com/repos/benjaminp/six
# 56  https://api.github.com/repos/benjaminp/six
#
#                                            labels_url  \
# 0   https://api.github.com/repos/benjaminp/six/iss...
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# 6   https://api.github.com/repos/benjaminp/six/iss...
# 7   https://api.github.com/repos/benjaminp/six/iss...
# 8   https://api.github.com/repos/benjaminp/six/iss...
# 9   https://api.github.com/repos/benjaminp/six/iss...
# 10  https://api.github.com/repos/benjaminp/six/iss...
# 11  https://api.github.com/repos/benjaminp/six/iss...
# 12  https://api.github.com/repos/benjaminp/six/iss...
# 13  https://api.github.com/repos/benjaminp/six/iss...
# 14  https://api.github.com/repos/benjaminp/six/iss...
# 15  https://api.github.com/repos/benjaminp/six/iss...
# 16  https://api.github.com/repos/benjaminp/six/iss...
# 17  https://api.github.com/repos/benjaminp/six/iss...
# 18  https://api.github.com/repos/benjaminp/six/iss...
# 19  https://api.github.com/repos/benjaminp/six/iss...
# 20  https://api.github.com/repos/benjaminp/six/iss...
# 21  https://api.github.com/repos/benjaminp/six/iss...
# 22  https://api.github.com/repos/benjaminp/six/iss...
# 23  https://api.github.com/repos/benjaminp/six/iss...
# 24  https://api.github.com/repos/benjaminp/six/iss...
# 25  https://api.github.com/repos/benjaminp/six/iss...
# 26  https://api.github.com/repos/benjaminp/six/iss...
# 27  https://api.github.com/repos/benjaminp/six/iss...
# 28  https://api.github.com/repos/benjaminp/six/iss...
# 29  https://api.github.com/repos/benjaminp/six/iss...
# 30  https://api.github.com/repos/benjaminp/six/iss...
# 31  https://api.github.com/repos/benjaminp/six/iss...
# 32  https://api.github.com/repos/benjaminp/six/iss...
# 33  https://api.github.com/repos/benjaminp/six/iss...
# 34  https://api.github.com/repos/benjaminp/six/iss...
# 35  https://api.github.com/repos/benjaminp/six/iss...
# 36  https://api.github.com/repos/benjaminp/six/iss...
# 37  https://api.github.com/repos/benjaminp/six/iss...
# 38  https://api.github.com/repos/benjaminp/six/iss...
# 39  https://api.github.com/repos/benjaminp/six/iss...
# 40  https://api.github.com/repos/benjaminp/six/iss...
# 41  https://api.github.com/repos/benjaminp/six/iss...
# 42  https://api.github.com/repos/benjaminp/six/iss...
# 43  https://api.github.com/repos/benjaminp/six/iss...
# 44  https://api.github.com/repos/benjaminp/six/iss...
# 45  https://api.github.com/repos/benjaminp/six/iss...
# 46  https://api.github.com/repos/benjaminp/six/iss...
# 47  https://api.github.com/repos/benjaminp/six/iss...
# 48  https://api.github.com/repos/benjaminp/six/iss...
# 49  https://api.github.com/repos/benjaminp/six/iss...
# 50  https://api.github.com/repos/benjaminp/six/iss...
# 51  https://api.github.com/repos/benjaminp/six/iss...
# 52  https://api.github.com/repos/benjaminp/six/iss...
# 53  https://api.github.com/repos/benjaminp/six/iss...
# 54  https://api.github.com/repos/benjaminp/six/iss...
# 55  https://api.github.com/repos/benjaminp/six/iss...
# 56  https://api.github.com/repos/benjaminp/six/iss...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/benjaminp/six/iss...
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# 6   https://api.github.com/repos/benjaminp/six/iss...
# 7   https://api.github.com/repos/benjaminp/six/iss...
# 8   https://api.github.com/repos/benjaminp/six/iss...
# 9   https://api.github.com/repos/benjaminp/six/iss...
# 10  https://api.github.com/repos/benjaminp/six/iss...
# 11  https://api.github.com/repos/benjaminp/six/iss...
# 12  https://api.github.com/repos/benjaminp/six/iss...
# 13  https://api.github.com/repos/benjaminp/six/iss...
# 14  https://api.github.com/repos/benjaminp/six/iss...
# 15  https://api.github.com/repos/benjaminp/six/iss...
# 16  https://api.github.com/repos/benjaminp/six/iss...
# 17  https://api.github.com/repos/benjaminp/six/iss...
# 18  https://api.github.com/repos/benjaminp/six/iss...
# 19  https://api.github.com/repos/benjaminp/six/iss...
# 20  https://api.github.com/repos/benjaminp/six/iss...
# 21  https://api.github.com/repos/benjaminp/six/iss...
# 22  https://api.github.com/repos/benjaminp/six/iss...
# 23  https://api.github.com/repos/benjaminp/six/iss...
# 24  https://api.github.com/repos/benjaminp/six/iss...
# 25  https://api.github.com/repos/benjaminp/six/iss...
# 26  https://api.github.com/repos/benjaminp/six/iss...
# 27  https://api.github.com/repos/benjaminp/six/iss...
# 28  https://api.github.com/repos/benjaminp/six/iss...
# 29  https://api.github.com/repos/benjaminp/six/iss...
# 30  https://api.github.com/repos/benjaminp/six/iss...
# 31  https://api.github.com/repos/benjaminp/six/iss...
# 32  https://api.github.com/repos/benjaminp/six/iss...
# 33  https://api.github.com/repos/benjaminp/six/iss...
# 34  https://api.github.com/repos/benjaminp/six/iss...
# 35  https://api.github.com/repos/benjaminp/six/iss...
# 36  https://api.github.com/repos/benjaminp/six/iss...
# 37  https://api.github.com/repos/benjaminp/six/iss...
# 38  https://api.github.com/repos/benjaminp/six/iss...
# 39  https://api.github.com/repos/benjaminp/six/iss...
# 40  https://api.github.com/repos/benjaminp/six/iss...
# 41  https://api.github.com/repos/benjaminp/six/iss...
# 42  https://api.github.com/repos/benjaminp/six/iss...
# 43  https://api.github.com/repos/benjaminp/six/iss...
# 44  https://api.github.com/repos/benjaminp/six/iss...
# 45  https://api.github.com/repos/benjaminp/six/iss...
# 46  https://api.github.com/repos/benjaminp/six/iss...
# 47  https://api.github.com/repos/benjaminp/six/iss...
# 48  https://api.github.com/repos/benjaminp/six/iss...
# 49  https://api.github.com/repos/benjaminp/six/iss...
# 50  https://api.github.com/repos/benjaminp/six/iss...
# 51  https://api.github.com/repos/benjaminp/six/iss...
# 52  https://api.github.com/repos/benjaminp/six/iss...
# 53  https://api.github.com/repos/benjaminp/six/iss...
# 54  https://api.github.com/repos/benjaminp/six/iss...
# 55  https://api.github.com/repos/benjaminp/six/iss...
# 56  https://api.github.com/repos/benjaminp/six/iss...
#
#                                            events_url  \
# 0   https://api.github.com/repos/benjaminp/six/iss...
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# 6   https://api.github.com/repos/benjaminp/six/iss...
# 7   https://api.github.com/repos/benjaminp/six/iss...
# 8   https://api.github.com/repos/benjaminp/six/iss...
# 9   https://api.github.com/repos/benjaminp/six/iss...
# 10  https://api.github.com/repos/benjaminp/six/iss...
# 11  https://api.github.com/repos/benjaminp/six/iss...
# 12  https://api.github.com/repos/benjaminp/six/iss...
# 13  https://api.github.com/repos/benjaminp/six/iss...
# 14  https://api.github.com/repos/benjaminp/six/iss...
# 15  https://api.github.com/repos/benjaminp/six/iss...
# 16  https://api.github.com/repos/benjaminp/six/iss...
# 17  https://api.github.com/repos/benjaminp/six/iss...
# 18  https://api.github.com/repos/benjaminp/six/iss...
# 19  https://api.github.com/repos/benjaminp/six/iss...
# 20  https://api.github.com/repos/benjaminp/six/iss...
# 21  https://api.github.com/repos/benjaminp/six/iss...
# 22  https://api.github.com/repos/benjaminp/six/iss...
# 23  https://api.github.com/repos/benjaminp/six/iss...
# 24  https://api.github.com/repos/benjaminp/six/iss...
# 25  https://api.github.com/repos/benjaminp/six/iss...
# 26  https://api.github.com/repos/benjaminp/six/iss...
# 27  https://api.github.com/repos/benjaminp/six/iss...
# 28  https://api.github.com/repos/benjaminp/six/iss...
# 29  https://api.github.com/repos/benjaminp/six/iss...
# 30  https://api.github.com/repos/benjaminp/six/iss...
# 31  https://api.github.com/repos/benjaminp/six/iss...
# 32  https://api.github.com/repos/benjaminp/six/iss...
# 33  https://api.github.com/repos/benjaminp/six/iss...
# 34  https://api.github.com/repos/benjaminp/six/iss...
# 35  https://api.github.com/repos/benjaminp/six/iss...
# 36  https://api.github.com/repos/benjaminp/six/iss...
# 37  https://api.github.com/repos/benjaminp/six/iss...
# 38  https://api.github.com/repos/benjaminp/six/iss...
# 39  https://api.github.com/repos/benjaminp/six/iss...
# 40  https://api.github.com/repos/benjaminp/six/iss...
# 41  https://api.github.com/repos/benjaminp/six/iss...
# 42  https://api.github.com/repos/benjaminp/six/iss...
# 43  https://api.github.com/repos/benjaminp/six/iss...
# 44  https://api.github.com/repos/benjaminp/six/iss...
# 45  https://api.github.com/repos/benjaminp/six/iss...
# 46  https://api.github.com/repos/benjaminp/six/iss...
# 47  https://api.github.com/repos/benjaminp/six/iss...
# 48  https://api.github.com/repos/benjaminp/six/iss...
# 49  https://api.github.com/repos/benjaminp/six/iss...
# 50  https://api.github.com/repos/benjaminp/six/iss...
# 51  https://api.github.com/repos/benjaminp/six/iss...
# 52  https://api.github.com/repos/benjaminp/six/iss...
# 53  https://api.github.com/repos/benjaminp/six/iss...
# 54  https://api.github.com/repos/benjaminp/six/iss...
# 55  https://api.github.com/repos/benjaminp/six/iss...
# 56  https://api.github.com/repos/benjaminp/six/iss...
#
#                                        html_url         id  \
# 0   https://github.com/benjaminp/six/issues/164  198392051
# 1   https://github.com/benjaminp/six/issues/163  198392047
# 2   https://github.com/benjaminp/six/issues/162  198392041
# 3   https://github.com/benjaminp/six/issues/159  198392027
# 4   https://github.com/benjaminp/six/issues/157  198392024
# 5   https://github.com/benjaminp/six/issues/155  198392017
# 6   https://github.com/benjaminp/six/issues/151  198391999
# 7   https://github.com/benjaminp/six/issues/150  198391996
# 8   https://github.com/benjaminp/six/issues/148  198391989
# 9   https://github.com/benjaminp/six/issues/141  198391963
# 10  https://github.com/benjaminp/six/issues/140  198391962
# 11  https://github.com/benjaminp/six/issues/137  198391948
# 12  https://github.com/benjaminp/six/issues/129  198391911
# 13  https://github.com/benjaminp/six/issues/128  198391910
# 14  https://github.com/benjaminp/six/issues/126  198391904
# 15  https://github.com/benjaminp/six/issues/123  198391896
# 16  https://github.com/benjaminp/six/issues/122  198391891
# 17  https://github.com/benjaminp/six/issues/121  198391888
# 18  https://github.com/benjaminp/six/issues/119  198391878
# 19  https://github.com/benjaminp/six/issues/116  198391864
# 20  https://github.com/benjaminp/six/issues/114  198391855
# 21  https://github.com/benjaminp/six/issues/113  198391850
# 22  https://github.com/benjaminp/six/issues/112  198391846
# 23  https://github.com/benjaminp/six/issues/108  198391782
# 24  https://github.com/benjaminp/six/issues/106  198391773
# 25  https://github.com/benjaminp/six/issues/101  198391745
# 26   https://github.com/benjaminp/six/issues/97  198391722
# 27   https://github.com/benjaminp/six/issues/83  198391671
# 28   https://github.com/benjaminp/six/issues/78  198391651
# 29   https://github.com/benjaminp/six/issues/70  198391621
# 30   https://github.com/benjaminp/six/issues/66  198391601
# 31   https://github.com/benjaminp/six/issues/61  198391578
# 32   https://github.com/benjaminp/six/issues/60  198391571
# 33   https://github.com/benjaminp/six/issues/59  198391566
# 34   https://github.com/benjaminp/six/issues/58  198391563
# 35   https://github.com/benjaminp/six/issues/52  198391446
# 36   https://github.com/benjaminp/six/issues/47  198391424
# 37   https://github.com/benjaminp/six/issues/46  198391418
# 38   https://github.com/benjaminp/six/issues/44  198391404
# 39   https://github.com/benjaminp/six/issues/42  198391396
# 40   https://github.com/benjaminp/six/issues/37  198391379
# 41   https://github.com/benjaminp/six/issues/36  198391374
# 42   https://github.com/benjaminp/six/issues/34  198391364
# 43   https://github.com/benjaminp/six/issues/33  198391360
# 44   https://github.com/benjaminp/six/issues/30  198391353
# 45   https://github.com/benjaminp/six/issues/22  198391320
# 46   https://github.com/benjaminp/six/issues/21  198391312
# 47   https://github.com/benjaminp/six/issues/20  198391307
# 48   https://github.com/benjaminp/six/issues/17  198391293
# 49   https://github.com/benjaminp/six/issues/15  198391285
# 50   https://github.com/benjaminp/six/issues/14  198391277
# 51   https://github.com/benjaminp/six/issues/11  198391259
# 52   https://github.com/benjaminp/six/issues/10  198391256
# 53    https://github.com/benjaminp/six/issues/8  198391231
# 54    https://github.com/benjaminp/six/issues/7  198391206
# 55    https://github.com/benjaminp/six/issues/5  198391151
# 56    https://github.com/benjaminp/six/issues/4  198391148
#
#                      node_id  number  \
# 0   MDU6SXNzdWUxOTgzOTIwNTE=     164
# 1   MDU6SXNzdWUxOTgzOTIwNDc=     163
# 2   MDU6SXNzdWUxOTgzOTIwNDE=     162
# 3   MDU6SXNzdWUxOTgzOTIwMjc=     159
# 4   MDU6SXNzdWUxOTgzOTIwMjQ=     157
# 5   MDU6SXNzdWUxOTgzOTIwMTc=     155
# 6   MDU6SXNzdWUxOTgzOTE5OTk=     151
# 7   MDU6SXNzdWUxOTgzOTE5OTY=     150
# 8   MDU6SXNzdWUxOTgzOTE5ODk=     148
# 9   MDU6SXNzdWUxOTgzOTE5NjM=     141
# 10  MDU6SXNzdWUxOTgzOTE5NjI=     140
# 11  MDU6SXNzdWUxOTgzOTE5NDg=     137
# 12  MDU6SXNzdWUxOTgzOTE5MTE=     129
# 13  MDU6SXNzdWUxOTgzOTE5MTA=     128
# 14  MDU6SXNzdWUxOTgzOTE5MDQ=     126
# 15  MDU6SXNzdWUxOTgzOTE4OTY=     123
# 16  MDU6SXNzdWUxOTgzOTE4OTE=     122
# 17  MDU6SXNzdWUxOTgzOTE4ODg=     121
# 18  MDU6SXNzdWUxOTgzOTE4Nzg=     119
# 19  MDU6SXNzdWUxOTgzOTE4NjQ=     116
# 20  MDU6SXNzdWUxOTgzOTE4NTU=     114
# 21  MDU6SXNzdWUxOTgzOTE4NTA=     113
# 22  MDU6SXNzdWUxOTgzOTE4NDY=     112
# 23  MDU6SXNzdWUxOTgzOTE3ODI=     108
# 24  MDU6SXNzdWUxOTgzOTE3NzM=     106
# 25  MDU6SXNzdWUxOTgzOTE3NDU=     101
# 26  MDU6SXNzdWUxOTgzOTE3MjI=      97
# 27  MDU6SXNzdWUxOTgzOTE2NzE=      83
# 28  MDU6SXNzdWUxOTgzOTE2NTE=      78
# 29  MDU6SXNzdWUxOTgzOTE2MjE=      70
# 30  MDU6SXNzdWUxOTgzOTE2MDE=      66
# 31  MDU6SXNzdWUxOTgzOTE1Nzg=      61
# 32  MDU6SXNzdWUxOTgzOTE1NzE=      60
# 33  MDU6SXNzdWUxOTgzOTE1NjY=      59
# 34  MDU6SXNzdWUxOTgzOTE1NjM=      58
# 35  MDU6SXNzdWUxOTgzOTE0NDY=      52
# 36  MDU6SXNzdWUxOTgzOTE0MjQ=      47
# 37  MDU6SXNzdWUxOTgzOTE0MTg=      46
# 38  MDU6SXNzdWUxOTgzOTE0MDQ=      44
# 39  MDU6SXNzdWUxOTgzOTEzOTY=      42
# 40  MDU6SXNzdWUxOTgzOTEzNzk=      37
# 41  MDU6SXNzdWUxOTgzOTEzNzQ=      36
# 42  MDU6SXNzdWUxOTgzOTEzNjQ=      34
# 43  MDU6SXNzdWUxOTgzOTEzNjA=      33
# 44  MDU6SXNzdWUxOTgzOTEzNTM=      30
# 45  MDU6SXNzdWUxOTgzOTEzMjA=      22
# 46  MDU6SXNzdWUxOTgzOTEzMTI=      21
# 47  MDU6SXNzdWUxOTgzOTEzMDc=      20
# 48  MDU6SXNzdWUxOTgzOTEyOTM=      17
# 49  MDU6SXNzdWUxOTgzOTEyODU=      15
# 50  MDU6SXNzdWUxOTgzOTEyNzc=      14
# 51  MDU6SXNzdWUxOTgzOTEyNTk=      11
# 52  MDU6SXNzdWUxOTgzOTEyNTY=      10
# 53  MDU6SXNzdWUxOTgzOTEyMzE=       8
# 54  MDU6SXNzdWUxOTgzOTEyMDY=       7
# 55  MDU6SXNzdWUxOTgzOTExNTE=       5
# 56  MDU6SXNzdWUxOTgzOTExNDg=       4
#
#                                                 title  ...  \
# 0                                         assertRegex  ...
# 1   int2byte does not match documentation on Python 3  ...
# 2                     Match Python 3 metaclass syntax  ...
# 3                                      Add cgi.escape  ...
# 4         six.moves.builtins causes strange exception  ...
# 5                       Add six.moves.collections.abc  ...
# 6   six.hasattr()? Behaving like Python 3 - not sw...  ...
# 7                           RemovedInDjango110Warning  ...
# 8   Add __repr__ support to @python_2_unicode_comp...  ...
# 9                         string module methods moved  ...
# 10                          six.moves.BytesFeedParser  ...
# 11                       Please add per-file licenses  ...
# 12               Add license headers to source files.  ...
# 13  Add functions to get list of keys, values and ...  ...
# 14                                    Deprecate exec_  ...
# 15  Copying sys.meta_path can fail on six._SixMeta...  ...
# 16         Improve int2byte() performance on Python 3  ...
# 17  Remove superfluous iter()-calls in PY2 iterkey...  ...
# 18                                 Add abc.ABC class?  ...
# 19        Enable importing from within custom renames  ...
# 20    unittest discovery six.moves.urllib ImportError  ...
# 21                      Test failures with Python 3.1  ...
# 22  six.moves.reload_module uses deprecated imp mo...  ...
# 23          getcwd is renamed between pythons 2 and 3  ...
# 24              print_ should support flush parameter  ...
# 25  generator.throw(type[, value[, traceback]]) mi...  ...
# 26          Performance improvement for six.iterbytes  ...
# 27                   with_meta and stack frame issues  ...
# 28                            New built-in exceptions  ...
# 29                             thread.get_ident moved  ...
# 30  Replace the implementation of `six.with_metacl...  ...
# 31                                  missing file type  ...
# 32        six.u mishandles string ending in backslash  ...
# 33                            missing intern function  ...
# 34  http://pythonhosted.org/six/ docs are not up t...  ...
# 35              test_move_items fails with Python 2.6  ...
# 36  add_metaclass doesn't account for string __slo...  ...
# 37                      six, commands, and subprocess  ...
# 38  six.u(r'\\') behaves differently on Python 2.x...  ...
# 39                       OrderedDict for python < 2.7  ...
# 40                        "five" link goes to nothing  ...
# 41                               docs for print wrong  ...
# 42        dir(six.moves.<module>) is lazily populated  ...
# 43    Docs for urllib.parse don't mention ParseResult  ...
# 44  Add a function for "true" if 1 == 1 else "fals...  ...
# 45            variable ``six.PY3`` -- is time bomb :)  ...
# 46      Additional object model compatibility methods  ...
# 47  python-six checks fail on GNU/Linux if tkinter...  ...
# 48  Six defines its own callable() on Py3 even if ...  ...
# 49  Could do with some decorators for the __unicod...  ...
# 50  Six does not allow multiple distinct instances...  ...
# 51                   Jython compatibility in setup.py  ...
# 52                                 raw_input v. input  ...
# 53                         Script to “six-ify” source  ...
# 54  Address Python 2/3’s different Exception hiera...  ...
# 55  import hook for replacing except .. as .. with...  ...
# 56                      Include test suite in tarball  ...
#
#                     closed_at author_association active_lock_reason  \
# 0                         NaN              OWNER                NaN
# 1                         NaN              OWNER                NaN
# 2                         NaN              OWNER                NaN
# 3                         NaN              OWNER                NaN
# 4                         NaN              OWNER                NaN
# 5   2019-11-05 07:21:56+00:00              OWNER                NaN
# 6                         NaN              OWNER                NaN
# 7   2017-01-02 23:43:21+00:00              OWNER                NaN
# 8                         NaN              OWNER                NaN
# 9                         NaN              OWNER                NaN
# 10                        NaN              OWNER                NaN
# 11  2017-01-02 23:42:50+00:00              OWNER                NaN
# 12  2017-01-02 23:42:13+00:00              OWNER                NaN
# 13                        NaN              OWNER                NaN
# 14                        NaN              OWNER                NaN
# 15                        NaN              OWNER                NaN
# 16  2017-01-02 23:41:58+00:00              OWNER                NaN
# 17  2017-01-02 23:41:55+00:00              OWNER                NaN
# 18                        NaN              OWNER                NaN
# 19                        NaN              OWNER                NaN
# 20                        NaN              OWNER                NaN
# 21  2017-01-02 23:41:18+00:00              OWNER                NaN
# 22  2017-01-02 23:41:15+00:00              OWNER                NaN
# 23  2017-01-02 23:40:03+00:00              OWNER                NaN
# 24  2017-01-02 23:39:54+00:00              OWNER                NaN
# 25                        NaN              OWNER                NaN
# 26  2017-01-02 23:39:13+00:00              OWNER                NaN
# 27                        NaN              OWNER                NaN
# 28  2017-01-02 23:38:17+00:00              OWNER                NaN
# 29  2017-01-02 23:37:53+00:00              OWNER                NaN
# 30  2017-01-02 23:37:32+00:00              OWNER                NaN
# 31                        NaN              OWNER                NaN
# 32  2020-11-05 18:11:21+00:00              OWNER                NaN
# 33  2017-01-02 23:37:07+00:00              OWNER                NaN
# 34  2017-01-02 23:37:05+00:00              OWNER                NaN
# 35  2017-01-02 23:35:21+00:00              OWNER                NaN
# 36  2017-01-02 23:35:03+00:00              OWNER                NaN
# 37  2017-03-01 05:37:14+00:00              OWNER                NaN
# 38  2017-01-02 23:34:45+00:00              OWNER                NaN
# 39  2017-01-02 23:34:39+00:00              OWNER                NaN
# 40  2017-01-02 23:34:22+00:00              OWNER                NaN
# 41  2017-01-02 23:34:19+00:00              OWNER                NaN
# 42  2017-01-02 23:34:12+00:00              OWNER                NaN
# 43  2017-01-02 23:34:09+00:00              OWNER                NaN
# 44  2017-01-02 23:34:01+00:00              OWNER                NaN
# 45  2017-01-02 23:33:38+00:00              OWNER                NaN
# 46  2017-01-02 23:33:33+00:00              OWNER                NaN
# 47  2017-01-02 23:33:29+00:00              OWNER                NaN
# 48  2017-01-02 23:33:18+00:00              OWNER                NaN
# 49  2017-01-02 23:33:09+00:00              OWNER                NaN
# 50  2017-01-02 23:33:02+00:00              OWNER                NaN
# 51  2017-01-02 23:32:45+00:00              OWNER                NaN
# 52  2017-01-02 23:32:42+00:00              OWNER                NaN
# 53  2017-01-02 23:32:30+00:00              OWNER                NaN
# 54  2017-01-02 23:31:57+00:00              OWNER                NaN
# 55  2017-01-02 23:31:12+00:00              OWNER                NaN
# 56  2017-01-02 23:31:08+00:00              OWNER                NaN
#
#                                                  body  \
# 0   Originally reported by: **Arthur Goldberg (Bit...
# 1   Originally reported by: **Evan (Bitbucket: [ev...
# 2   Originally reported by: **Evan (Bitbucket: [ev...
# 3   Originally reported by: **Anonymous**\n\n-----...
# 4   Originally reported by: **Anonymous**\n\n-----...
# 5   Originally reported by: **Eklavya Sharma (Bitb...
# 6   Originally reported by: **Alex Willmer (Bitbuc...
# 7   Originally reported by: **Ernest Prabhakar (Bi...
# 8   Originally reported by: **Anonymous**\n\n-----...
# 9   Originally reported by: **Pedro Rodrigues (Bit...
# 10  Originally reported by: **JocelynDelalande (Bi...
# 11  Originally reported by: **petrcermak (Bitbucke...
# 12  Originally reported by: **philbeaudoin (Bitbuc...
# 13  Originally reported by: **Antti Haapala (Bitbu...
# 14  Originally reported by: **Antti Haapala (Bitbu...
# 15  Originally reported by: **marmaduke woodman (B...
# 16  Originally reported by: **Wouter Bolsterlee (B...
# 17  Originally reported by: **Sebastian Bank (Bitb...
# 18  Originally reported by: **Antoine Pitrou (Bitb...
# 19  Originally reported by: **Björn Pollex (Bitbuc...
# 20  Originally reported by: **Anonymous**\n\n-----...
# 21  Originally reported by: **Arfrever Frehtes Tai...
# 22  Originally reported by: **Tim Graham (Bitbucke...
# 23  Originally reported by: **Max Grender-Jones (B...
# 24  Originally reported by: **Maik Riechert (Bitbu...
# 25  Originally reported by: **Maik Riechert (Bitbu...
# 26  Originally reported by: **Wouter Bolsterlee (B...
# 27  Originally reported by: **faassen (Bitbucket: ...
# 28  Originally reported by: **Zhen Wang (Bitbucket...
# 29  Originally reported by: **Joshua Harlow (Bitbu...
# 30  Originally reported by: **charettes (Bitbucket...
# 31  Originally reported by: **Peter Bigot (Bitbuck...
# 32  Originally reported by: **Peter Bigot (Bitbuck...
# 33  Originally reported by: **Peter Bigot (Bitbuck...
# 34  Originally reported by: **Marc Abramowitz (Bit...
# 35  Originally reported by: **Arfrever Frehtes Tai...
# 36  Originally reported by: **Alex Gaynor (Bitbuck...
# 37  Originally reported by: **kyleabeauchamp (Bitb...
# 38  Originally reported by: **daviddrysdale (Bitbu...
# 39  Originally reported by: **Konsta Vesterinen (B...
# 40  Originally reported by: **Georg Brandl (Bitbuc...
# 41  Originally reported by: **Robert Robert (Bitbu...
# 42  Originally reported by: **Marc Abramowitz (Bit...
# 43  Originally reported by: **Aymeric Augustin (Bi...
# 44  Originally reported by: **Anonymous**\n\n-----...
# 45  Originally reported by: **Andrej Antonov (Bitb...
# 46  Originally reported by: **Aymeric Augustin (Bi...
# 47  Originally reported by: **Anonymous**\n\n-----...
# 48  Originally reported by: **Ned Batchelder (Bitb...
# 49  Originally reported by: **Tom Grainger (Bitbuc...
# 50  Originally reported by: **Bryce Boe (Bitbucket...
# 51  Originally reported by: **squeaky (Bitbucket: ...
# 52  Originally reported by: **Bryce Boe (Bitbucket...
# 53  Originally reported by: **Zearin (Bitbucket: [...
# 54  Originally reported by: **Zearin (Bitbucket: [...
# 55  Originally reported by: **Ronny Pfannschmidt (...
# 56  Originally reported by: **cjwatson (Bitbucket:...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/benjamin...
# 1   {'url': 'https://api.github.com/repos/benjamin...
# 2   {'url': 'https://api.github.com/repos/benjamin...
# 3   {'url': 'https://api.github.com/repos/benjamin...
# 4   {'url': 'https://api.github.com/repos/benjamin...
# 5   {'url': 'https://api.github.com/repos/benjamin...
# 6   {'url': 'https://api.github.com/repos/benjamin...
# 7   {'url': 'https://api.github.com/repos/benjamin...
# 8   {'url': 'https://api.github.com/repos/benjamin...
# 9   {'url': 'https://api.github.com/repos/benjamin...
# 10  {'url': 'https://api.github.com/repos/benjamin...
# 11  {'url': 'https://api.github.com/repos/benjamin...
# 12  {'url': 'https://api.github.com/repos/benjamin...
# 13  {'url': 'https://api.github.com/repos/benjamin...
# 14  {'url': 'https://api.github.com/repos/benjamin...
# 15  {'url': 'https://api.github.com/repos/benjamin...
# 16  {'url': 'https://api.github.com/repos/benjamin...
# 17  {'url': 'https://api.github.com/repos/benjamin...
# 18  {'url': 'https://api.github.com/repos/benjamin...
# 19  {'url': 'https://api.github.com/repos/benjamin...
# 20  {'url': 'https://api.github.com/repos/benjamin...
# 21  {'url': 'https://api.github.com/repos/benjamin...
# 22  {'url': 'https://api.github.com/repos/benjamin...
# 23  {'url': 'https://api.github.com/repos/benjamin...
# 24  {'url': 'https://api.github.com/repos/benjamin...
# 25  {'url': 'https://api.github.com/repos/benjamin...
# 26  {'url': 'https://api.github.com/repos/benjamin...
# 27  {'url': 'https://api.github.com/repos/benjamin...
# 28  {'url': 'https://api.github.com/repos/benjamin...
# 29  {'url': 'https://api.github.com/repos/benjamin...
# 30  {'url': 'https://api.github.com/repos/benjamin...
# 31  {'url': 'https://api.github.com/repos/benjamin...
# 32  {'url': 'https://api.github.com/repos/benjamin...
# 33  {'url': 'https://api.github.com/repos/benjamin...
# 34  {'url': 'https://api.github.com/repos/benjamin...
# 35  {'url': 'https://api.github.com/repos/benjamin...
# 36  {'url': 'https://api.github.com/repos/benjamin...
# 37  {'url': 'https://api.github.com/repos/benjamin...
# 38  {'url': 'https://api.github.com/repos/benjamin...
# 39  {'url': 'https://api.github.com/repos/benjamin...
# 40  {'url': 'https://api.github.com/repos/benjamin...
# 41  {'url': 'https://api.github.com/repos/benjamin...
# 42  {'url': 'https://api.github.com/repos/benjamin...
# 43  {'url': 'https://api.github.com/repos/benjamin...
# 44  {'url': 'https://api.github.com/repos/benjamin...
# 45  {'url': 'https://api.github.com/repos/benjamin...
# 46  {'url': 'https://api.github.com/repos/benjamin...
# 47  {'url': 'https://api.github.com/repos/benjamin...
# 48  {'url': 'https://api.github.com/repos/benjamin...
# 49  {'url': 'https://api.github.com/repos/benjamin...
# 50  {'url': 'https://api.github.com/repos/benjamin...
# 51  {'url': 'https://api.github.com/repos/benjamin...
# 52  {'url': 'https://api.github.com/repos/benjamin...
# 53  {'url': 'https://api.github.com/repos/benjamin...
# 54  {'url': 'https://api.github.com/repos/benjamin...
# 55  {'url': 'https://api.github.com/repos/benjamin...
# 56  {'url': 'https://api.github.com/repos/benjamin...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/benjaminp/six/iss...
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# 6   https://api.github.com/repos/benjaminp/six/iss...
# 7   https://api.github.com/repos/benjaminp/six/iss...
# 8   https://api.github.com/repos/benjaminp/six/iss...
# 9   https://api.github.com/repos/benjaminp/six/iss...
# 10  https://api.github.com/repos/benjaminp/six/iss...
# 11  https://api.github.com/repos/benjaminp/six/iss...
# 12  https://api.github.com/repos/benjaminp/six/iss...
# 13  https://api.github.com/repos/benjaminp/six/iss...
# 14  https://api.github.com/repos/benjaminp/six/iss...
# 15  https://api.github.com/repos/benjaminp/six/iss...
# 16  https://api.github.com/repos/benjaminp/six/iss...
# 17  https://api.github.com/repos/benjaminp/six/iss...
# 18  https://api.github.com/repos/benjaminp/six/iss...
# 19  https://api.github.com/repos/benjaminp/six/iss...
# 20  https://api.github.com/repos/benjaminp/six/iss...
# 21  https://api.github.com/repos/benjaminp/six/iss...
# 22  https://api.github.com/repos/benjaminp/six/iss...
# 23  https://api.github.com/repos/benjaminp/six/iss...
# 24  https://api.github.com/repos/benjaminp/six/iss...
# 25  https://api.github.com/repos/benjaminp/six/iss...
# 26  https://api.github.com/repos/benjaminp/six/iss...
# 27  https://api.github.com/repos/benjaminp/six/iss...
# 28  https://api.github.com/repos/benjaminp/six/iss...
# 29  https://api.github.com/repos/benjaminp/six/iss...
# 30  https://api.github.com/repos/benjaminp/six/iss...
# 31  https://api.github.com/repos/benjaminp/six/iss...
# 32  https://api.github.com/repos/benjaminp/six/iss...
# 33  https://api.github.com/repos/benjaminp/six/iss...
# 34  https://api.github.com/repos/benjaminp/six/iss...
# 35  https://api.github.com/repos/benjaminp/six/iss...
# 36  https://api.github.com/repos/benjaminp/six/iss...
# 37  https://api.github.com/repos/benjaminp/six/iss...
# 38  https://api.github.com/repos/benjaminp/six/iss...
# 39  https://api.github.com/repos/benjaminp/six/iss...
# 40  https://api.github.com/repos/benjaminp/six/iss...
# 41  https://api.github.com/repos/benjaminp/six/iss...
# 42  https://api.github.com/repos/benjaminp/six/iss...
# 43  https://api.github.com/repos/benjaminp/six/iss...
# 44  https://api.github.com/repos/benjaminp/six/iss...
# 45  https://api.github.com/repos/benjaminp/six/iss...
# 46  https://api.github.com/repos/benjaminp/six/iss...
# 47  https://api.github.com/repos/benjaminp/six/iss...
# 48  https://api.github.com/repos/benjaminp/six/iss...
# 49  https://api.github.com/repos/benjaminp/six/iss...
# 50  https://api.github.com/repos/benjaminp/six/iss...
# 51  https://api.github.com/repos/benjaminp/six/iss...
# 52  https://api.github.com/repos/benjaminp/six/iss...
# 53  https://api.github.com/repos/benjaminp/six/iss...
# 54  https://api.github.com/repos/benjaminp/six/iss...
# 55  https://api.github.com/repos/benjaminp/six/iss...
# 56  https://api.github.com/repos/benjaminp/six/iss...
#
#     performed_via_github_app  state_reason draft pull_request
# 0                        NaN           NaN   NaN          NaN
# 1                        NaN           NaN   NaN          NaN
# 2                        NaN           NaN   NaN          NaN
# 3                        NaN           NaN   NaN          NaN
# 4                        NaN           NaN   NaN          NaN
# 5                        NaN     completed   NaN          NaN
# 6                        NaN           NaN   NaN          NaN
# 7                        NaN     completed   NaN          NaN
# 8                        NaN           NaN   NaN          NaN
# 9                        NaN           NaN   NaN          NaN
# 10                       NaN           NaN   NaN          NaN
# 11                       NaN     completed   NaN          NaN
# 12                       NaN     completed   NaN          NaN
# 13                       NaN           NaN   NaN          NaN
# 14                       NaN           NaN   NaN          NaN
# 15                       NaN           NaN   NaN          NaN
# 16                       NaN     completed   NaN          NaN
# 17                       NaN     completed   NaN          NaN
# 18                       NaN           NaN   NaN          NaN
# 19                       NaN           NaN   NaN          NaN
# 20                       NaN           NaN   NaN          NaN
# 21                       NaN     completed   NaN          NaN
# 22                       NaN     completed   NaN          NaN
# 23                       NaN     completed   NaN          NaN
# 24                       NaN     completed   NaN          NaN
# 25                       NaN           NaN   NaN          NaN
# 26                       NaN     completed   NaN          NaN
# 27                       NaN           NaN   NaN          NaN
# 28                       NaN     completed   NaN          NaN
# 29                       NaN     completed   NaN          NaN
# 30                       NaN     completed   NaN          NaN
# 31                       NaN           NaN   NaN          NaN
# 32                       NaN     completed   NaN          NaN
# 33                       NaN     completed   NaN          NaN
# 34                       NaN     completed   NaN          NaN
# 35                       NaN     completed   NaN          NaN
# 36                       NaN     completed   NaN          NaN
# 37                       NaN     completed   NaN          NaN
# 38                       NaN     completed   NaN          NaN
# 39                       NaN     completed   NaN          NaN
# 40                       NaN     completed   NaN          NaN
# 41                       NaN     completed   NaN          NaN
# 42                       NaN     completed   NaN          NaN
# 43                       NaN     completed   NaN          NaN
# 44                       NaN     completed   NaN          NaN
# 45                       NaN     completed   NaN          NaN
# 46                       NaN     completed   NaN          NaN
# 47                       NaN     completed   NaN          NaN
# 48                       NaN     completed   NaN          NaN
# 49                       NaN     completed   NaN          NaN
# 50                       NaN     completed   NaN          NaN
# 51                       NaN     completed   NaN          NaN
# 52                       NaN     completed   NaN          NaN
# 53                       NaN     completed   NaN          NaN
# 54                       NaN     completed   NaN          NaN
# 55                       NaN     completed   NaN          NaN
# 56                       NaN     completed   NaN          NaN
#
# [57 rows x 30 columns]

# %% [markdown]
# Took data newcomers which is closed issue

# %%
data_newcomers_closed = data_newcomers[data_newcomers.state == "closed"]

# %% [markdown]
# Show closed data newcomers

# %%
data_newcomers_closed.reset_index(drop=True, inplace=True)
data_newcomers_closed.index += 1 
data_newcomers_closed
# Out:
#                                                   url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# 6   https://api.github.com/repos/benjaminp/six/iss...
# 7   https://api.github.com/repos/benjaminp/six/iss...
# 8   https://api.github.com/repos/benjaminp/six/iss...
# 9   https://api.github.com/repos/benjaminp/six/iss...
# 10  https://api.github.com/repos/benjaminp/six/iss...
# 11  https://api.github.com/repos/benjaminp/six/iss...
# 12  https://api.github.com/repos/benjaminp/six/iss...
# 13  https://api.github.com/repos/benjaminp/six/iss...
# 14  https://api.github.com/repos/benjaminp/six/iss...
# 15  https://api.github.com/repos/benjaminp/six/iss...
# 16  https://api.github.com/repos/benjaminp/six/iss...
# 17  https://api.github.com/repos/benjaminp/six/iss...
# 18  https://api.github.com/repos/benjaminp/six/iss...
# 19  https://api.github.com/repos/benjaminp/six/iss...
# 20  https://api.github.com/repos/benjaminp/six/iss...
# 21  https://api.github.com/repos/benjaminp/six/iss...
# 22  https://api.github.com/repos/benjaminp/six/iss...
# 23  https://api.github.com/repos/benjaminp/six/iss...
# 24  https://api.github.com/repos/benjaminp/six/iss...
# 25  https://api.github.com/repos/benjaminp/six/iss...
# 26  https://api.github.com/repos/benjaminp/six/iss...
# 27  https://api.github.com/repos/benjaminp/six/iss...
# 28  https://api.github.com/repos/benjaminp/six/iss...
# 29  https://api.github.com/repos/benjaminp/six/iss...
# 30  https://api.github.com/repos/benjaminp/six/iss...
# 31  https://api.github.com/repos/benjaminp/six/iss...
# 32  https://api.github.com/repos/benjaminp/six/iss...
# 33  https://api.github.com/repos/benjaminp/six/iss...
# 34  https://api.github.com/repos/benjaminp/six/iss...
# 35  https://api.github.com/repos/benjaminp/six/iss...
# 36  https://api.github.com/repos/benjaminp/six/iss...
# 37  https://api.github.com/repos/benjaminp/six/iss...
# 38  https://api.github.com/repos/benjaminp/six/iss...
# 39  https://api.github.com/repos/benjaminp/six/iss...
#
#                                 repository_url  \
# 1   https://api.github.com/repos/benjaminp/six
# 2   https://api.github.com/repos/benjaminp/six
# 3   https://api.github.com/repos/benjaminp/six
# 4   https://api.github.com/repos/benjaminp/six
# 5   https://api.github.com/repos/benjaminp/six
# 6   https://api.github.com/repos/benjaminp/six
# 7   https://api.github.com/repos/benjaminp/six
# 8   https://api.github.com/repos/benjaminp/six
# 9   https://api.github.com/repos/benjaminp/six
# 10  https://api.github.com/repos/benjaminp/six
# 11  https://api.github.com/repos/benjaminp/six
# 12  https://api.github.com/repos/benjaminp/six
# 13  https://api.github.com/repos/benjaminp/six
# 14  https://api.github.com/repos/benjaminp/six
# 15  https://api.github.com/repos/benjaminp/six
# 16  https://api.github.com/repos/benjaminp/six
# 17  https://api.github.com/repos/benjaminp/six
# 18  https://api.github.com/repos/benjaminp/six
# 19  https://api.github.com/repos/benjaminp/six
# 20  https://api.github.com/repos/benjaminp/six
# 21  https://api.github.com/repos/benjaminp/six
# 22  https://api.github.com/repos/benjaminp/six
# 23  https://api.github.com/repos/benjaminp/six
# 24  https://api.github.com/repos/benjaminp/six
# 25  https://api.github.com/repos/benjaminp/six
# 26  https://api.github.com/repos/benjaminp/six
# 27  https://api.github.com/repos/benjaminp/six
# 28  https://api.github.com/repos/benjaminp/six
# 29  https://api.github.com/repos/benjaminp/six
# 30  https://api.github.com/repos/benjaminp/six
# 31  https://api.github.com/repos/benjaminp/six
# 32  https://api.github.com/repos/benjaminp/six
# 33  https://api.github.com/repos/benjaminp/six
# 34  https://api.github.com/repos/benjaminp/six
# 35  https://api.github.com/repos/benjaminp/six
# 36  https://api.github.com/repos/benjaminp/six
# 37  https://api.github.com/repos/benjaminp/six
# 38  https://api.github.com/repos/benjaminp/six
# 39  https://api.github.com/repos/benjaminp/six
#
#                                            labels_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# 6   https://api.github.com/repos/benjaminp/six/iss...
# 7   https://api.github.com/repos/benjaminp/six/iss...
# 8   https://api.github.com/repos/benjaminp/six/iss...
# 9   https://api.github.com/repos/benjaminp/six/iss...
# 10  https://api.github.com/repos/benjaminp/six/iss...
# 11  https://api.github.com/repos/benjaminp/six/iss...
# 12  https://api.github.com/repos/benjaminp/six/iss...
# 13  https://api.github.com/repos/benjaminp/six/iss...
# 14  https://api.github.com/repos/benjaminp/six/iss...
# 15  https://api.github.com/repos/benjaminp/six/iss...
# 16  https://api.github.com/repos/benjaminp/six/iss...
# 17  https://api.github.com/repos/benjaminp/six/iss...
# 18  https://api.github.com/repos/benjaminp/six/iss...
# 19  https://api.github.com/repos/benjaminp/six/iss...
# 20  https://api.github.com/repos/benjaminp/six/iss...
# 21  https://api.github.com/repos/benjaminp/six/iss...
# 22  https://api.github.com/repos/benjaminp/six/iss...
# 23  https://api.github.com/repos/benjaminp/six/iss...
# 24  https://api.github.com/repos/benjaminp/six/iss...
# 25  https://api.github.com/repos/benjaminp/six/iss...
# 26  https://api.github.com/repos/benjaminp/six/iss...
# 27  https://api.github.com/repos/benjaminp/six/iss...
# 28  https://api.github.com/repos/benjaminp/six/iss...
# 29  https://api.github.com/repos/benjaminp/six/iss...
# 30  https://api.github.com/repos/benjaminp/six/iss...
# 31  https://api.github.com/repos/benjaminp/six/iss...
# 32  https://api.github.com/repos/benjaminp/six/iss...
# 33  https://api.github.com/repos/benjaminp/six/iss...
# 34  https://api.github.com/repos/benjaminp/six/iss...
# 35  https://api.github.com/repos/benjaminp/six/iss...
# 36  https://api.github.com/repos/benjaminp/six/iss...
# 37  https://api.github.com/repos/benjaminp/six/iss...
# 38  https://api.github.com/repos/benjaminp/six/iss...
# 39  https://api.github.com/repos/benjaminp/six/iss...
#
#                                          comments_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# 6   https://api.github.com/repos/benjaminp/six/iss...
# 7   https://api.github.com/repos/benjaminp/six/iss...
# 8   https://api.github.com/repos/benjaminp/six/iss...
# 9   https://api.github.com/repos/benjaminp/six/iss...
# 10  https://api.github.com/repos/benjaminp/six/iss...
# 11  https://api.github.com/repos/benjaminp/six/iss...
# 12  https://api.github.com/repos/benjaminp/six/iss...
# 13  https://api.github.com/repos/benjaminp/six/iss...
# 14  https://api.github.com/repos/benjaminp/six/iss...
# 15  https://api.github.com/repos/benjaminp/six/iss...
# 16  https://api.github.com/repos/benjaminp/six/iss...
# 17  https://api.github.com/repos/benjaminp/six/iss...
# 18  https://api.github.com/repos/benjaminp/six/iss...
# 19  https://api.github.com/repos/benjaminp/six/iss...
# 20  https://api.github.com/repos/benjaminp/six/iss...
# 21  https://api.github.com/repos/benjaminp/six/iss...
# 22  https://api.github.com/repos/benjaminp/six/iss...
# 23  https://api.github.com/repos/benjaminp/six/iss...
# 24  https://api.github.com/repos/benjaminp/six/iss...
# 25  https://api.github.com/repos/benjaminp/six/iss...
# 26  https://api.github.com/repos/benjaminp/six/iss...
# 27  https://api.github.com/repos/benjaminp/six/iss...
# 28  https://api.github.com/repos/benjaminp/six/iss...
# 29  https://api.github.com/repos/benjaminp/six/iss...
# 30  https://api.github.com/repos/benjaminp/six/iss...
# 31  https://api.github.com/repos/benjaminp/six/iss...
# 32  https://api.github.com/repos/benjaminp/six/iss...
# 33  https://api.github.com/repos/benjaminp/six/iss...
# 34  https://api.github.com/repos/benjaminp/six/iss...
# 35  https://api.github.com/repos/benjaminp/six/iss...
# 36  https://api.github.com/repos/benjaminp/six/iss...
# 37  https://api.github.com/repos/benjaminp/six/iss...
# 38  https://api.github.com/repos/benjaminp/six/iss...
# 39  https://api.github.com/repos/benjaminp/six/iss...
#
#                                            events_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# 6   https://api.github.com/repos/benjaminp/six/iss...
# 7   https://api.github.com/repos/benjaminp/six/iss...
# 8   https://api.github.com/repos/benjaminp/six/iss...
# 9   https://api.github.com/repos/benjaminp/six/iss...
# 10  https://api.github.com/repos/benjaminp/six/iss...
# 11  https://api.github.com/repos/benjaminp/six/iss...
# 12  https://api.github.com/repos/benjaminp/six/iss...
# 13  https://api.github.com/repos/benjaminp/six/iss...
# 14  https://api.github.com/repos/benjaminp/six/iss...
# 15  https://api.github.com/repos/benjaminp/six/iss...
# 16  https://api.github.com/repos/benjaminp/six/iss...
# 17  https://api.github.com/repos/benjaminp/six/iss...
# 18  https://api.github.com/repos/benjaminp/six/iss...
# 19  https://api.github.com/repos/benjaminp/six/iss...
# 20  https://api.github.com/repos/benjaminp/six/iss...
# 21  https://api.github.com/repos/benjaminp/six/iss...
# 22  https://api.github.com/repos/benjaminp/six/iss...
# 23  https://api.github.com/repos/benjaminp/six/iss...
# 24  https://api.github.com/repos/benjaminp/six/iss...
# 25  https://api.github.com/repos/benjaminp/six/iss...
# 26  https://api.github.com/repos/benjaminp/six/iss...
# 27  https://api.github.com/repos/benjaminp/six/iss...
# 28  https://api.github.com/repos/benjaminp/six/iss...
# 29  https://api.github.com/repos/benjaminp/six/iss...
# 30  https://api.github.com/repos/benjaminp/six/iss...
# 31  https://api.github.com/repos/benjaminp/six/iss...
# 32  https://api.github.com/repos/benjaminp/six/iss...
# 33  https://api.github.com/repos/benjaminp/six/iss...
# 34  https://api.github.com/repos/benjaminp/six/iss...
# 35  https://api.github.com/repos/benjaminp/six/iss...
# 36  https://api.github.com/repos/benjaminp/six/iss...
# 37  https://api.github.com/repos/benjaminp/six/iss...
# 38  https://api.github.com/repos/benjaminp/six/iss...
# 39  https://api.github.com/repos/benjaminp/six/iss...
#
#                                        html_url         id  \
# 1   https://github.com/benjaminp/six/issues/155  198392017
# 2   https://github.com/benjaminp/six/issues/150  198391996
# 3   https://github.com/benjaminp/six/issues/137  198391948
# 4   https://github.com/benjaminp/six/issues/129  198391911
# 5   https://github.com/benjaminp/six/issues/122  198391891
# 6   https://github.com/benjaminp/six/issues/121  198391888
# 7   https://github.com/benjaminp/six/issues/113  198391850
# 8   https://github.com/benjaminp/six/issues/112  198391846
# 9   https://github.com/benjaminp/six/issues/108  198391782
# 10  https://github.com/benjaminp/six/issues/106  198391773
# 11   https://github.com/benjaminp/six/issues/97  198391722
# 12   https://github.com/benjaminp/six/issues/78  198391651
# 13   https://github.com/benjaminp/six/issues/70  198391621
# 14   https://github.com/benjaminp/six/issues/66  198391601
# 15   https://github.com/benjaminp/six/issues/60  198391571
# 16   https://github.com/benjaminp/six/issues/59  198391566
# 17   https://github.com/benjaminp/six/issues/58  198391563
# 18   https://github.com/benjaminp/six/issues/52  198391446
# 19   https://github.com/benjaminp/six/issues/47  198391424
# 20   https://github.com/benjaminp/six/issues/46  198391418
# 21   https://github.com/benjaminp/six/issues/44  198391404
# 22   https://github.com/benjaminp/six/issues/42  198391396
# 23   https://github.com/benjaminp/six/issues/37  198391379
# 24   https://github.com/benjaminp/six/issues/36  198391374
# 25   https://github.com/benjaminp/six/issues/34  198391364
# 26   https://github.com/benjaminp/six/issues/33  198391360
# 27   https://github.com/benjaminp/six/issues/30  198391353
# 28   https://github.com/benjaminp/six/issues/22  198391320
# 29   https://github.com/benjaminp/six/issues/21  198391312
# 30   https://github.com/benjaminp/six/issues/20  198391307
# 31   https://github.com/benjaminp/six/issues/17  198391293
# 32   https://github.com/benjaminp/six/issues/15  198391285
# 33   https://github.com/benjaminp/six/issues/14  198391277
# 34   https://github.com/benjaminp/six/issues/11  198391259
# 35   https://github.com/benjaminp/six/issues/10  198391256
# 36    https://github.com/benjaminp/six/issues/8  198391231
# 37    https://github.com/benjaminp/six/issues/7  198391206
# 38    https://github.com/benjaminp/six/issues/5  198391151
# 39    https://github.com/benjaminp/six/issues/4  198391148
#
#                      node_id  number  \
# 1   MDU6SXNzdWUxOTgzOTIwMTc=     155
# 2   MDU6SXNzdWUxOTgzOTE5OTY=     150
# 3   MDU6SXNzdWUxOTgzOTE5NDg=     137
# 4   MDU6SXNzdWUxOTgzOTE5MTE=     129
# 5   MDU6SXNzdWUxOTgzOTE4OTE=     122
# 6   MDU6SXNzdWUxOTgzOTE4ODg=     121
# 7   MDU6SXNzdWUxOTgzOTE4NTA=     113
# 8   MDU6SXNzdWUxOTgzOTE4NDY=     112
# 9   MDU6SXNzdWUxOTgzOTE3ODI=     108
# 10  MDU6SXNzdWUxOTgzOTE3NzM=     106
# 11  MDU6SXNzdWUxOTgzOTE3MjI=      97
# 12  MDU6SXNzdWUxOTgzOTE2NTE=      78
# 13  MDU6SXNzdWUxOTgzOTE2MjE=      70
# 14  MDU6SXNzdWUxOTgzOTE2MDE=      66
# 15  MDU6SXNzdWUxOTgzOTE1NzE=      60
# 16  MDU6SXNzdWUxOTgzOTE1NjY=      59
# 17  MDU6SXNzdWUxOTgzOTE1NjM=      58
# 18  MDU6SXNzdWUxOTgzOTE0NDY=      52
# 19  MDU6SXNzdWUxOTgzOTE0MjQ=      47
# 20  MDU6SXNzdWUxOTgzOTE0MTg=      46
# 21  MDU6SXNzdWUxOTgzOTE0MDQ=      44
# 22  MDU6SXNzdWUxOTgzOTEzOTY=      42
# 23  MDU6SXNzdWUxOTgzOTEzNzk=      37
# 24  MDU6SXNzdWUxOTgzOTEzNzQ=      36
# 25  MDU6SXNzdWUxOTgzOTEzNjQ=      34
# 26  MDU6SXNzdWUxOTgzOTEzNjA=      33
# 27  MDU6SXNzdWUxOTgzOTEzNTM=      30
# 28  MDU6SXNzdWUxOTgzOTEzMjA=      22
# 29  MDU6SXNzdWUxOTgzOTEzMTI=      21
# 30  MDU6SXNzdWUxOTgzOTEzMDc=      20
# 31  MDU6SXNzdWUxOTgzOTEyOTM=      17
# 32  MDU6SXNzdWUxOTgzOTEyODU=      15
# 33  MDU6SXNzdWUxOTgzOTEyNzc=      14
# 34  MDU6SXNzdWUxOTgzOTEyNTk=      11
# 35  MDU6SXNzdWUxOTgzOTEyNTY=      10
# 36  MDU6SXNzdWUxOTgzOTEyMzE=       8
# 37  MDU6SXNzdWUxOTgzOTEyMDY=       7
# 38  MDU6SXNzdWUxOTgzOTExNTE=       5
# 39  MDU6SXNzdWUxOTgzOTExNDg=       4
#
#                                                 title  ...  \
# 1                       Add six.moves.collections.abc  ...
# 2                           RemovedInDjango110Warning  ...
# 3                        Please add per-file licenses  ...
# 4                Add license headers to source files.  ...
# 5          Improve int2byte() performance on Python 3  ...
# 6   Remove superfluous iter()-calls in PY2 iterkey...  ...
# 7                       Test failures with Python 3.1  ...
# 8   six.moves.reload_module uses deprecated imp mo...  ...
# 9           getcwd is renamed between pythons 2 and 3  ...
# 10              print_ should support flush parameter  ...
# 11          Performance improvement for six.iterbytes  ...
# 12                            New built-in exceptions  ...
# 13                             thread.get_ident moved  ...
# 14  Replace the implementation of `six.with_metacl...  ...
# 15        six.u mishandles string ending in backslash  ...
# 16                            missing intern function  ...
# 17  http://pythonhosted.org/six/ docs are not up t...  ...
# 18              test_move_items fails with Python 2.6  ...
# 19  add_metaclass doesn't account for string __slo...  ...
# 20                      six, commands, and subprocess  ...
# 21  six.u(r'\\') behaves differently on Python 2.x...  ...
# 22                       OrderedDict for python < 2.7  ...
# 23                        "five" link goes to nothing  ...
# 24                               docs for print wrong  ...
# 25        dir(six.moves.<module>) is lazily populated  ...
# 26    Docs for urllib.parse don't mention ParseResult  ...
# 27  Add a function for "true" if 1 == 1 else "fals...  ...
# 28            variable ``six.PY3`` -- is time bomb :)  ...
# 29      Additional object model compatibility methods  ...
# 30  python-six checks fail on GNU/Linux if tkinter...  ...
# 31  Six defines its own callable() on Py3 even if ...  ...
# 32  Could do with some decorators for the __unicod...  ...
# 33  Six does not allow multiple distinct instances...  ...
# 34                   Jython compatibility in setup.py  ...
# 35                                 raw_input v. input  ...
# 36                         Script to “six-ify” source  ...
# 37  Address Python 2/3’s different Exception hiera...  ...
# 38  import hook for replacing except .. as .. with...  ...
# 39                      Include test suite in tarball  ...
#
#                     closed_at author_association active_lock_reason  \
# 1   2019-11-05 07:21:56+00:00              OWNER                NaN
# 2   2017-01-02 23:43:21+00:00              OWNER                NaN
# 3   2017-01-02 23:42:50+00:00              OWNER                NaN
# 4   2017-01-02 23:42:13+00:00              OWNER                NaN
# 5   2017-01-02 23:41:58+00:00              OWNER                NaN
# 6   2017-01-02 23:41:55+00:00              OWNER                NaN
# 7   2017-01-02 23:41:18+00:00              OWNER                NaN
# 8   2017-01-02 23:41:15+00:00              OWNER                NaN
# 9   2017-01-02 23:40:03+00:00              OWNER                NaN
# 10  2017-01-02 23:39:54+00:00              OWNER                NaN
# 11  2017-01-02 23:39:13+00:00              OWNER                NaN
# 12  2017-01-02 23:38:17+00:00              OWNER                NaN
# 13  2017-01-02 23:37:53+00:00              OWNER                NaN
# 14  2017-01-02 23:37:32+00:00              OWNER                NaN
# 15  2020-11-05 18:11:21+00:00              OWNER                NaN
# 16  2017-01-02 23:37:07+00:00              OWNER                NaN
# 17  2017-01-02 23:37:05+00:00              OWNER                NaN
# 18  2017-01-02 23:35:21+00:00              OWNER                NaN
# 19  2017-01-02 23:35:03+00:00              OWNER                NaN
# 20  2017-03-01 05:37:14+00:00              OWNER                NaN
# 21  2017-01-02 23:34:45+00:00              OWNER                NaN
# 22  2017-01-02 23:34:39+00:00              OWNER                NaN
# 23  2017-01-02 23:34:22+00:00              OWNER                NaN
# 24  2017-01-02 23:34:19+00:00              OWNER                NaN
# 25  2017-01-02 23:34:12+00:00              OWNER                NaN
# 26  2017-01-02 23:34:09+00:00              OWNER                NaN
# 27  2017-01-02 23:34:01+00:00              OWNER                NaN
# 28  2017-01-02 23:33:38+00:00              OWNER                NaN
# 29  2017-01-02 23:33:33+00:00              OWNER                NaN
# 30  2017-01-02 23:33:29+00:00              OWNER                NaN
# 31  2017-01-02 23:33:18+00:00              OWNER                NaN
# 32  2017-01-02 23:33:09+00:00              OWNER                NaN
# 33  2017-01-02 23:33:02+00:00              OWNER                NaN
# 34  2017-01-02 23:32:45+00:00              OWNER                NaN
# 35  2017-01-02 23:32:42+00:00              OWNER                NaN
# 36  2017-01-02 23:32:30+00:00              OWNER                NaN
# 37  2017-01-02 23:31:57+00:00              OWNER                NaN
# 38  2017-01-02 23:31:12+00:00              OWNER                NaN
# 39  2017-01-02 23:31:08+00:00              OWNER                NaN
#
#                                                  body  \
# 1   Originally reported by: **Eklavya Sharma (Bitb...
# 2   Originally reported by: **Ernest Prabhakar (Bi...
# 3   Originally reported by: **petrcermak (Bitbucke...
# 4   Originally reported by: **philbeaudoin (Bitbuc...
# 5   Originally reported by: **Wouter Bolsterlee (B...
# 6   Originally reported by: **Sebastian Bank (Bitb...
# 7   Originally reported by: **Arfrever Frehtes Tai...
# 8   Originally reported by: **Tim Graham (Bitbucke...
# 9   Originally reported by: **Max Grender-Jones (B...
# 10  Originally reported by: **Maik Riechert (Bitbu...
# 11  Originally reported by: **Wouter Bolsterlee (B...
# 12  Originally reported by: **Zhen Wang (Bitbucket...
# 13  Originally reported by: **Joshua Harlow (Bitbu...
# 14  Originally reported by: **charettes (Bitbucket...
# 15  Originally reported by: **Peter Bigot (Bitbuck...
# 16  Originally reported by: **Peter Bigot (Bitbuck...
# 17  Originally reported by: **Marc Abramowitz (Bit...
# 18  Originally reported by: **Arfrever Frehtes Tai...
# 19  Originally reported by: **Alex Gaynor (Bitbuck...
# 20  Originally reported by: **kyleabeauchamp (Bitb...
# 21  Originally reported by: **daviddrysdale (Bitbu...
# 22  Originally reported by: **Konsta Vesterinen (B...
# 23  Originally reported by: **Georg Brandl (Bitbuc...
# 24  Originally reported by: **Robert Robert (Bitbu...
# 25  Originally reported by: **Marc Abramowitz (Bit...
# 26  Originally reported by: **Aymeric Augustin (Bi...
# 27  Originally reported by: **Anonymous**\n\n-----...
# 28  Originally reported by: **Andrej Antonov (Bitb...
# 29  Originally reported by: **Aymeric Augustin (Bi...
# 30  Originally reported by: **Anonymous**\n\n-----...
# 31  Originally reported by: **Ned Batchelder (Bitb...
# 32  Originally reported by: **Tom Grainger (Bitbuc...
# 33  Originally reported by: **Bryce Boe (Bitbucket...
# 34  Originally reported by: **squeaky (Bitbucket: ...
# 35  Originally reported by: **Bryce Boe (Bitbucket...
# 36  Originally reported by: **Zearin (Bitbucket: [...
# 37  Originally reported by: **Zearin (Bitbucket: [...
# 38  Originally reported by: **Ronny Pfannschmidt (...
# 39  Originally reported by: **cjwatson (Bitbucket:...
#
#                                             reactions  \
# 1   {'url': 'https://api.github.com/repos/benjamin...
# 2   {'url': 'https://api.github.com/repos/benjamin...
# 3   {'url': 'https://api.github.com/repos/benjamin...
# 4   {'url': 'https://api.github.com/repos/benjamin...
# 5   {'url': 'https://api.github.com/repos/benjamin...
# 6   {'url': 'https://api.github.com/repos/benjamin...
# 7   {'url': 'https://api.github.com/repos/benjamin...
# 8   {'url': 'https://api.github.com/repos/benjamin...
# 9   {'url': 'https://api.github.com/repos/benjamin...
# 10  {'url': 'https://api.github.com/repos/benjamin...
# 11  {'url': 'https://api.github.com/repos/benjamin...
# 12  {'url': 'https://api.github.com/repos/benjamin...
# 13  {'url': 'https://api.github.com/repos/benjamin...
# 14  {'url': 'https://api.github.com/repos/benjamin...
# 15  {'url': 'https://api.github.com/repos/benjamin...
# 16  {'url': 'https://api.github.com/repos/benjamin...
# 17  {'url': 'https://api.github.com/repos/benjamin...
# 18  {'url': 'https://api.github.com/repos/benjamin...
# 19  {'url': 'https://api.github.com/repos/benjamin...
# 20  {'url': 'https://api.github.com/repos/benjamin...
# 21  {'url': 'https://api.github.com/repos/benjamin...
# 22  {'url': 'https://api.github.com/repos/benjamin...
# 23  {'url': 'https://api.github.com/repos/benjamin...
# 24  {'url': 'https://api.github.com/repos/benjamin...
# 25  {'url': 'https://api.github.com/repos/benjamin...
# 26  {'url': 'https://api.github.com/repos/benjamin...
# 27  {'url': 'https://api.github.com/repos/benjamin...
# 28  {'url': 'https://api.github.com/repos/benjamin...
# 29  {'url': 'https://api.github.com/repos/benjamin...
# 30  {'url': 'https://api.github.com/repos/benjamin...
# 31  {'url': 'https://api.github.com/repos/benjamin...
# 32  {'url': 'https://api.github.com/repos/benjamin...
# 33  {'url': 'https://api.github.com/repos/benjamin...
# 34  {'url': 'https://api.github.com/repos/benjamin...
# 35  {'url': 'https://api.github.com/repos/benjamin...
# 36  {'url': 'https://api.github.com/repos/benjamin...
# 37  {'url': 'https://api.github.com/repos/benjamin...
# 38  {'url': 'https://api.github.com/repos/benjamin...
# 39  {'url': 'https://api.github.com/repos/benjamin...
#
#                                          timeline_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# 6   https://api.github.com/repos/benjaminp/six/iss...
# 7   https://api.github.com/repos/benjaminp/six/iss...
# 8   https://api.github.com/repos/benjaminp/six/iss...
# 9   https://api.github.com/repos/benjaminp/six/iss...
# 10  https://api.github.com/repos/benjaminp/six/iss...
# 11  https://api.github.com/repos/benjaminp/six/iss...
# 12  https://api.github.com/repos/benjaminp/six/iss...
# 13  https://api.github.com/repos/benjaminp/six/iss...
# 14  https://api.github.com/repos/benjaminp/six/iss...
# 15  https://api.github.com/repos/benjaminp/six/iss...
# 16  https://api.github.com/repos/benjaminp/six/iss...
# 17  https://api.github.com/repos/benjaminp/six/iss...
# 18  https://api.github.com/repos/benjaminp/six/iss...
# 19  https://api.github.com/repos/benjaminp/six/iss...
# 20  https://api.github.com/repos/benjaminp/six/iss...
# 21  https://api.github.com/repos/benjaminp/six/iss...
# 22  https://api.github.com/repos/benjaminp/six/iss...
# 23  https://api.github.com/repos/benjaminp/six/iss...
# 24  https://api.github.com/repos/benjaminp/six/iss...
# 25  https://api.github.com/repos/benjaminp/six/iss...
# 26  https://api.github.com/repos/benjaminp/six/iss...
# 27  https://api.github.com/repos/benjaminp/six/iss...
# 28  https://api.github.com/repos/benjaminp/six/iss...
# 29  https://api.github.com/repos/benjaminp/six/iss...
# 30  https://api.github.com/repos/benjaminp/six/iss...
# 31  https://api.github.com/repos/benjaminp/six/iss...
# 32  https://api.github.com/repos/benjaminp/six/iss...
# 33  https://api.github.com/repos/benjaminp/six/iss...
# 34  https://api.github.com/repos/benjaminp/six/iss...
# 35  https://api.github.com/repos/benjaminp/six/iss...
# 36  https://api.github.com/repos/benjaminp/six/iss...
# 37  https://api.github.com/repos/benjaminp/six/iss...
# 38  https://api.github.com/repos/benjaminp/six/iss...
# 39  https://api.github.com/repos/benjaminp/six/iss...
#
#     performed_via_github_app  state_reason draft pull_request
# 1                        NaN     completed   NaN          NaN
# 2                        NaN     completed   NaN          NaN
# 3                        NaN     completed   NaN          NaN
# 4                        NaN     completed   NaN          NaN
# 5                        NaN     completed   NaN          NaN
# 6                        NaN     completed   NaN          NaN
# 7                        NaN     completed   NaN          NaN
# 8                        NaN     completed   NaN          NaN
# 9                        NaN     completed   NaN          NaN
# 10                       NaN     completed   NaN          NaN
# 11                       NaN     completed   NaN          NaN
# 12                       NaN     completed   NaN          NaN
# 13                       NaN     completed   NaN          NaN
# 14                       NaN     completed   NaN          NaN
# 15                       NaN     completed   NaN          NaN
# 16                       NaN     completed   NaN          NaN
# 17                       NaN     completed   NaN          NaN
# 18                       NaN     completed   NaN          NaN
# 19                       NaN     completed   NaN          NaN
# 20                       NaN     completed   NaN          NaN
# 21                       NaN     completed   NaN          NaN
# 22                       NaN     completed   NaN          NaN
# 23                       NaN     completed   NaN          NaN
# 24                       NaN     completed   NaN          NaN
# 25                       NaN     completed   NaN          NaN
# 26                       NaN     completed   NaN          NaN
# 27                       NaN     completed   NaN          NaN
# 28                       NaN     completed   NaN          NaN
# 29                       NaN     completed   NaN          NaN
# 30                       NaN     completed   NaN          NaN
# 31                       NaN     completed   NaN          NaN
# 32                       NaN     completed   NaN          NaN
# 33                       NaN     completed   NaN          NaN
# 34                       NaN     completed   NaN          NaN
# 35                       NaN     completed   NaN          NaN
# 36                       NaN     completed   NaN          NaN
# 37                       NaN     completed   NaN          NaN
# 38                       NaN     completed   NaN          NaN
# 39                       NaN     completed   NaN          NaN
#
# [39 rows x 30 columns]

# %% [markdown]
# Save the data newcomers

# %%
data_newcomers_closed.to_csv("data_newcomers_closed_index.csv")

# %% [markdown]
# ## Expert

# %% [markdown]
# Make dataset csv according experts labels

# %%
df2_expert_labels.to_csv("data_experts.csv", index=False)

# %% [markdown]
# Read dataset csv according experts labels

# %%
data_experts = pd.read_csv("data_experts.csv")
data_experts
# Out:
#                                                    url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 125  https://api.github.com/repos/benjaminp/six/iss...
# 126  https://api.github.com/repos/benjaminp/six/iss...
# 127  https://api.github.com/repos/benjaminp/six/iss...
# 128  https://api.github.com/repos/benjaminp/six/iss...
# 129  https://api.github.com/repos/benjaminp/six/iss...
#
#                                  repository_url  \
# 0    https://api.github.com/repos/benjaminp/six
# 1    https://api.github.com/repos/benjaminp/six
# 2    https://api.github.com/repos/benjaminp/six
# 3    https://api.github.com/repos/benjaminp/six
# 4    https://api.github.com/repos/benjaminp/six
# ..                                          ...
# 125  https://api.github.com/repos/benjaminp/six
# 126  https://api.github.com/repos/benjaminp/six
# 127  https://api.github.com/repos/benjaminp/six
# 128  https://api.github.com/repos/benjaminp/six
# 129  https://api.github.com/repos/benjaminp/six
#
#                                             labels_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 125  https://api.github.com/repos/benjaminp/six/iss...
# 126  https://api.github.com/repos/benjaminp/six/iss...
# 127  https://api.github.com/repos/benjaminp/six/iss...
# 128  https://api.github.com/repos/benjaminp/six/iss...
# 129  https://api.github.com/repos/benjaminp/six/iss...
#
#                                           comments_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 125  https://api.github.com/repos/benjaminp/six/iss...
# 126  https://api.github.com/repos/benjaminp/six/iss...
# 127  https://api.github.com/repos/benjaminp/six/iss...
# 128  https://api.github.com/repos/benjaminp/six/iss...
# 129  https://api.github.com/repos/benjaminp/six/iss...
#
#                                             events_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 125  https://api.github.com/repos/benjaminp/six/iss...
# 126  https://api.github.com/repos/benjaminp/six/iss...
# 127  https://api.github.com/repos/benjaminp/six/iss...
# 128  https://api.github.com/repos/benjaminp/six/iss...
# 129  https://api.github.com/repos/benjaminp/six/iss...
#
#                                         html_url         id  \
# 0    https://github.com/benjaminp/six/issues/165  198392054
# 1    https://github.com/benjaminp/six/issues/162  198392041
# 2    https://github.com/benjaminp/six/issues/161  198392040
# 3    https://github.com/benjaminp/six/issues/160  198392037
# 4    https://github.com/benjaminp/six/issues/158  198392025
# ..                                           ...        ...
# 125    https://github.com/benjaminp/six/issues/7  198391206
# 126    https://github.com/benjaminp/six/issues/6  198391155
# 127    https://github.com/benjaminp/six/issues/3  198391144
# 128    https://github.com/benjaminp/six/issues/2  198391139
# 129    https://github.com/benjaminp/six/issues/1  198391131
#
#                       node_id  number  \
# 0    MDU6SXNzdWUxOTgzOTIwNTQ=     165
# 1    MDU6SXNzdWUxOTgzOTIwNDE=     162
# 2    MDU6SXNzdWUxOTgzOTIwNDA=     161
# 3    MDU6SXNzdWUxOTgzOTIwMzc=     160
# 4    MDU6SXNzdWUxOTgzOTIwMjU=     158
# ..                        ...     ...
# 125  MDU6SXNzdWUxOTgzOTEyMDY=       7
# 126  MDU6SXNzdWUxOTgzOTExNTU=       6
# 127  MDU6SXNzdWUxOTgzOTExNDQ=       3
# 128  MDU6SXNzdWUxOTgzOTExMzk=       2
# 129  MDU6SXNzdWUxOTgzOTExMzE=       1
#
#                                                  title  ...  \
# 0             wraps behaves differently on 2.7 and 3.5  ...
# 1                      Match Python 3 metaclass syntax  ...
# 2    Inconsistent value returned from http_client.B...  ...
# 3           ImportError: No module named xmlrpc_server  ...
# 4      DeprecationWarning from six.moves.reload_module  ...
# ..                                                 ...  ...
# 125  Address Python 2/3’s different Exception hiera...  ...
# 126                           Python 3 style `super()`  ...
# 127                                  map/filter issues  ...
# 128  u() function does not support unicode characte...  ...
# 129                                         ChangeLog?  ...
#
#                      closed_at author_association active_lock_reason  \
# 0    2020-01-07 02:55:44+00:00              OWNER                NaN
# 1                          NaN              OWNER                NaN
# 2    2017-01-02 23:43:51+00:00              OWNER                NaN
# 3                          NaN              OWNER                NaN
# 4                          NaN              OWNER                NaN
# ..                         ...                ...                ...
# 125  2017-01-02 23:31:57+00:00              OWNER                NaN
# 126  2017-01-02 23:31:15+00:00              OWNER                NaN
# 127  2017-01-02 23:31:05+00:00              OWNER                NaN
# 128  2017-01-02 23:31:03+00:00              OWNER                NaN
# 129  2017-01-02 23:30:58+00:00              OWNER                NaN
#
#                                                   body  \
# 0    Originally reported by: **Hexchain Tong (Bitbu...
# 1    Originally reported by: **Evan (Bitbucket: [ev...
# 2    Originally reported by: **Eric Brown (Bitbucke...
# 3    Originally reported by: **parahelox (Bitbucket...
# 4    Originally reported by: **Ben Finney (Bitbucke...
# ..                                                 ...
# 125  Originally reported by: **Zearin (Bitbucket: [...
# 126  Originally reported by: **Zearin (Bitbucket: [...
# 127  Originally reported by: **Michael Salib (Bitbu...
# 128  Originally reported by: **Matt Chaput (Bitbuck...
# 129  Originally reported by: **Sridhar Ratnakumar (...
#
#                                              reactions  \
# 0    {'url': 'https://api.github.com/repos/benjamin...
# 1    {'url': 'https://api.github.com/repos/benjamin...
# 2    {'url': 'https://api.github.com/repos/benjamin...
# 3    {'url': 'https://api.github.com/repos/benjamin...
# 4    {'url': 'https://api.github.com/repos/benjamin...
# ..                                                 ...
# 125  {'url': 'https://api.github.com/repos/benjamin...
# 126  {'url': 'https://api.github.com/repos/benjamin...
# 127  {'url': 'https://api.github.com/repos/benjamin...
# 128  {'url': 'https://api.github.com/repos/benjamin...
# 129  {'url': 'https://api.github.com/repos/benjamin...
#
#                                           timeline_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 125  https://api.github.com/repos/benjaminp/six/iss...
# 126  https://api.github.com/repos/benjaminp/six/iss...
# 127  https://api.github.com/repos/benjaminp/six/iss...
# 128  https://api.github.com/repos/benjaminp/six/iss...
# 129  https://api.github.com/repos/benjaminp/six/iss...
#
#      performed_via_github_app  state_reason draft pull_request
# 0                         NaN     completed   NaN          NaN
# 1                         NaN           NaN   NaN          NaN
# 2                         NaN     completed   NaN          NaN
# 3                         NaN           NaN   NaN          NaN
# 4                         NaN           NaN   NaN          NaN
# ..                        ...           ...   ...          ...
# 125                       NaN     completed   NaN          NaN
# 126                       NaN     completed   NaN          NaN
# 127                       NaN     completed   NaN          NaN
# 128                       NaN     completed   NaN          NaN
# 129                       NaN     completed   NaN          NaN
#
# [130 rows x 30 columns]

# %% [markdown]
# Took data experts which is closed issue

# %%
data_experts_closed = data_experts[data_experts.state == "closed"]

# %% [markdown]
# Show closed data experts

# %%
data_experts_closed.reset_index(drop=True, inplace=True)
data_experts_closed.index += 1 
data_experts_closed
# Out:
#                                                   url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# ..                                                ...
# 91  https://api.github.com/repos/benjaminp/six/iss...
# 92  https://api.github.com/repos/benjaminp/six/iss...
# 93  https://api.github.com/repos/benjaminp/six/iss...
# 94  https://api.github.com/repos/benjaminp/six/iss...
# 95  https://api.github.com/repos/benjaminp/six/iss...
#
#                                 repository_url  \
# 1   https://api.github.com/repos/benjaminp/six
# 2   https://api.github.com/repos/benjaminp/six
# 3   https://api.github.com/repos/benjaminp/six
# 4   https://api.github.com/repos/benjaminp/six
# 5   https://api.github.com/repos/benjaminp/six
# ..                                         ...
# 91  https://api.github.com/repos/benjaminp/six
# 92  https://api.github.com/repos/benjaminp/six
# 93  https://api.github.com/repos/benjaminp/six
# 94  https://api.github.com/repos/benjaminp/six
# 95  https://api.github.com/repos/benjaminp/six
#
#                                            labels_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# ..                                                ...
# 91  https://api.github.com/repos/benjaminp/six/iss...
# 92  https://api.github.com/repos/benjaminp/six/iss...
# 93  https://api.github.com/repos/benjaminp/six/iss...
# 94  https://api.github.com/repos/benjaminp/six/iss...
# 95  https://api.github.com/repos/benjaminp/six/iss...
#
#                                          comments_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# ..                                                ...
# 91  https://api.github.com/repos/benjaminp/six/iss...
# 92  https://api.github.com/repos/benjaminp/six/iss...
# 93  https://api.github.com/repos/benjaminp/six/iss...
# 94  https://api.github.com/repos/benjaminp/six/iss...
# 95  https://api.github.com/repos/benjaminp/six/iss...
#
#                                            events_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# ..                                                ...
# 91  https://api.github.com/repos/benjaminp/six/iss...
# 92  https://api.github.com/repos/benjaminp/six/iss...
# 93  https://api.github.com/repos/benjaminp/six/iss...
# 94  https://api.github.com/repos/benjaminp/six/iss...
# 95  https://api.github.com/repos/benjaminp/six/iss...
#
#                                        html_url         id  \
# 1   https://github.com/benjaminp/six/issues/165  198392054
# 2   https://github.com/benjaminp/six/issues/161  198392040
# 3   https://github.com/benjaminp/six/issues/156  198392019
# 4   https://github.com/benjaminp/six/issues/154  198392012
# 5   https://github.com/benjaminp/six/issues/149  198391994
# ..                                          ...        ...
# 91    https://github.com/benjaminp/six/issues/7  198391206
# 92    https://github.com/benjaminp/six/issues/6  198391155
# 93    https://github.com/benjaminp/six/issues/3  198391144
# 94    https://github.com/benjaminp/six/issues/2  198391139
# 95    https://github.com/benjaminp/six/issues/1  198391131
#
#                      node_id  number  \
# 1   MDU6SXNzdWUxOTgzOTIwNTQ=     165
# 2   MDU6SXNzdWUxOTgzOTIwNDA=     161
# 3   MDU6SXNzdWUxOTgzOTIwMTk=     156
# 4   MDU6SXNzdWUxOTgzOTIwMTI=     154
# 5   MDU6SXNzdWUxOTgzOTE5OTQ=     149
# ..                       ...     ...
# 91  MDU6SXNzdWUxOTgzOTEyMDY=       7
# 92  MDU6SXNzdWUxOTgzOTExNTU=       6
# 93  MDU6SXNzdWUxOTgzOTExNDQ=       3
# 94  MDU6SXNzdWUxOTgzOTExMzk=       2
# 95  MDU6SXNzdWUxOTgzOTExMzE=       1
#
#                                                 title  ...  \
# 1            wraps behaves differently on 2.7 and 3.5  ...
# 2   Inconsistent value returned from http_client.B...  ...
# 3                         unsupported python versions  ...
# 4                     problem installing six with pip  ...
# 5                six.BytesIO doesn't match io.BytesIO  ...
# ..                                                ...  ...
# 91  Address Python 2/3’s different Exception hiera...  ...
# 92                           Python 3 style `super()`  ...
# 93                                  map/filter issues  ...
# 94  u() function does not support unicode characte...  ...
# 95                                         ChangeLog?  ...
#
#                     closed_at author_association active_lock_reason  \
# 1   2020-01-07 02:55:44+00:00              OWNER                NaN
# 2   2017-01-02 23:43:51+00:00              OWNER                NaN
# 3   2017-01-02 23:43:35+00:00              OWNER                NaN
# 4   2017-01-02 23:43:30+00:00              OWNER                NaN
# 5   2017-01-02 23:43:19+00:00              OWNER                NaN
# ..                        ...                ...                ...
# 91  2017-01-02 23:31:57+00:00              OWNER                NaN
# 92  2017-01-02 23:31:15+00:00              OWNER                NaN
# 93  2017-01-02 23:31:05+00:00              OWNER                NaN
# 94  2017-01-02 23:31:03+00:00              OWNER                NaN
# 95  2017-01-02 23:30:58+00:00              OWNER                NaN
#
#                                                  body  \
# 1   Originally reported by: **Hexchain Tong (Bitbu...
# 2   Originally reported by: **Eric Brown (Bitbucke...
# 3   Originally reported by: **liso (Bitbucket: [li...
# 4   Originally reported by: **Anonymous**\n\n-----...
# 5   Originally reported by: **Stephen Lowrie (Bitb...
# ..                                                ...
# 91  Originally reported by: **Zearin (Bitbucket: [...
# 92  Originally reported by: **Zearin (Bitbucket: [...
# 93  Originally reported by: **Michael Salib (Bitbu...
# 94  Originally reported by: **Matt Chaput (Bitbuck...
# 95  Originally reported by: **Sridhar Ratnakumar (...
#
#                                             reactions  \
# 1   {'url': 'https://api.github.com/repos/benjamin...
# 2   {'url': 'https://api.github.com/repos/benjamin...
# 3   {'url': 'https://api.github.com/repos/benjamin...
# 4   {'url': 'https://api.github.com/repos/benjamin...
# 5   {'url': 'https://api.github.com/repos/benjamin...
# ..                                                ...
# 91  {'url': 'https://api.github.com/repos/benjamin...
# 92  {'url': 'https://api.github.com/repos/benjamin...
# 93  {'url': 'https://api.github.com/repos/benjamin...
# 94  {'url': 'https://api.github.com/repos/benjamin...
# 95  {'url': 'https://api.github.com/repos/benjamin...
#
#                                          timeline_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# ..                                                ...
# 91  https://api.github.com/repos/benjaminp/six/iss...
# 92  https://api.github.com/repos/benjaminp/six/iss...
# 93  https://api.github.com/repos/benjaminp/six/iss...
# 94  https://api.github.com/repos/benjaminp/six/iss...
# 95  https://api.github.com/repos/benjaminp/six/iss...
#
#     performed_via_github_app  state_reason draft pull_request
# 1                        NaN     completed   NaN          NaN
# 2                        NaN     completed   NaN          NaN
# 3                        NaN     completed   NaN          NaN
# 4                        NaN     completed   NaN          NaN
# 5                        NaN     completed   NaN          NaN
# ..                       ...           ...   ...          ...
# 91                       NaN     completed   NaN          NaN
# 92                       NaN     completed   NaN          NaN
# 93                       NaN     completed   NaN          NaN
# 94                       NaN     completed   NaN          NaN
# 95                       NaN     completed   NaN          NaN
#
# [95 rows x 30 columns]

# %% [markdown]
# Save the data experts

# %%
data_experts_closed.to_csv("data_experts_closed_index.csv")

# %% [markdown]
# ## Both

# %% [markdown]
# Make dataset csv according experts and newcomers labels

# %%
df2_expert_newcomers_labels.to_csv("data_expert_newcomers.csv", index=False)

# %% [markdown]
# Read dataset csv according experts and newcomers labels

# %%
data_expert_newcomers = pd.read_csv("data_expert_newcomers.csv")
data_expert_newcomers
# Out:
#                                                    url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 109  https://api.github.com/repos/benjaminp/six/iss...
# 110  https://api.github.com/repos/benjaminp/six/iss...
# 111  https://api.github.com/repos/benjaminp/six/iss...
# 112  https://api.github.com/repos/benjaminp/six/iss...
# 113  https://api.github.com/repos/benjaminp/six/iss...
#
#                                  repository_url  \
# 0    https://api.github.com/repos/benjaminp/six
# 1    https://api.github.com/repos/benjaminp/six
# 2    https://api.github.com/repos/benjaminp/six
# 3    https://api.github.com/repos/benjaminp/six
# 4    https://api.github.com/repos/benjaminp/six
# ..                                          ...
# 109  https://api.github.com/repos/benjaminp/six
# 110  https://api.github.com/repos/benjaminp/six
# 111  https://api.github.com/repos/benjaminp/six
# 112  https://api.github.com/repos/benjaminp/six
# 113  https://api.github.com/repos/benjaminp/six
#
#                                             labels_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 109  https://api.github.com/repos/benjaminp/six/iss...
# 110  https://api.github.com/repos/benjaminp/six/iss...
# 111  https://api.github.com/repos/benjaminp/six/iss...
# 112  https://api.github.com/repos/benjaminp/six/iss...
# 113  https://api.github.com/repos/benjaminp/six/iss...
#
#                                           comments_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 109  https://api.github.com/repos/benjaminp/six/iss...
# 110  https://api.github.com/repos/benjaminp/six/iss...
# 111  https://api.github.com/repos/benjaminp/six/iss...
# 112  https://api.github.com/repos/benjaminp/six/iss...
# 113  https://api.github.com/repos/benjaminp/six/iss...
#
#                                             events_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 109  https://api.github.com/repos/benjaminp/six/iss...
# 110  https://api.github.com/repos/benjaminp/six/iss...
# 111  https://api.github.com/repos/benjaminp/six/iss...
# 112  https://api.github.com/repos/benjaminp/six/iss...
# 113  https://api.github.com/repos/benjaminp/six/iss...
#
#                                         html_url         id  \
# 0    https://github.com/benjaminp/six/issues/165  198392054
# 1    https://github.com/benjaminp/six/issues/164  198392051
# 2    https://github.com/benjaminp/six/issues/163  198392047
# 3    https://github.com/benjaminp/six/issues/161  198392040
# 4    https://github.com/benjaminp/six/issues/160  198392037
# ..                                           ...        ...
# 109    https://github.com/benjaminp/six/issues/5  198391151
# 110    https://github.com/benjaminp/six/issues/4  198391148
# 111    https://github.com/benjaminp/six/issues/3  198391144
# 112    https://github.com/benjaminp/six/issues/2  198391139
# 113    https://github.com/benjaminp/six/issues/1  198391131
#
#                       node_id  number  \
# 0    MDU6SXNzdWUxOTgzOTIwNTQ=     165
# 1    MDU6SXNzdWUxOTgzOTIwNTE=     164
# 2    MDU6SXNzdWUxOTgzOTIwNDc=     163
# 3    MDU6SXNzdWUxOTgzOTIwNDA=     161
# 4    MDU6SXNzdWUxOTgzOTIwMzc=     160
# ..                        ...     ...
# 109  MDU6SXNzdWUxOTgzOTExNTE=       5
# 110  MDU6SXNzdWUxOTgzOTExNDg=       4
# 111  MDU6SXNzdWUxOTgzOTExNDQ=       3
# 112  MDU6SXNzdWUxOTgzOTExMzk=       2
# 113  MDU6SXNzdWUxOTgzOTExMzE=       1
#
#                                                  title  ...  \
# 0             wraps behaves differently on 2.7 and 3.5  ...
# 1                                          assertRegex  ...
# 2    int2byte does not match documentation on Python 3  ...
# 3    Inconsistent value returned from http_client.B...  ...
# 4           ImportError: No module named xmlrpc_server  ...
# ..                                                 ...  ...
# 109  import hook for replacing except .. as .. with...  ...
# 110                      Include test suite in tarball  ...
# 111                                  map/filter issues  ...
# 112  u() function does not support unicode characte...  ...
# 113                                         ChangeLog?  ...
#
#                      closed_at author_association active_lock_reason  \
# 0    2020-01-07 02:55:44+00:00              OWNER                NaN
# 1                          NaN              OWNER                NaN
# 2                          NaN              OWNER                NaN
# 3    2017-01-02 23:43:51+00:00              OWNER                NaN
# 4                          NaN              OWNER                NaN
# ..                         ...                ...                ...
# 109  2017-01-02 23:31:12+00:00              OWNER                NaN
# 110  2017-01-02 23:31:08+00:00              OWNER                NaN
# 111  2017-01-02 23:31:05+00:00              OWNER                NaN
# 112  2017-01-02 23:31:03+00:00              OWNER                NaN
# 113  2017-01-02 23:30:58+00:00              OWNER                NaN
#
#                                                   body  \
# 0    Originally reported by: **Hexchain Tong (Bitbu...
# 1    Originally reported by: **Arthur Goldberg (Bit...
# 2    Originally reported by: **Evan (Bitbucket: [ev...
# 3    Originally reported by: **Eric Brown (Bitbucke...
# 4    Originally reported by: **parahelox (Bitbucket...
# ..                                                 ...
# 109  Originally reported by: **Ronny Pfannschmidt (...
# 110  Originally reported by: **cjwatson (Bitbucket:...
# 111  Originally reported by: **Michael Salib (Bitbu...
# 112  Originally reported by: **Matt Chaput (Bitbuck...
# 113  Originally reported by: **Sridhar Ratnakumar (...
#
#                                              reactions  \
# 0    {'url': 'https://api.github.com/repos/benjamin...
# 1    {'url': 'https://api.github.com/repos/benjamin...
# 2    {'url': 'https://api.github.com/repos/benjamin...
# 3    {'url': 'https://api.github.com/repos/benjamin...
# 4    {'url': 'https://api.github.com/repos/benjamin...
# ..                                                 ...
# 109  {'url': 'https://api.github.com/repos/benjamin...
# 110  {'url': 'https://api.github.com/repos/benjamin...
# 111  {'url': 'https://api.github.com/repos/benjamin...
# 112  {'url': 'https://api.github.com/repos/benjamin...
# 113  {'url': 'https://api.github.com/repos/benjamin...
#
#                                           timeline_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 109  https://api.github.com/repos/benjaminp/six/iss...
# 110  https://api.github.com/repos/benjaminp/six/iss...
# 111  https://api.github.com/repos/benjaminp/six/iss...
# 112  https://api.github.com/repos/benjaminp/six/iss...
# 113  https://api.github.com/repos/benjaminp/six/iss...
#
#      performed_via_github_app  state_reason draft pull_request
# 0                         NaN     completed   NaN          NaN
# 1                         NaN           NaN   NaN          NaN
# 2                         NaN           NaN   NaN          NaN
# 3                         NaN     completed   NaN          NaN
# 4                         NaN           NaN   NaN          NaN
# ..                        ...           ...   ...          ...
# 109                       NaN     completed   NaN          NaN
# 110                       NaN     completed   NaN          NaN
# 111                       NaN     completed   NaN          NaN
# 112                       NaN     completed   NaN          NaN
# 113                       NaN     completed   NaN          NaN
#
# [114 rows x 30 columns]

# %% [markdown]
# Took data newcomers and experts which is closed issue

# %%
data_expert_newcomers_closed = data_expert_newcomers[data_expert_newcomers.state == "closed"]

# %% [markdown]
# Show closed data newcomers and experts

# %%
data_expert_newcomers_closed.reset_index(drop=True, inplace=True)
data_expert_newcomers_closed.index += 1 
data_expert_newcomers_closed
# Out:
#                                                   url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# ..                                                ...
# 80  https://api.github.com/repos/benjaminp/six/iss...
# 81  https://api.github.com/repos/benjaminp/six/iss...
# 82  https://api.github.com/repos/benjaminp/six/iss...
# 83  https://api.github.com/repos/benjaminp/six/iss...
# 84  https://api.github.com/repos/benjaminp/six/iss...
#
#                                 repository_url  \
# 1   https://api.github.com/repos/benjaminp/six
# 2   https://api.github.com/repos/benjaminp/six
# 3   https://api.github.com/repos/benjaminp/six
# 4   https://api.github.com/repos/benjaminp/six
# 5   https://api.github.com/repos/benjaminp/six
# ..                                         ...
# 80  https://api.github.com/repos/benjaminp/six
# 81  https://api.github.com/repos/benjaminp/six
# 82  https://api.github.com/repos/benjaminp/six
# 83  https://api.github.com/repos/benjaminp/six
# 84  https://api.github.com/repos/benjaminp/six
#
#                                            labels_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# ..                                                ...
# 80  https://api.github.com/repos/benjaminp/six/iss...
# 81  https://api.github.com/repos/benjaminp/six/iss...
# 82  https://api.github.com/repos/benjaminp/six/iss...
# 83  https://api.github.com/repos/benjaminp/six/iss...
# 84  https://api.github.com/repos/benjaminp/six/iss...
#
#                                          comments_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# ..                                                ...
# 80  https://api.github.com/repos/benjaminp/six/iss...
# 81  https://api.github.com/repos/benjaminp/six/iss...
# 82  https://api.github.com/repos/benjaminp/six/iss...
# 83  https://api.github.com/repos/benjaminp/six/iss...
# 84  https://api.github.com/repos/benjaminp/six/iss...
#
#                                            events_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# ..                                                ...
# 80  https://api.github.com/repos/benjaminp/six/iss...
# 81  https://api.github.com/repos/benjaminp/six/iss...
# 82  https://api.github.com/repos/benjaminp/six/iss...
# 83  https://api.github.com/repos/benjaminp/six/iss...
# 84  https://api.github.com/repos/benjaminp/six/iss...
#
#                                        html_url         id  \
# 1   https://github.com/benjaminp/six/issues/165  198392054
# 2   https://github.com/benjaminp/six/issues/161  198392040
# 3   https://github.com/benjaminp/six/issues/156  198392019
# 4   https://github.com/benjaminp/six/issues/155  198392017
# 5   https://github.com/benjaminp/six/issues/154  198392012
# ..                                          ...        ...
# 80    https://github.com/benjaminp/six/issues/5  198391151
# 81    https://github.com/benjaminp/six/issues/4  198391148
# 82    https://github.com/benjaminp/six/issues/3  198391144
# 83    https://github.com/benjaminp/six/issues/2  198391139
# 84    https://github.com/benjaminp/six/issues/1  198391131
#
#                      node_id  number  \
# 1   MDU6SXNzdWUxOTgzOTIwNTQ=     165
# 2   MDU6SXNzdWUxOTgzOTIwNDA=     161
# 3   MDU6SXNzdWUxOTgzOTIwMTk=     156
# 4   MDU6SXNzdWUxOTgzOTIwMTc=     155
# 5   MDU6SXNzdWUxOTgzOTIwMTI=     154
# ..                       ...     ...
# 80  MDU6SXNzdWUxOTgzOTExNTE=       5
# 81  MDU6SXNzdWUxOTgzOTExNDg=       4
# 82  MDU6SXNzdWUxOTgzOTExNDQ=       3
# 83  MDU6SXNzdWUxOTgzOTExMzk=       2
# 84  MDU6SXNzdWUxOTgzOTExMzE=       1
#
#                                                 title  ...  \
# 1            wraps behaves differently on 2.7 and 3.5  ...
# 2   Inconsistent value returned from http_client.B...  ...
# 3                         unsupported python versions  ...
# 4                       Add six.moves.collections.abc  ...
# 5                     problem installing six with pip  ...
# ..                                                ...  ...
# 80  import hook for replacing except .. as .. with...  ...
# 81                      Include test suite in tarball  ...
# 82                                  map/filter issues  ...
# 83  u() function does not support unicode characte...  ...
# 84                                         ChangeLog?  ...
#
#                     closed_at author_association active_lock_reason  \
# 1   2020-01-07 02:55:44+00:00              OWNER                NaN
# 2   2017-01-02 23:43:51+00:00              OWNER                NaN
# 3   2017-01-02 23:43:35+00:00              OWNER                NaN
# 4   2019-11-05 07:21:56+00:00              OWNER                NaN
# 5   2017-01-02 23:43:30+00:00              OWNER                NaN
# ..                        ...                ...                ...
# 80  2017-01-02 23:31:12+00:00              OWNER                NaN
# 81  2017-01-02 23:31:08+00:00              OWNER                NaN
# 82  2017-01-02 23:31:05+00:00              OWNER                NaN
# 83  2017-01-02 23:31:03+00:00              OWNER                NaN
# 84  2017-01-02 23:30:58+00:00              OWNER                NaN
#
#                                                  body  \
# 1   Originally reported by: **Hexchain Tong (Bitbu...
# 2   Originally reported by: **Eric Brown (Bitbucke...
# 3   Originally reported by: **liso (Bitbucket: [li...
# 4   Originally reported by: **Eklavya Sharma (Bitb...
# 5   Originally reported by: **Anonymous**\n\n-----...
# ..                                                ...
# 80  Originally reported by: **Ronny Pfannschmidt (...
# 81  Originally reported by: **cjwatson (Bitbucket:...
# 82  Originally reported by: **Michael Salib (Bitbu...
# 83  Originally reported by: **Matt Chaput (Bitbuck...
# 84  Originally reported by: **Sridhar Ratnakumar (...
#
#                                             reactions  \
# 1   {'url': 'https://api.github.com/repos/benjamin...
# 2   {'url': 'https://api.github.com/repos/benjamin...
# 3   {'url': 'https://api.github.com/repos/benjamin...
# 4   {'url': 'https://api.github.com/repos/benjamin...
# 5   {'url': 'https://api.github.com/repos/benjamin...
# ..                                                ...
# 80  {'url': 'https://api.github.com/repos/benjamin...
# 81  {'url': 'https://api.github.com/repos/benjamin...
# 82  {'url': 'https://api.github.com/repos/benjamin...
# 83  {'url': 'https://api.github.com/repos/benjamin...
# 84  {'url': 'https://api.github.com/repos/benjamin...
#
#                                          timeline_url  \
# 1   https://api.github.com/repos/benjaminp/six/iss...
# 2   https://api.github.com/repos/benjaminp/six/iss...
# 3   https://api.github.com/repos/benjaminp/six/iss...
# 4   https://api.github.com/repos/benjaminp/six/iss...
# 5   https://api.github.com/repos/benjaminp/six/iss...
# ..                                                ...
# 80  https://api.github.com/repos/benjaminp/six/iss...
# 81  https://api.github.com/repos/benjaminp/six/iss...
# 82  https://api.github.com/repos/benjaminp/six/iss...
# 83  https://api.github.com/repos/benjaminp/six/iss...
# 84  https://api.github.com/repos/benjaminp/six/iss...
#
#     performed_via_github_app  state_reason draft pull_request
# 1                        NaN     completed   NaN          NaN
# 2                        NaN     completed   NaN          NaN
# 3                        NaN     completed   NaN          NaN
# 4                        NaN     completed   NaN          NaN
# 5                        NaN     completed   NaN          NaN
# ..                       ...           ...   ...          ...
# 80                       NaN     completed   NaN          NaN
# 81                       NaN     completed   NaN          NaN
# 82                       NaN     completed   NaN          NaN
# 83                       NaN     completed   NaN          NaN
# 84                       NaN     completed   NaN          NaN
#
# [84 rows x 30 columns]

# %% [markdown]
# Save the data newcomers and experts

# %%
data_expert_newcomers_closed.to_csv("data_expert_newcomers_closed_index.csv")

# %% [markdown]
# ## Combined

# %% [markdown]
# Make dataset csv according experts and newcomers combined labels

# %%
df2_expert_newcomers_labels_combined.to_csv("data_expert_newcomers_combined.csv", index=False)

# %% [markdown]
# Read dataset csv according experts and newcomers labels

# %%
data_expert_newcomers_combined = pd.read_csv("data_expert_newcomers_combined.csv")
data_expert_newcomers_combined
# Out:
#                                                    url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 182  https://api.github.com/repos/benjaminp/six/iss...
# 183  https://api.github.com/repos/benjaminp/six/iss...
# 184  https://api.github.com/repos/benjaminp/six/iss...
# 185  https://api.github.com/repos/benjaminp/six/iss...
# 186  https://api.github.com/repos/benjaminp/six/iss...
#
#                                  repository_url  \
# 0    https://api.github.com/repos/benjaminp/six
# 1    https://api.github.com/repos/benjaminp/six
# 2    https://api.github.com/repos/benjaminp/six
# 3    https://api.github.com/repos/benjaminp/six
# 4    https://api.github.com/repos/benjaminp/six
# ..                                          ...
# 182  https://api.github.com/repos/benjaminp/six
# 183  https://api.github.com/repos/benjaminp/six
# 184  https://api.github.com/repos/benjaminp/six
# 185  https://api.github.com/repos/benjaminp/six
# 186  https://api.github.com/repos/benjaminp/six
#
#                                             labels_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 182  https://api.github.com/repos/benjaminp/six/iss...
# 183  https://api.github.com/repos/benjaminp/six/iss...
# 184  https://api.github.com/repos/benjaminp/six/iss...
# 185  https://api.github.com/repos/benjaminp/six/iss...
# 186  https://api.github.com/repos/benjaminp/six/iss...
#
#                                           comments_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 182  https://api.github.com/repos/benjaminp/six/iss...
# 183  https://api.github.com/repos/benjaminp/six/iss...
# 184  https://api.github.com/repos/benjaminp/six/iss...
# 185  https://api.github.com/repos/benjaminp/six/iss...
# 186  https://api.github.com/repos/benjaminp/six/iss...
#
#                                             events_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 182  https://api.github.com/repos/benjaminp/six/iss...
# 183  https://api.github.com/repos/benjaminp/six/iss...
# 184  https://api.github.com/repos/benjaminp/six/iss...
# 185  https://api.github.com/repos/benjaminp/six/iss...
# 186  https://api.github.com/repos/benjaminp/six/iss...
#
#                                         html_url         id  \
# 0    https://github.com/benjaminp/six/issues/164  198392051
# 1    https://github.com/benjaminp/six/issues/163  198392047
# 2    https://github.com/benjaminp/six/issues/162  198392041
# 3    https://github.com/benjaminp/six/issues/159  198392027
# 4    https://github.com/benjaminp/six/issues/157  198392024
# ..                                           ...        ...
# 182    https://github.com/benjaminp/six/issues/7  198391206
# 183    https://github.com/benjaminp/six/issues/6  198391155
# 184    https://github.com/benjaminp/six/issues/3  198391144
# 185    https://github.com/benjaminp/six/issues/2  198391139
# 186    https://github.com/benjaminp/six/issues/1  198391131
#
#                       node_id  number  \
# 0    MDU6SXNzdWUxOTgzOTIwNTE=     164
# 1    MDU6SXNzdWUxOTgzOTIwNDc=     163
# 2    MDU6SXNzdWUxOTgzOTIwNDE=     162
# 3    MDU6SXNzdWUxOTgzOTIwMjc=     159
# 4    MDU6SXNzdWUxOTgzOTIwMjQ=     157
# ..                        ...     ...
# 182  MDU6SXNzdWUxOTgzOTEyMDY=       7
# 183  MDU6SXNzdWUxOTgzOTExNTU=       6
# 184  MDU6SXNzdWUxOTgzOTExNDQ=       3
# 185  MDU6SXNzdWUxOTgzOTExMzk=       2
# 186  MDU6SXNzdWUxOTgzOTExMzE=       1
#
#                                                  title  ...  \
# 0                                          assertRegex  ...
# 1    int2byte does not match documentation on Python 3  ...
# 2                      Match Python 3 metaclass syntax  ...
# 3                                       Add cgi.escape  ...
# 4          six.moves.builtins causes strange exception  ...
# ..                                                 ...  ...
# 182  Address Python 2/3’s different Exception hiera...  ...
# 183                           Python 3 style `super()`  ...
# 184                                  map/filter issues  ...
# 185  u() function does not support unicode characte...  ...
# 186                                         ChangeLog?  ...
#
#                      closed_at author_association active_lock_reason  \
# 0                          NaN              OWNER                NaN
# 1                          NaN              OWNER                NaN
# 2                          NaN              OWNER                NaN
# 3                          NaN              OWNER                NaN
# 4                          NaN              OWNER                NaN
# ..                         ...                ...                ...
# 182  2017-01-02 23:31:57+00:00              OWNER                NaN
# 183  2017-01-02 23:31:15+00:00              OWNER                NaN
# 184  2017-01-02 23:31:05+00:00              OWNER                NaN
# 185  2017-01-02 23:31:03+00:00              OWNER                NaN
# 186  2017-01-02 23:30:58+00:00              OWNER                NaN
#
#                                                   body  \
# 0    Originally reported by: **Arthur Goldberg (Bit...
# 1    Originally reported by: **Evan (Bitbucket: [ev...
# 2    Originally reported by: **Evan (Bitbucket: [ev...
# 3    Originally reported by: **Anonymous**\n\n-----...
# 4    Originally reported by: **Anonymous**\n\n-----...
# ..                                                 ...
# 182  Originally reported by: **Zearin (Bitbucket: [...
# 183  Originally reported by: **Zearin (Bitbucket: [...
# 184  Originally reported by: **Michael Salib (Bitbu...
# 185  Originally reported by: **Matt Chaput (Bitbuck...
# 186  Originally reported by: **Sridhar Ratnakumar (...
#
#                                              reactions  \
# 0    {'url': 'https://api.github.com/repos/benjamin...
# 1    {'url': 'https://api.github.com/repos/benjamin...
# 2    {'url': 'https://api.github.com/repos/benjamin...
# 3    {'url': 'https://api.github.com/repos/benjamin...
# 4    {'url': 'https://api.github.com/repos/benjamin...
# ..                                                 ...
# 182  {'url': 'https://api.github.com/repos/benjamin...
# 183  {'url': 'https://api.github.com/repos/benjamin...
# 184  {'url': 'https://api.github.com/repos/benjamin...
# 185  {'url': 'https://api.github.com/repos/benjamin...
# 186  {'url': 'https://api.github.com/repos/benjamin...
#
#                                           timeline_url  \
# 0    https://api.github.com/repos/benjaminp/six/iss...
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 182  https://api.github.com/repos/benjaminp/six/iss...
# 183  https://api.github.com/repos/benjaminp/six/iss...
# 184  https://api.github.com/repos/benjaminp/six/iss...
# 185  https://api.github.com/repos/benjaminp/six/iss...
# 186  https://api.github.com/repos/benjaminp/six/iss...
#
#      performed_via_github_app  state_reason draft pull_request
# 0                         NaN           NaN   NaN          NaN
# 1                         NaN           NaN   NaN          NaN
# 2                         NaN           NaN   NaN          NaN
# 3                         NaN           NaN   NaN          NaN
# 4                         NaN           NaN   NaN          NaN
# ..                        ...           ...   ...          ...
# 182                       NaN     completed   NaN          NaN
# 183                       NaN     completed   NaN          NaN
# 184                       NaN     completed   NaN          NaN
# 185                       NaN     completed   NaN          NaN
# 186                       NaN     completed   NaN          NaN
#
# [187 rows x 30 columns]

# %% [markdown]
# Took data newcomers and experts combined which is closed issue

# %%
data_expert_newcomers_combined_closed = data_expert_newcomers_combined[data_expert_newcomers_combined.state == "closed"]

# %% [markdown]
# Show closed data newcomers and experts combined

# %%
data_expert_newcomers_combined_closed.reset_index(drop=True, inplace=True)
data_expert_newcomers_combined_closed.index += 1 
data_expert_newcomers_combined_closed
# Out:
#                                                    url  \
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# 5    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 130  https://api.github.com/repos/benjaminp/six/iss...
# 131  https://api.github.com/repos/benjaminp/six/iss...
# 132  https://api.github.com/repos/benjaminp/six/iss...
# 133  https://api.github.com/repos/benjaminp/six/iss...
# 134  https://api.github.com/repos/benjaminp/six/iss...
#
#                                  repository_url  \
# 1    https://api.github.com/repos/benjaminp/six
# 2    https://api.github.com/repos/benjaminp/six
# 3    https://api.github.com/repos/benjaminp/six
# 4    https://api.github.com/repos/benjaminp/six
# 5    https://api.github.com/repos/benjaminp/six
# ..                                          ...
# 130  https://api.github.com/repos/benjaminp/six
# 131  https://api.github.com/repos/benjaminp/six
# 132  https://api.github.com/repos/benjaminp/six
# 133  https://api.github.com/repos/benjaminp/six
# 134  https://api.github.com/repos/benjaminp/six
#
#                                             labels_url  \
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# 5    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 130  https://api.github.com/repos/benjaminp/six/iss...
# 131  https://api.github.com/repos/benjaminp/six/iss...
# 132  https://api.github.com/repos/benjaminp/six/iss...
# 133  https://api.github.com/repos/benjaminp/six/iss...
# 134  https://api.github.com/repos/benjaminp/six/iss...
#
#                                           comments_url  \
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# 5    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 130  https://api.github.com/repos/benjaminp/six/iss...
# 131  https://api.github.com/repos/benjaminp/six/iss...
# 132  https://api.github.com/repos/benjaminp/six/iss...
# 133  https://api.github.com/repos/benjaminp/six/iss...
# 134  https://api.github.com/repos/benjaminp/six/iss...
#
#                                             events_url  \
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# 5    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 130  https://api.github.com/repos/benjaminp/six/iss...
# 131  https://api.github.com/repos/benjaminp/six/iss...
# 132  https://api.github.com/repos/benjaminp/six/iss...
# 133  https://api.github.com/repos/benjaminp/six/iss...
# 134  https://api.github.com/repos/benjaminp/six/iss...
#
#                                         html_url         id  \
# 1    https://github.com/benjaminp/six/issues/155  198392017
# 2    https://github.com/benjaminp/six/issues/150  198391996
# 3    https://github.com/benjaminp/six/issues/137  198391948
# 4    https://github.com/benjaminp/six/issues/129  198391911
# 5    https://github.com/benjaminp/six/issues/122  198391891
# ..                                           ...        ...
# 130    https://github.com/benjaminp/six/issues/7  198391206
# 131    https://github.com/benjaminp/six/issues/6  198391155
# 132    https://github.com/benjaminp/six/issues/3  198391144
# 133    https://github.com/benjaminp/six/issues/2  198391139
# 134    https://github.com/benjaminp/six/issues/1  198391131
#
#                       node_id  number  \
# 1    MDU6SXNzdWUxOTgzOTIwMTc=     155
# 2    MDU6SXNzdWUxOTgzOTE5OTY=     150
# 3    MDU6SXNzdWUxOTgzOTE5NDg=     137
# 4    MDU6SXNzdWUxOTgzOTE5MTE=     129
# 5    MDU6SXNzdWUxOTgzOTE4OTE=     122
# ..                        ...     ...
# 130  MDU6SXNzdWUxOTgzOTEyMDY=       7
# 131  MDU6SXNzdWUxOTgzOTExNTU=       6
# 132  MDU6SXNzdWUxOTgzOTExNDQ=       3
# 133  MDU6SXNzdWUxOTgzOTExMzk=       2
# 134  MDU6SXNzdWUxOTgzOTExMzE=       1
#
#                                                  title  ...  \
# 1                        Add six.moves.collections.abc  ...
# 2                            RemovedInDjango110Warning  ...
# 3                         Please add per-file licenses  ...
# 4                 Add license headers to source files.  ...
# 5           Improve int2byte() performance on Python 3  ...
# ..                                                 ...  ...
# 130  Address Python 2/3’s different Exception hiera...  ...
# 131                           Python 3 style `super()`  ...
# 132                                  map/filter issues  ...
# 133  u() function does not support unicode characte...  ...
# 134                                         ChangeLog?  ...
#
#                      closed_at author_association active_lock_reason  \
# 1    2019-11-05 07:21:56+00:00              OWNER                NaN
# 2    2017-01-02 23:43:21+00:00              OWNER                NaN
# 3    2017-01-02 23:42:50+00:00              OWNER                NaN
# 4    2017-01-02 23:42:13+00:00              OWNER                NaN
# 5    2017-01-02 23:41:58+00:00              OWNER                NaN
# ..                         ...                ...                ...
# 130  2017-01-02 23:31:57+00:00              OWNER                NaN
# 131  2017-01-02 23:31:15+00:00              OWNER                NaN
# 132  2017-01-02 23:31:05+00:00              OWNER                NaN
# 133  2017-01-02 23:31:03+00:00              OWNER                NaN
# 134  2017-01-02 23:30:58+00:00              OWNER                NaN
#
#                                                   body  \
# 1    Originally reported by: **Eklavya Sharma (Bitb...
# 2    Originally reported by: **Ernest Prabhakar (Bi...
# 3    Originally reported by: **petrcermak (Bitbucke...
# 4    Originally reported by: **philbeaudoin (Bitbuc...
# 5    Originally reported by: **Wouter Bolsterlee (B...
# ..                                                 ...
# 130  Originally reported by: **Zearin (Bitbucket: [...
# 131  Originally reported by: **Zearin (Bitbucket: [...
# 132  Originally reported by: **Michael Salib (Bitbu...
# 133  Originally reported by: **Matt Chaput (Bitbuck...
# 134  Originally reported by: **Sridhar Ratnakumar (...
#
#                                              reactions  \
# 1    {'url': 'https://api.github.com/repos/benjamin...
# 2    {'url': 'https://api.github.com/repos/benjamin...
# 3    {'url': 'https://api.github.com/repos/benjamin...
# 4    {'url': 'https://api.github.com/repos/benjamin...
# 5    {'url': 'https://api.github.com/repos/benjamin...
# ..                                                 ...
# 130  {'url': 'https://api.github.com/repos/benjamin...
# 131  {'url': 'https://api.github.com/repos/benjamin...
# 132  {'url': 'https://api.github.com/repos/benjamin...
# 133  {'url': 'https://api.github.com/repos/benjamin...
# 134  {'url': 'https://api.github.com/repos/benjamin...
#
#                                           timeline_url  \
# 1    https://api.github.com/repos/benjaminp/six/iss...
# 2    https://api.github.com/repos/benjaminp/six/iss...
# 3    https://api.github.com/repos/benjaminp/six/iss...
# 4    https://api.github.com/repos/benjaminp/six/iss...
# 5    https://api.github.com/repos/benjaminp/six/iss...
# ..                                                 ...
# 130  https://api.github.com/repos/benjaminp/six/iss...
# 131  https://api.github.com/repos/benjaminp/six/iss...
# 132  https://api.github.com/repos/benjaminp/six/iss...
# 133  https://api.github.com/repos/benjaminp/six/iss...
# 134  https://api.github.com/repos/benjaminp/six/iss...
#
#      performed_via_github_app  state_reason draft pull_request
# 1                         NaN     completed   NaN          NaN
# 2                         NaN     completed   NaN          NaN
# 3                         NaN     completed   NaN          NaN
# 4                         NaN     completed   NaN          NaN
# 5                         NaN     completed   NaN          NaN
# ..                        ...           ...   ...          ...
# 130                       NaN     completed   NaN          NaN
# 131                       NaN     completed   NaN          NaN
# 132                       NaN     completed   NaN          NaN
# 133                       NaN     completed   NaN          NaN
# 134                       NaN     completed   NaN          NaN
#
# [134 rows x 30 columns]

# %% [markdown]
# Save the data newcomers and experts combined

# %%
data_expert_newcomers_combined_closed.to_csv("data_expert_newcomers_combined_closed_index.csv")

# %% [markdown]
# ## Take title and body

# %% [markdown]
# ### Newcomers

# %% [markdown]
# #### Title

# %% [markdown]
# This code for take title of datasets of newcomers and save it in to csv file.

# %%
data_newcomers_closed['title']
# Out:
# 1                         Add six.moves.collections.abc
# 2                             RemovedInDjango110Warning
# 3                          Please add per-file licenses
# 4                  Add license headers to source files.
# 5            Improve int2byte() performance on Python 3
# 6     Remove superfluous iter()-calls in PY2 iterkey...
# 7                         Test failures with Python 3.1
# 8     six.moves.reload_module uses deprecated imp mo...
# 9             getcwd is renamed between pythons 2 and 3
# 10                print_ should support flush parameter
# 11            Performance improvement for six.iterbytes
# 12                              New built-in exceptions
# 13                               thread.get_ident moved
# 14    Replace the implementation of `six.with_metacl...
# 15          six.u mishandles string ending in backslash
# 16                              missing intern function
# 17    http://pythonhosted.org/six/ docs are not up t...
# 18                test_move_items fails with Python 2.6
# 19    add_metaclass doesn't account for string __slo...
# 20                        six, commands, and subprocess
# 21    six.u(r'\\') behaves differently on Python 2.x...
# 22                         OrderedDict for python < 2.7
# 23                          "five" link goes to nothing
# 24                                 docs for print wrong
# 25          dir(six.moves.<module>) is lazily populated
# 26      Docs for urllib.parse don't mention ParseResult
# 27    Add a function for "true" if 1 == 1 else "fals...
# 28              variable ``six.PY3`` -- is time bomb :)
# 29        Additional object model compatibility methods
# 30    python-six checks fail on GNU/Linux if tkinter...
# 31    Six defines its own callable() on Py3 even if ...
# 32    Could do with some decorators for the __unicod...
# 33    Six does not allow multiple distinct instances...
# 34                     Jython compatibility in setup.py
# 35                                   raw_input v. input
# 36                           Script to “six-ify” source
# 37    Address Python 2/3’s different Exception hiera...
# 38    import hook for replacing except .. as .. with...
# 39                        Include test suite in tarball
# Name: title, dtype: object

# %%
data_title_newcomers = data_newcomers_closed['title']

# %%
pd.DataFrame(data_title_newcomers)
# Out:
#                                                 title
# 1                       Add six.moves.collections.abc
# 2                           RemovedInDjango110Warning
# 3                        Please add per-file licenses
# 4                Add license headers to source files.
# 5          Improve int2byte() performance on Python 3
# 6   Remove superfluous iter()-calls in PY2 iterkey...
# 7                       Test failures with Python 3.1
# 8   six.moves.reload_module uses deprecated imp mo...
# 9           getcwd is renamed between pythons 2 and 3
# 10              print_ should support flush parameter
# 11          Performance improvement for six.iterbytes
# 12                            New built-in exceptions
# 13                             thread.get_ident moved
# 14  Replace the implementation of `six.with_metacl...
# 15        six.u mishandles string ending in backslash
# 16                            missing intern function
# 17  http://pythonhosted.org/six/ docs are not up t...
# 18              test_move_items fails with Python 2.6
# 19  add_metaclass doesn't account for string __slo...
# 20                      six, commands, and subprocess
# 21  six.u(r'\\') behaves differently on Python 2.x...
# 22                       OrderedDict for python < 2.7
# 23                        "five" link goes to nothing
# 24                               docs for print wrong
# 25        dir(six.moves.<module>) is lazily populated
# 26    Docs for urllib.parse don't mention ParseResult
# 27  Add a function for "true" if 1 == 1 else "fals...
# 28            variable ``six.PY3`` -- is time bomb :)
# 29      Additional object model compatibility methods
# 30  python-six checks fail on GNU/Linux if tkinter...
# 31  Six defines its own callable() on Py3 even if ...
# 32  Could do with some decorators for the __unicod...
# 33  Six does not allow multiple distinct instances...
# 34                   Jython compatibility in setup.py
# 35                                 raw_input v. input
# 36                         Script to “six-ify” source
# 37  Address Python 2/3’s different Exception hiera...
# 38  import hook for replacing except .. as .. with...
# 39                      Include test suite in tarball

# %%
data_title_newcomers.to_csv("data_title_newcomers.csv", index=False)

# %% [markdown]
# #### Body

# %% [markdown]
# This code for take body from datasets of newcomers and save it to csv file

# %%
data_newcomers_closed['body']
# Out:
# 1     Originally reported by: **Eklavya Sharma (Bitb...
# 2     Originally reported by: **Ernest Prabhakar (Bi...
# 3     Originally reported by: **petrcermak (Bitbucke...
# 4     Originally reported by: **philbeaudoin (Bitbuc...
# 5     Originally reported by: **Wouter Bolsterlee (B...
# 6     Originally reported by: **Sebastian Bank (Bitb...
# 7     Originally reported by: **Arfrever Frehtes Tai...
# 8     Originally reported by: **Tim Graham (Bitbucke...
# 9     Originally reported by: **Max Grender-Jones (B...
# 10    Originally reported by: **Maik Riechert (Bitbu...
# 11    Originally reported by: **Wouter Bolsterlee (B...
# 12    Originally reported by: **Zhen Wang (Bitbucket...
# 13    Originally reported by: **Joshua Harlow (Bitbu...
# 14    Originally reported by: **charettes (Bitbucket...
# 15    Originally reported by: **Peter Bigot (Bitbuck...
# 16    Originally reported by: **Peter Bigot (Bitbuck...
# 17    Originally reported by: **Marc Abramowitz (Bit...
# 18    Originally reported by: **Arfrever Frehtes Tai...
# 19    Originally reported by: **Alex Gaynor (Bitbuck...
# 20    Originally reported by: **kyleabeauchamp (Bitb...
# 21    Originally reported by: **daviddrysdale (Bitbu...
# 22    Originally reported by: **Konsta Vesterinen (B...
# 23    Originally reported by: **Georg Brandl (Bitbuc...
# 24    Originally reported by: **Robert Robert (Bitbu...
# 25    Originally reported by: **Marc Abramowitz (Bit...
# 26    Originally reported by: **Aymeric Augustin (Bi...
# 27    Originally reported by: **Anonymous**\n\n-----...
# 28    Originally reported by: **Andrej Antonov (Bitb...
# 29    Originally reported by: **Aymeric Augustin (Bi...
# 30    Originally reported by: **Anonymous**\n\n-----...
# 31    Originally reported by: **Ned Batchelder (Bitb...
# 32    Originally reported by: **Tom Grainger (Bitbuc...
# 33    Originally reported by: **Bryce Boe (Bitbucket...
# 34    Originally reported by: **squeaky (Bitbucket: ...
# 35    Originally reported by: **Bryce Boe (Bitbucket...
# 36    Originally reported by: **Zearin (Bitbucket: [...
# 37    Originally reported by: **Zearin (Bitbucket: [...
# 38    Originally reported by: **Ronny Pfannschmidt (...
# 39    Originally reported by: **cjwatson (Bitbucket:...
# Name: body, dtype: object

# %%
data_body_newcomers = data_newcomers_closed['body']

# %%
pd.DataFrame(data_body_newcomers)
# Out:
#                                                  body
# 1   Originally reported by: **Eklavya Sharma (Bitb...
# 2   Originally reported by: **Ernest Prabhakar (Bi...
# 3   Originally reported by: **petrcermak (Bitbucke...
# 4   Originally reported by: **philbeaudoin (Bitbuc...
# 5   Originally reported by: **Wouter Bolsterlee (B...
# 6   Originally reported by: **Sebastian Bank (Bitb...
# 7   Originally reported by: **Arfrever Frehtes Tai...
# 8   Originally reported by: **Tim Graham (Bitbucke...
# 9   Originally reported by: **Max Grender-Jones (B...
# 10  Originally reported by: **Maik Riechert (Bitbu...
# 11  Originally reported by: **Wouter Bolsterlee (B...
# 12  Originally reported by: **Zhen Wang (Bitbucket...
# 13  Originally reported by: **Joshua Harlow (Bitbu...
# 14  Originally reported by: **charettes (Bitbucket...
# 15  Originally reported by: **Peter Bigot (Bitbuck...
# 16  Originally reported by: **Peter Bigot (Bitbuck...
# 17  Originally reported by: **Marc Abramowitz (Bit...
# 18  Originally reported by: **Arfrever Frehtes Tai...
# 19  Originally reported by: **Alex Gaynor (Bitbuck...
# 20  Originally reported by: **kyleabeauchamp (Bitb...
# 21  Originally reported by: **daviddrysdale (Bitbu...
# 22  Originally reported by: **Konsta Vesterinen (B...
# 23  Originally reported by: **Georg Brandl (Bitbuc...
# 24  Originally reported by: **Robert Robert (Bitbu...
# 25  Originally reported by: **Marc Abramowitz (Bit...
# 26  Originally reported by: **Aymeric Augustin (Bi...
# 27  Originally reported by: **Anonymous**\n\n-----...
# 28  Originally reported by: **Andrej Antonov (Bitb...
# 29  Originally reported by: **Aymeric Augustin (Bi...
# 30  Originally reported by: **Anonymous**\n\n-----...
# 31  Originally reported by: **Ned Batchelder (Bitb...
# 32  Originally reported by: **Tom Grainger (Bitbuc...
# 33  Originally reported by: **Bryce Boe (Bitbucket...
# 34  Originally reported by: **squeaky (Bitbucket: ...
# 35  Originally reported by: **Bryce Boe (Bitbucket...
# 36  Originally reported by: **Zearin (Bitbucket: [...
# 37  Originally reported by: **Zearin (Bitbucket: [...
# 38  Originally reported by: **Ronny Pfannschmidt (...
# 39  Originally reported by: **cjwatson (Bitbucket:...

# %%
data_body_newcomers.to_csv("data_body_newcomers.csv", index=False)

# %% [markdown]
# ### Expert

# %% [markdown]
# #### Title

# %% [markdown]
# This code for take body of datasets of newcomers and save it in to csv file

# %%
data_experts_closed['title']
# Out:
# 1              wraps behaves differently on 2.7 and 3.5
# 2     Inconsistent value returned from http_client.B...
# 3                           unsupported python versions
# 4                       problem installing six with pip
# 5                  six.BytesIO doesn't match io.BytesIO
#                             ...
# 91    Address Python 2/3’s different Exception hiera...
# 92                             Python 3 style `super()`
# 93                                    map/filter issues
# 94    u() function does not support unicode characte...
# 95                                           ChangeLog?
# Name: title, Length: 95, dtype: object

# %%
data_title_experts = data_experts_closed['title']

# %%
pd.DataFrame(data_title_experts)
# Out:
#                                                 title
# 1            wraps behaves differently on 2.7 and 3.5
# 2   Inconsistent value returned from http_client.B...
# 3                         unsupported python versions
# 4                     problem installing six with pip
# 5                six.BytesIO doesn't match io.BytesIO
# ..                                                ...
# 91  Address Python 2/3’s different Exception hiera...
# 92                           Python 3 style `super()`
# 93                                  map/filter issues
# 94  u() function does not support unicode characte...
# 95                                         ChangeLog?
#
# [95 rows x 1 columns]

# %%
data_title_experts.to_csv("data_title_experts.csv", index=False)

# %% [markdown]
# #### Body

# %% [markdown]
# This code for take body of datasets of experts and save it in to csv file

# %%
data_experts_closed['body']
# Out:
# 1     Originally reported by: **Hexchain Tong (Bitbu...
# 2     Originally reported by: **Eric Brown (Bitbucke...
# 3     Originally reported by: **liso (Bitbucket: [li...
# 4     Originally reported by: **Anonymous**\n\n-----...
# 5     Originally reported by: **Stephen Lowrie (Bitb...
#                             ...
# 91    Originally reported by: **Zearin (Bitbucket: [...
# 92    Originally reported by: **Zearin (Bitbucket: [...
# 93    Originally reported by: **Michael Salib (Bitbu...
# 94    Originally reported by: **Matt Chaput (Bitbuck...
# 95    Originally reported by: **Sridhar Ratnakumar (...
# Name: body, Length: 95, dtype: object

# %%
data_body_experts = data_experts_closed['body']

# %%
pd.DataFrame(data_body_experts)
# Out:
#                                                  body
# 1   Originally reported by: **Hexchain Tong (Bitbu...
# 2   Originally reported by: **Eric Brown (Bitbucke...
# 3   Originally reported by: **liso (Bitbucket: [li...
# 4   Originally reported by: **Anonymous**\n\n-----...
# 5   Originally reported by: **Stephen Lowrie (Bitb...
# ..                                                ...
# 91  Originally reported by: **Zearin (Bitbucket: [...
# 92  Originally reported by: **Zearin (Bitbucket: [...
# 93  Originally reported by: **Michael Salib (Bitbu...
# 94  Originally reported by: **Matt Chaput (Bitbuck...
# 95  Originally reported by: **Sridhar Ratnakumar (...
#
# [95 rows x 1 columns]

# %%
data_body_experts.to_csv("data_body_experts.csv", index=False)

# %% [markdown]
# ### Both

# %% [markdown]
# #### Title

# %% [markdown]
# This code for take body of datasets of experts and newcomers and save it in to csv file

# %%
data_expert_newcomers_closed['title']
# Out:
# 1              wraps behaves differently on 2.7 and 3.5
# 2     Inconsistent value returned from http_client.B...
# 3                           unsupported python versions
# 4                         Add six.moves.collections.abc
# 5                       problem installing six with pip
#                             ...
# 80    import hook for replacing except .. as .. with...
# 81                        Include test suite in tarball
# 82                                    map/filter issues
# 83    u() function does not support unicode characte...
# 84                                           ChangeLog?
# Name: title, Length: 84, dtype: object

# %%
data_title_expert_newcomers = data_expert_newcomers_closed['title']

# %%
pd.DataFrame(data_title_expert_newcomers)
# Out:
#                                                 title
# 1            wraps behaves differently on 2.7 and 3.5
# 2   Inconsistent value returned from http_client.B...
# 3                         unsupported python versions
# 4                       Add six.moves.collections.abc
# 5                     problem installing six with pip
# ..                                                ...
# 80  import hook for replacing except .. as .. with...
# 81                      Include test suite in tarball
# 82                                  map/filter issues
# 83  u() function does not support unicode characte...
# 84                                         ChangeLog?
#
# [84 rows x 1 columns]

# %%
data_title_expert_newcomers.to_csv("data_title_expert_newcomers.csv", index=False)

# %% [markdown]
# #### Body

# %% [markdown]
# This code for take body of datasets of experts and newcomers and save it in to csv file

# %%
data_expert_newcomers_closed['body']
# Out:
# 1     Originally reported by: **Hexchain Tong (Bitbu...
# 2     Originally reported by: **Eric Brown (Bitbucke...
# 3     Originally reported by: **liso (Bitbucket: [li...
# 4     Originally reported by: **Eklavya Sharma (Bitb...
# 5     Originally reported by: **Anonymous**\n\n-----...
#                             ...
# 80    Originally reported by: **Ronny Pfannschmidt (...
# 81    Originally reported by: **cjwatson (Bitbucket:...
# 82    Originally reported by: **Michael Salib (Bitbu...
# 83    Originally reported by: **Matt Chaput (Bitbuck...
# 84    Originally reported by: **Sridhar Ratnakumar (...
# Name: body, Length: 84, dtype: object

# %%
data_body_expert_newcomers = data_expert_newcomers_closed['body']

# %%
pd.DataFrame(data_body_expert_newcomers)
# Out:
#                                                  body
# 1   Originally reported by: **Hexchain Tong (Bitbu...
# 2   Originally reported by: **Eric Brown (Bitbucke...
# 3   Originally reported by: **liso (Bitbucket: [li...
# 4   Originally reported by: **Eklavya Sharma (Bitb...
# 5   Originally reported by: **Anonymous**\n\n-----...
# ..                                                ...
# 80  Originally reported by: **Ronny Pfannschmidt (...
# 81  Originally reported by: **cjwatson (Bitbucket:...
# 82  Originally reported by: **Michael Salib (Bitbu...
# 83  Originally reported by: **Matt Chaput (Bitbuck...
# 84  Originally reported by: **Sridhar Ratnakumar (...
#
# [84 rows x 1 columns]

# %%
data_body_expert_newcomers.to_csv("data_body_expert_newcomers.csv", index=False)

# %% [markdown]
# # Combined

# %% [markdown]
# ## Title

# %%
data_title_expert_newcomers_combined = data_title_newcomers.append(data_title_experts)

# %%
data_title_expert_newcomers_combined
# Out:
# 1                         Add six.moves.collections.abc
# 2                             RemovedInDjango110Warning
# 3                          Please add per-file licenses
# 4                  Add license headers to source files.
# 5            Improve int2byte() performance on Python 3
#                             ...
# 91    Address Python 2/3’s different Exception hiera...
# 92                             Python 3 style `super()`
# 93                                    map/filter issues
# 94    u() function does not support unicode characte...
# 95                                           ChangeLog?
# Name: title, Length: 134, dtype: object

# %%
pd.DataFrame(data_title_expert_newcomers_combined)
# Out:
#                                                 title
# 1                       Add six.moves.collections.abc
# 2                           RemovedInDjango110Warning
# 3                        Please add per-file licenses
# 4                Add license headers to source files.
# 5          Improve int2byte() performance on Python 3
# ..                                                ...
# 91  Address Python 2/3’s different Exception hiera...
# 92                           Python 3 style `super()`
# 93                                  map/filter issues
# 94  u() function does not support unicode characte...
# 95                                         ChangeLog?
#
# [134 rows x 1 columns]

# %%
data_title_expert_newcomers_combined.to_csv("data_title_expert_newcomers_combined.csv", index=False)

# %% [markdown]
# ## Body

# %%
data_body_expert_newcomers_combined = data_body_newcomers.append(data_body_experts)

# %%
data_body_expert_newcomers_combined
# Out:
# 1     Originally reported by: **Eklavya Sharma (Bitb...
# 2     Originally reported by: **Ernest Prabhakar (Bi...
# 3     Originally reported by: **petrcermak (Bitbucke...
# 4     Originally reported by: **philbeaudoin (Bitbuc...
# 5     Originally reported by: **Wouter Bolsterlee (B...
#                             ...
# 91    Originally reported by: **Zearin (Bitbucket: [...
# 92    Originally reported by: **Zearin (Bitbucket: [...
# 93    Originally reported by: **Michael Salib (Bitbu...
# 94    Originally reported by: **Matt Chaput (Bitbuck...
# 95    Originally reported by: **Sridhar Ratnakumar (...
# Name: body, Length: 134, dtype: object

# %%
data_body_expert_newcomers_combined.to_csv("data_body_expert_newcomers_combined.csv", index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fa6ea122-4727-42f4-b68a-cc34c0ec83c3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
